# %%
train = open('data/gikrya_new_train.out')
new_train = open('data/train_pos.out', 'w')

for line in train:
    if line[0].isdigit():
        i,word,lemma,pos, *_ = line.split('\t')
        new_train.write('\t'.join([word, lemma, pos]) + '\n')
    else:
        new_train.write(line)

new_train.close()

# %%
test = open('data/gikrya_new_test.out')
new_test = open('data/test_pos.out', 'w')

for line in test:
    if line[0].isdigit():
        i,word,lemma,pos, *_ = line.split('\t')
        new_test.write('\t'.join([word, lemma, pos]) + '\n')
    else:
        new_test.write(line)

new_test.close()

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_extraction.text import CountVectorizer
from scipy.sparse import hstack
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
train = open('data/train_pos.out').read().split('\n\n')[:5000]
test = open('data/test_pos.out').read().split('\n\n')[:1000]

# %%
train_data = []
for sent in train:
    sent_list = [['<START>', '<START>', '<START>']]
    for line in sent.split('\n'):
        sent_list.append(line.split('\t'))
    
    train_data.append(sent_list)

test_data = []
for sent in test:
    sent_list = [['<START>', '<START>', '<START>']]
    for line in sent.split('\n'):
        sent_list.append(line.split('\t'))
    
    test_data.append(sent_list)

# %%
train_current_word = []
# train_current_lemma = []
train_previous_word = []
# train_previous_lemma = []
train_previous_pos = []
train_target = []

for sent in train_data:
    
    for i in range(1, len(sent)):
        current_w, current_l, target_pos = sent[i]
        previous_w, previous_l, previous_pos = sent[i-1]
        
        train_target.append(target_pos)
        train_current_word.append(current_w)
#         train_current_lemma.append(current_l)
        train_previous_word.append(previous_w)
#         train_previous_lemma.append(previous_l)
        train_previous_pos.append(previous_pos)
        
test_current_word = []
# test_current_lemma = []
test_previous_word = []
# test_previous_lemma = []
test_previous_pos = []
test_target = []

for sent in test_data:
    
    for i in range(1, len(sent)):
        current_w, current_l, target_pos = sent[i]
        previous_w, previous_l, previous_pos = sent[i-1]
        
        test_target.append(target_pos)
        test_current_word.append(current_w)
#         test_current_lemma.append(current_l)
        test_previous_word.append(previous_w)
#         test_previous_lemma.append(previous_l)
        test_previous_pos.append(previous_pos)

# %%
train_target[:10]
# Out:
# ['DET', 'NOUN', 'VERB', 'PRON', 'ADP', 'NOUN', 'PUNCT', 'PRON', 'PART', 'VERB']

# %%
# PREVIOUS POS ENCODING
lenc_prev_pos = LabelEncoder()
int_prev_pos_enc = lenc_prev_pos.fit_transform(train_previous_pos)
onehot_prev_pos = OneHotEncoder(sparse=True)
int_prev_pos = int_prev_pos_enc.reshape(len(int_prev_pos_enc), 1)

X_prev_pos_train = onehot_prev_pos.fit_transform(int_prev_pos)

int_prev_pos_enc_test = lenc_prev_pos.transform(test_previous_pos)
int_prev_pos_test = int_prev_pos_enc_test.reshape(
                                     len(int_prev_pos_enc_test),1)

X_prev_pos_test = onehot_prev_pos.transform(int_prev_pos_test)

# PREVIOUS and CURRENT WORD ENCODING
cv_word = CountVectorizer(ngram_range=(1,3), analyzer='char', max_features=3000)
cv_word.fit(train_previous_word + train_current_word)

X_prev_word_train = cv_word.transform(train_previous_word)
X_current_word_train = cv_word.transform(train_current_word)

X_prev_word_test = cv_word.transform(test_previous_word)
X_current_word_test = cv_word.transform(test_current_word)

# PREVIOUS and CURRENT LEMMA ENCODING
# cv_lemma = CountVectorizer(ngram_range=(1,1), max_features=10000)
# cv_lemma.fit(train_previous_lemma + train_current_lemma)

# X_prev_lemma_train = cv_lemma.transform(train_previous_lemma)
# X_current_lemma_train = cv_lemma.transform(train_current_lemma)

# X_prev_lemma_test = cv_lemma.transform(test_previous_lemma)
# X_current_lemma_test = cv_lemma.transform(test_current_lemma)

# %%
X_train = hstack([X_prev_pos_train, X_prev_word_train,
                  X_current_word_train])

# %%
print(X_train.shape)
# Out:
# (64888, 6014)

# %%
X_test = hstack([X_prev_pos_test, X_prev_word_test,
                  X_current_word_test])

# %%
print(X_test.shape)
# Out:
# (12745, 6014)

# %%
clf = LogisticRegression()
clf.fit(X_train, train_target)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
pred_pos = clf.predict(X_test)
print(classification_report(test_target, pred_pos))
# Out:
#              precision    recall  f1-score   support
#
#         ADJ       0.92      0.90      0.91      1154
#         ADP       0.96      0.99      0.97      1155
#         ADV       0.89      0.87      0.88       814
#        CONJ       0.86      0.95      0.90       752
#         DET       0.88      0.89      0.88       490
#           H       0.94      0.65      0.77        49
#        INTJ       0.71      0.28      0.40        18
#        NOUN       0.95      0.95      0.95      2857
#         NUM       0.92      0.84      0.88       144
#        PART       0.96      0.86      0.91       471
#        PRON       0.91      0.92      0.91       911
#       PUNCT       1.00      1.00      1.00      2139
#        VERB       0.96      0.96      0.96      1791
#
# avg / total       0.94      0.94      0.94     12745

# %%
# PREVIOUS POS ENCODING

pred_pos_fair = []
true_pos = []

def vectorize_word(word, prev_word, prev_pos):
    int_prev_pos_enc = lenc_prev_pos.transform(
                                   [prev_pos])
    int_prev_pos = int_prev_pos_enc.reshape(
                                         len(int_prev_pos_enc),1)

    X_prev_pos = onehot_prev_pos.transform(int_prev_pos)

    X_prev_word = cv_word.transform([prev_word])
    X_current_word = cv_word.transform([word])

#         X_prev_lemma = cv_lemma.transform([previous_l])
#         X_current_lemma = cv_lemma.transform([current_l])

    X = hstack([X_prev_pos, X_prev_word,
              X_current_word])

    pred = clf.predict(X)[0]
    
    return pred

for sent in test_data[:1000]:
    previous_pos = sent[0][2]
    pos_sequence = []
    
    for i in range(1, len(sent)):
        current_w, current_l, target_pos = sent[i]
        previous_w, previous_l, _ = sent[i-1]
        true_pos.append(target_pos)
        
        pred = vectorize_word(current_w, previous_w, previous_pos)
        previous_pos = pred
        pos_sequence.append(pred)
        
    pred_pos_fair += pos_sequence

# %%
def predict_pos(word, prev_word, prev_pos):
    int_prev_pos_enc = lenc_prev_pos.transform(
                                   [prev_pos])
    int_prev_pos = int_prev_pos_enc.reshape(
                                         len(int_prev_pos_enc),1)

    X_prev_pos = onehot_prev_pos.transform(int_prev_pos)

    X_prev_word = cv_word.transform([prev_word])
    X_current_word = cv_word.transform([word])

#         X_prev_lemma = cv_lemma.transform([previous_l])
#         X_current_lemma = cv_lemma.transform([current_l])

    X = hstack([X_prev_pos, X_prev_word,
              X_current_word])

    pred = clf.predict_proba(X)[0]
    
    return pred

# %%
clf.classes_[10]
# Out:
# 'PRON'

# %%
print(classification_report(true_pos, pred_pos_fair))
# Out:
#              precision    recall  f1-score   support
#
#         ADJ       0.92      0.90      0.91      1154
#         ADP       0.96      0.99      0.97      1155
#         ADV       0.90      0.87      0.88       814
#        CONJ       0.86      0.95      0.90       752
#         DET       0.88      0.89      0.88       490
#           H       0.94      0.65      0.77        49
#        INTJ       0.71      0.28      0.40        18
#        NOUN       0.95      0.95      0.95      2857
#         NUM       0.92      0.85      0.88       144
#        PART       0.95      0.87      0.91       471
#        PRON       0.91      0.92      0.91       911
#       PUNCT       1.00      1.00      1.00      2139
#        VERB       0.96      0.96      0.96      1791
#
# avg / total       0.94      0.94      0.94     12745

# %%
test_current_word[0]
# Out:
# 'Любая'

# %%
test_current_word[:10]
# Out:
# ['Любая',
#  'страна',
#  'имеет',
#  'право',
#  'задержать',
#  'на',
#  'границе',
#  'любого',
#  'человека',
#  'и']

# %%
errors = []
for i in range(len(true_pos)):
    if true_pos[i] != pred_pos_fair[i]:
        errors.append((true_pos[i], pred_pos_fair[i], test_current_word[i]))

# %%
errors
# Out:
# [('PRON', 'DET', 'его'),
#  ('ADV', 'DET', 'все'),
#  ('ADJ', 'NOUN', 'рабочий'),
#  ('PRON', 'CONJ', 'Что'),
#  ('CONJ', 'NOUN', 'Раз'),
#  ('PRON', 'DET', 'все'),
#  ('ADJ', 'ADV', 'равно'),
#  ('NOUN', 'VERB', 'выстрел'),
#  ('PART', 'CONJ', 'и'),
#  ('PRON', 'CONJ', 'что'),
#  ('ADV', 'NOUN', 'зря'),
#  ('PART', 'CONJ', 'и'),
#  ('PART', 'CONJ', 'и'),
#  ('PRON', 'CONJ', 'что'),
#  ('NOUN', 'ADJ', 'взрослых'),
#  ('ADV', 'NOUN', 'еле'),
#  ('CONJ', 'ADV', 'словно'),
#  ('H', 'ADV', 'наверно'),
#  ('ADV', 'ADP', 'назад'),
#  ('NOUN', 'VERB', 'пугало'),
#  ('H', 'ADV', 'наверно'),
#  ('NOUN', 'ADJ', 'хуйню'),
#  ('VERB', 'NOUN', 'пишет'),
#  ('NOUN', 'VERB', 'мол'),
#  ('VERB', 'PRON', 'умеем'),
#  ('PART', 'CONJ', 'и'),
#  ('INTJ', 'NOUN', 'блин'),
#  ('ADJ', 'ADV', 'возможно'),
#  ('ADV', 'CONJ', 'как'),
#  ('INTJ', 'CONJ', 'Ага'),
#  ('ADJ', 'VERB', 'могучего'),
#  ('PRON', 'CONJ', 'Что'),
#  ('DET', 'PRON', 'того'),
#  ('PRON', 'CONJ', 'что'),
#  ('H', 'VERB', 'Может'),
#  ('ADJ', 'DET', 'многие'),
#  ('CONJ', 'ADV', 'как'),
#  ('DET', 'PRON', 'все'),
#  ('ADJ', 'ADP', 'больна'),
#  ('CONJ', 'ADP', 'с'),
#  ('NOUN', 'ADJ', 'Зубковым'),
#  ('PRON', 'CONJ', 'что'),
#  ('NOUN', 'DET', 'Ивашовым'),
#  ('VERB', 'NOUN', 'терпят'),
#  ('NOUN', 'VERB', 'медали'),
#  ('ADP', 'ADJ', 'надо'),
#  ('PART', 'CONJ', 'И'),
#  ('ADV', 'VERB', 'поначалу'),
#  ('CONJ', 'PART', 'Хоть'),
#  ('PART', 'CONJ', 'и'),
#  ('ADV', 'CONJ', 'жадно'),
#  ('H', 'VERB', 'может'),
#  ('CONJ', 'ADV', 'чуть'),
#  ('ADJ', 'NOUN', 'старше'),
#  ('PRON', 'CONJ', 'что'),
#  ('NOUN', 'DET', 'этикет'),
#  ('ADV', 'ADJ', 'крайне'),
#  ('ADJ', 'NOUN', 'строг'),
#  ('NOUN', 'VERB', 'Шелест'),
#  ('PART', 'CONJ', 'и'),
#  ('NOUN', 'VERB', 'жалюзи'),
#  ('ADV', 'ADJ', 'удобно'),
#  ('CONJ', 'PART', 'и'),
#  ('INTJ', 'PART', 'ну'),
#  ('PART', 'PRON', 'это'),
#  ('ADJ', 'VERB', 'подпитываемая'),
#  ('DET', 'PRON', 'это'),
#  ('CONJ', 'PART', 'и'),
#  ('PRON', 'DET', 'Все'),
#  ('PART', 'CONJ', 'и'),
#  ('VERB', 'ADV', 'волновало'),
#  ('NOUN', 'VERB', 'грех'),
#  ('PRON', 'CONJ', 'что'),
#  ('NOUN', 'ADJ', 'сумасшедшему'),
#  ('VERB', 'NOUN', 'может'),
#  ('H', 'ADJ', 'тем_самым'),
#  ('ADV', 'CONJ', 'как'),
#  ('VERB', 'PART', 'нес'),
#  ('INTJ', 'ADP', 'Ох'),
#  ('VERB', 'ADJ', 'обними'),
#  ('ADJ', 'ADV', 'поздно'),
#  ('VERB', 'NOUN', 'слышат'),
#  ('PART', 'PRON', 'это'),
#  ('DET', 'PRON', 'тем'),
#  ('NUM', 'NOUN', 'полторы'),
#  ('DET', 'PRON', 'его'),
#  ('ADJ', 'ADV', 'отвратно'),
#  ('ADJ', 'ADV', 'быстро'),
#  ('VERB', 'NOUN', 'выпью'),
#  ('ADJ', 'NOUN', 'рогатое'),
#  ('NOUN', 'PRON', 'камней'),
#  ('NOUN', 'ADJ', 'самолет'),
#  ('ADJ', 'NOUN', 'сияющему'),
#  ('ADV', 'PRON', 'все'),
#  ('VERB', 'NOUN', 'живет'),
#  ('DET', 'PRON', 'том'),
#  ('NUM', 'ADP', 'сто'),
#  ('NUM', 'NOUN', 'семь'),
#  ('VERB', 'NOUN', 'печет'),
#  ('NUM', 'PUNCT', '1'),
#  ('PRON', 'DET', 'всеми'),
#  ('PART', 'CONJ', 'и'),
#  ('ADV', 'CONJ', 'пока'),
#  ('ADJ', 'NUM', 'тридцатидвухлетний'),
#  ('ADJ', 'NOUN', 'жива'),
#  ('PRON', 'CONJ', 'что'),
#  ('ADJ', 'ADP', 'способна'),
#  ('ADP', 'NOUN', 'порядка'),
#  ('ADJ', 'NOUN', 'путеводной'),
#  ('NOUN', 'VERB', 'нити'),
#  ('ADV', 'NOUN', 'зря'),
#  ('DET', 'PRON', 'То'),
#  ('PRON', 'CONJ', 'что'),
#  ('NOUN', 'ADJ', 'Нападающие'),
#  ('ADV', 'NOUN', 'наголову'),
#  ('ADJ', 'NOUN', 'разбиты'),
#  ('PART', 'CONJ', 'и'),
#  ('PART', 'VERB', 'пожалуйста'),
#  ('ADJ', 'NOUN', 'казачьими'),
#  ('ADV', 'NOUN', 'мигом'),
#  ('DET', 'PRON', 'его'),
#  ('ADJ', 'NOUN', 'маленькой'),
#  ('ADJ', 'NOUN', 'казачьем'),
#  ('NOUN', 'VERB', 'приём'),
#  ('DET', 'PRON', 'оного'),
#  ('ADJ', 'NOUN', 'каминной'),
#  ('NOUN', 'ADJ', 'полкой'),
#  ('PART', 'CONJ', 'Да'),
#  ('NOUN', 'ADJ', 'ведущий'),
#  ('ADV', 'ADJ', 'поскорее'),
#  ('PART', 'ADV', 'незнамо'),
#  ('PRON', 'CONJ', 'что'),
#  ('ADJ', 'NUM', 'один'),
#  ('VERB', 'NOUN', 'Суть'),
#  ('PART', 'VERB', 'нет'),
#  ('PRON', 'DET', 'все'),
#  ('ADV', 'ADP', 'назад'),
#  ('DET', 'PRON', 'то'),
#  ('ADV', 'PRON', 'все'),
#  ('DET', 'PRON', 'это'),
#  ('DET', 'PRON', 'его'),
#  ('NOUN', 'ADJ', 'обвиняемой'),
#  ('PRON', 'DET', 'ее'),
#  ('VERB', 'NOUN', 'восстановим'),
#  ('PART', 'CONJ', 'и'),
#  ('ADJ', 'NOUN', 'порван'),
#  ('ADJ', 'NOUN', 'содеянном'),
#  ('DET', 'PRON', 'его'),
#  ('NOUN', 'PRON', 'имя'),
#  ('PART', 'CONJ', 'Да'),
#  ('PART', 'CONJ', 'и'),
#  ('VERB', 'ADV', 'почернел'),
#  ('DET', 'PRON', 'всех'),
#  ('NOUN', 'PRON', 'тему'),
#  ('VERB', 'NOUN', 'даст'),
#  ('PRON', 'CONJ', 'что'),
#  ('NOUN', 'ADJ', 'Стивен'),
#  ('DET', 'PRON', 'их'),
#  ('ADJ', 'VERB', 'зависим'),
#  ('DET', 'ADV', 'чьи-то'),
#  ('ADV', 'NOUN', 'наугад'),
#  ('ADJ', 'NOUN', 'близок'),
#  ('ADJ', 'NOUN', 'густой'),
#  ('ADJ', 'ADV', 'модно'),
#  ('ADJ', 'ADV', 'модно'),
#  ('CONJ', 'ADP', '+'),
#  ('ADV', 'CONJ', 'как'),
#  ('NOUN', 'VERB', 'статью'),
#  ('ADJ', 'NUM', '1990-х'),
#  ('CONJ', 'PART', 'и'),
#  ('CONJ', 'ADV', 'пока'),
#  ('NUM', 'PUNCT', '2-3'),
#  ('ADJ', 'ADV', 'меньше'),
#  ('NOUN', 'ADV', 'постам'),
#  ('CONJ', 'PRON', 'что'),
#  ('PRON', 'DET', 'его'),
#  ('ADJ', 'NOUN', 'эффективен'),
#  ('NOUN', 'ADJ', 'данных'),
#  ('PART', 'CONJ', 'и'),
#  ('DET', 'PRON', 'это'),
#  ('ADP', 'ADV', 'Вместо'),
#  ('NOUN', 'ADV', 'неисправности'),
#  ('NOUN', 'VERB', 'подраздел'),
#  ('NOUN', 'ADP', 'ИЗМЕНА'),
#  ('ADJ', 'NOUN', 'хаки'),
#  ('ADJ', 'NOUN', 'голубая'),
#  ('VERB', 'NOUN', 'погибли'),
#  ('NUM', 'ADV', 'пятеро'),
#  ('NUM', 'VERB', 'пятьдесят'),
#  ('NUM', 'ADP', 'сто'),
#  ('PART', 'CONJ', 'и'),
#  ('NOUN', 'ADJ', 'часовые'),
#  ('NOUN', 'ADJ', 'подопечный'),
#  ('ADV', 'NOUN', 'теперь'),
#  ('PART', 'CONJ', 'да'),
#  ('ADJ', 'VERB', 'жив'),
#  ('ADV', 'VERB', 'молча'),
#  ('CONJ', 'PART', 'то_ли'),
#  ('DET', 'VERB', 'прочая'),
#  ('PRON', 'DET', 'все'),
#  ('NOUN', 'ADJ', 'Ковалевского'),
#  ('ADV', 'CONJ', 'как'),
#  ('NOUN', 'ADJ', 'малышей'),
#  ('ADV', 'NOUN', 'полностью'),
#  ('NOUN', 'ADJ', 'ванной'),
#  ('VERB', 'ADJ', 'ухудшало'),
#  ('INTJ', 'ADV', 'почему'),
#  ('PRON', 'CONJ', 'что'),
#  ('CONJ', 'ADV', 'как'),
#  ('NOUN', 'ADJ', 'Навального'),
#  ('ADJ', 'NOUN', 'иностранных'),
#  ('PRON', 'DET', 'всех'),
#  ('NUM', 'ADV', 'столько'),
#  ('CONJ', 'NUM', 'сколько'),
#  ('ADJ', 'NOUN', 'Голландский'),
#  ('ADV', 'CONJ', 'как'),
#  ('ADV', 'NOUN', 'дома'),
#  ('CONJ', 'NOUN', 'Раз'),
#  ('PRON', 'DET', 'их'),
#  ('NUM', 'NOUN', 'семь'),
#  ('ADV', 'ADJ', 'похоже'),
#  ('VERB', 'NOUN', 'умер'),
#  ('NOUN', 'ADV', 'право'),
#  ('ADV', 'NOUN', 'верхом'),
#  ('ADJ', 'PUNCT', '4-х'),
#  ('ADV', 'ADP', 'взамен'),
#  ('ADV', 'CONJ', 'как'),
#  ('ADV', 'ADJ', 'Позднее'),
#  ('NOUN', 'VERB', 'зеркала'),
#  ('ADV', 'ADJ', 'неприятно'),
#  ('NOUN', 'ADV', 'неполноту'),
#  ('DET', 'PRON', 'их'),
#  ('ADV', 'NOUN', 'нафига'),
#  ('ADJ', 'ADV', 'актуальнее'),
#  ('NOUN', 'ADP', 'добро'),
#  ('PRON', 'DET', 'всех'),
#  ('ADV', 'VERB', 'мало'),
#  ('NUM', 'ADV', 'столько'),
#  ('PART', 'CONJ', 'Да'),
#  ('PRON', 'DET', 'его'),
#  ('VERB', 'NOUN', 'роднит'),
#  ('ADJ', 'NUM', 'одно'),
#  ('ADJ', 'ADP', 'скромна'),
#  ('ADJ', 'NOUN', 'проста'),
#  ('PRON', 'DET', 'все'),
#  ('ADJ', 'NOUN', 'призвано'),
#  ('H', 'ADV', 'более_того'),
#  ('NOUN', 'VERB', 'пули'),
#  ('ADV', 'CONJ', 'Как'),
#  ('ADJ', 'ADV', 'грустно'),
#  ('ADV', 'NOUN', 'лениво'),
#  ('NOUN', 'ADJ', 'выходным'),
#  ('ADV', 'CONJ', 'как'),
#  ('ADJ', 'VERB', 'задумчивая'),
#  ('PRON', 'DET', 'его'),
#  ('NOUN', 'VERB', 'отдела'),
#  ('NOUN', 'ADP', 'зампред'),
#  ('NUM', 'NOUN', 'полтора'),
#  ('ADJ', 'ADV', 'тактическим'),
#  ('NOUN', 'ADJ', 'горничную'),
#  ('VERB', 'NOUN', 'хочу'),
#  ('ADJ', 'NUM', '76ой'),
#  ('ADV', 'NOUN', 'полностью'),
#  ('ADJ', 'NOUN', 'комплексного'),
#  ('VERB', 'NOUN', 'погиб'),
#  ('NOUN', 'ADV', 'поиски'),
#  ('H', 'VERB', 'Разумеется'),
#  ('ADJ', 'VERB', 'задумана'),
#  ('DET', 'PRON', 'этом'),
#  ('DET', 'PRON', 'их'),
#  ('ADV', 'PART', 'жизненно'),
#  ('DET', 'PRON', 'ее'),
#  ('NOUN', 'ADJ', 'животных'),
#  ('ADV', 'ADJ', 'проворно'),
#  ('DET', 'PRON', 'этого'),
#  ('ADV', 'ADJ', 'возможно'),
#  ('NOUN', 'ADJ', 'данных'),
#  ('VERB', 'NOUN', 'шевеля'),
#  ('ADJ', 'NOUN', 'подбита'),
#  ('NOUN', 'ADJ', 'Влагой'),
#  ('NOUN', 'ADJ', 'ливней'),
#  ('VERB', 'NOUN', 'звучал'),
#  ('ADV', 'NOUN', 'глухо'),
#  ('ADJ', 'VERB', 'затронуто'),
#  ('PRON', 'DET', 'ее'),
#  ('NOUN', 'ADJ', 'животных'),
#  ('NOUN', 'ADJ', 'животные'),
#  ('NOUN', 'ADP', 'вред'),
#  ('ADJ', 'NUM', 'один'),
#  ('CONJ', 'PRON', 'Чем'),
#  ('CONJ', 'PRON', 'тем'),
#  ('VERB', 'CONJ', 'Иди'),
#  ('VERB', 'NOUN', 'Гляжу'),
#  ('CONJ', 'PART', 'и'),
#  ('NOUN', 'ADV', 'почты'),
#  ('NOUN', 'ADJ', 'длиной'),
#  ('DET', 'ADJ', 'того'),
#  ('NOUN', 'VERB', 'дела'),
#  ('NOUN', 'ADJ', 'Пострадавших'),
#  ('NOUN', 'ADJ', 'родными'),
#  ('ADJ', 'VERB', 'жив'),
#  ('DET', 'VERB', 'любая'),
#  ('PRON', 'CONJ', 'чем'),
#  ('VERB', 'NOUN', 'Заняв'),
#  ('NOUN', 'ADJ', 'животных'),
#  ('H', 'VERB', 'может'),
#  ('DET', 'PRON', 'этом'),
#  ('PRON', 'DET', 'всего'),
#  ('ADV', 'ADJ', 'чисто'),
#  ('ADV', 'VERB', 'мало'),
#  ('NOUN', 'DET', 'кота'),
#  ('NOUN', 'ADJ', 'помадой'),
#  ('ADJ', 'NOUN', 'светлых'),
#  ('DET', 'PRON', 'этом'),
#  ('ADJ', 'NOUN', 'мышиный'),
#  ('INTJ', 'ADP', 'Ох'),
#  ('ADV', 'CONJ', 'как'),
#  ('NOUN', 'VERB', 'завал'),
#  ('CONJ', 'ADV', 'как'),
#  ('ADV', 'ADP', 'назло'),
#  ('DET', 'NOUN', 'теми'),
#  ('ADV', 'NOUN', 'неуловимо'),
#  ('VERB', 'NOUN', 'мерцали'),
#  ('VERB', 'NOUN', 'спас'),
#  ('ADJ', 'DET', 'многих'),
#  ('NOUN', 'VERB', 'криминал'),
#  ('CONJ', 'PART', 'и'),
#  ('NOUN', 'H', 'правда'),
#  ('ADV', 'PRON', 'все'),
#  ('PRON', 'CONJ', 'что'),
#  ('PART', 'PRON', 'это'),
#  ('VERB', 'PART', 'денешь'),
#  ('PRON', 'DET', 'Ее'),
#  ('ADJ', 'ADV', 'покончено'),
#  ('NOUN', 'ADP', 'око'),
#  ('VERB', 'NOUN', 'натяну'),
#  ('ADP', 'NOUN', 'поверх'),
#  ('NUM', 'ADV', 'столько'),
#  ('ADJ', 'DET', 'Моторная'),
#  ('NOUN', 'PRON', 'Том'),
#  ('ADV', 'ADJ', 'автоматически'),
#  ('VERB', 'NOUN', 'катайте'),
#  ('PART', 'CONJ', 'и'),
#  ('PART', 'CONJ', 'и'),
#  ('PUNCT', 'ADP', '['),
#  ('ADJ', 'NOUN', 'грядущее'),
#  ('PUNCT', 'ADP', ']'),
#  ('NOUN', 'ADJ', 'Запасному'),
#  ('NUM', 'NOUN', 'трех'),
#  ('PART', 'ADV', 'так'),
#  ('NOUN', 'VERB', 'замши'),
#  ('PART', 'CONJ', 'и'),
#  ('ADP', 'ADJ', 'согласно'),
#  ('ADJ', 'NOUN', 'полицейскому'),
#  ('ADJ', 'ADV', 'Примечательно'),
#  ('NOUN', 'ADJ', 'Мадонну'),
#  ('NOUN', 'VERB', 'потеря'),
#  ('DET', 'PRON', 'этом'),
#  ('NOUN', 'ADV', 'зале'),
#  ('H', 'ADV', 'наверно'),
#  ('ADV', 'CONJ', 'как'),
#  ('ADJ', 'NOUN', 'волчьи'),
#  ('DET', 'PRON', 'этого'),
#  ('PRON', 'CONJ', 'что'),
#  ('NOUN', 'ADJ', 'ближнему'),
#  ('DET', 'PRON', 'том'),
#  ('VERB', 'NOUN', 'Кончай'),
#  ('NOUN', 'VERB', 'перелёта'),
#  ('PART', 'VERB', 'Дескать'),
#  ('ADJ', 'NOUN', 'субботние'),
#  ('NUM', 'ADJ', 'пятерых'),
#  ('ADV', 'NOUN', 'Молча'),
#  ('ADJ', 'NUM', 'один'),
#  ('PART', 'CONJ', 'хоть'),
#  ('VERB', 'NOUN', 'распни'),
#  ('ADJ', 'NUM', 'один'),
#  ('NOUN', 'PRON', 'яму'),
#  ('VERB', 'ADV', 'болеем'),
#  ('ADJ', 'NOUN', 'могучем'),
#  ('NOUN', 'ADV', 'животного'),
#  ('PRON', 'DET', 'тому'),
#  ('PRON', 'CONJ', 'что'),
#  ('PRON', 'DET', 'Всех'),
#  ('VERB', 'NOUN', 'люблю'),
#  ('ADJ', 'ADV', 'кропотлив'),
#  ('PRON', 'CONJ', 'что'),
#  ('NOUN', 'ADP', 'вздох'),
#  ('PART', 'CONJ', 'и'),
#  ('DET', 'PRON', 'том'),
#  ('ADV', 'CONJ', 'как'),
#  ('H', 'VERB', 'что_говорить'),
#  ('PRON', 'CONJ', 'чем'),
#  ('PRON', 'DET', 'его'),
#  ('H', 'NOUN', 'право'),
#  ('ADV', 'DET', 'все'),
#  ('ADJ', 'NOUN', 'крепче'),
#  ('VERB', 'CONJ', 'жили'),
#  ('NOUN', 'VERB', 'повестки'),
#  ('ADJ', 'NOUN', 'сборные'),
#  ('VERB', 'NOUN', 'облечь'),
#  ('PRON', 'CONJ', 'то'),
#  ('PRON', 'DET', 'все'),
#  ('NUM', 'ADP', '4'),
#  ('NUM', 'ADP', '3'),
#  ('DET', 'ADJ', 'немногих'),
#  ('CONJ', 'PRON', 'что'),
#  ('ADV', 'NOUN', 'геройски'),
#  ('VERB', 'NOUN', 'умру'),
#  ('PART', 'PRON', 'это'),
#  ('CONJ', 'PART', 'и'),
#  ('NOUN', 'ADJ', 'прошлому'),
#  ('NOUN', 'ADJ', 'прошлого'),
#  ('PART', 'DET', 'всего'),
#  ('PRON', 'DET', 'Все'),
#  ('ADJ', 'NOUN', 'Камышовой'),
#  ('DET', 'CONJ', 'чьи'),
#  ('ADV', 'ADP', 'назло'),
#  ('H', 'VERB', 'Может'),
#  ('ADJ', 'NOUN', 'Сухие'),
#  ('ADV', 'NOUN', 'рядом'),
#  ('ADV', 'ADP', 'Вокруг'),
#  ('CONJ', 'PART', 'лишь'),
#  ('NOUN', 'ADJ', 'шумом'),
#  ('DET', 'PRON', 'это'),
#  ('ADJ', 'NUM', 'одни'),
#  ('PRON', 'DET', 'всех'),
#  ('INTJ', 'PRON', 'Ммм'),
#  ('ADV', 'CONJ', 'когда'),
#  ('ADV', 'CONJ', 'когда'),
#  ('PRON', 'DET', 'всего'),
#  ('ADJ', 'ADV', 'достаточно'),
#  ('ADV', 'ADJ', 'прекрасно'),
#  ('INTJ', 'ADV', 'почему'),
#  ('NOUN', 'ADV', 'тут'),
#  ('PART', 'CONJ', 'и'),
#  ('NOUN', 'VERB', 'зал'),
#  ('VERB', 'ADV', 'остричь'),
#  ('PRON', 'DET', 'Их'),
#  ('NOUN', 'ADV', 'друг'),
#  ('NOUN', 'CONJ', 'Иванова'),
#  ('VERB', 'ADV', 'начнем'),
#  ('NOUN', 'ADP', 'Вуд'),
#  ('ADV', 'DET', 'домой'),
#  ('VERB', 'NOUN', 'Ищу'),
#  ('DET', 'CONJ', 'теми'),
#  ('INTJ', 'NOUN', 'фу'),
#  ('DET', 'PRON', 'теми'),
#  ('NOUN', 'ADJ', 'Ходорковского'),
#  ('VERB', 'NOUN', 'перерос'),
#  ('ADJ', 'VERB', 'приобретены'),
#  ('NOUN', 'PRON', 'коня'),
#  ('DET', 'PRON', 'ее'),
#  ('VERB', 'NOUN', 'налью'),
#  ('NOUN', 'VERB', 'прилива'),
#  ('VERB', 'NOUN', 'гарантируем'),
#  ('ADV', 'CONJ', 'Как'),
#  ('CONJ', 'PRON', 'что'),
#  ('PART', 'ADJ', 'неизвестно'),
#  ('VERB', 'CONJ', 'Хотя'),
#  ('ADV', 'CONJ', 'как'),
#  ('NOUN', 'ADJ', 'Ученые'),
#  ('VERB', 'NOUN', 'ищут'),
#  ('ADV', 'NOUN', 'молча'),
#  ('ADV', 'ADJ', 'неудобно'),
#  ('ADV', 'DET', 'оттого'),
#  ('PRON', 'DET', 'все'),
#  ('DET', 'PRON', 'это'),
#  ('NUM', 'PUNCT', '4-6'),
#  ('PUNCT', 'ADP', ';'),
#  ('VERB', 'CONJ', 'ища'),
#  ('ADJ', 'NOUN', 'воскресным'),
#  ('NOUN', 'ADV', 'постом'),
#  ('ADV', 'CONJ', 'как'),
#  ('NOUN', 'VERB', 'новосела'),
#  ('PRON', 'DET', 'всех'),
#  ('VERB', 'NOUN', 'просвистели'),
#  ('NOUN', 'CONJ', 'ножа'),
#  ('NOUN', 'VERB', 'правил'),
#  ('PRON', 'DET', 'его'),
#  ('NOUN', 'ADP', 'пежо'),
#  ('NOUN', 'ADV', 'завтрак'),
#  ('ADJ', 'NUM', 'один'),
#  ('NOUN', 'ADV', 'престола'),
#  ('CONJ', 'ADV', 'как'),
#  ('NOUN', 'ADJ', 'сумасшедшую'),
#  ('ADV', 'ADJ', 'достаточно'),
#  ('PRON', 'CONJ', 'что'),
#  ('PART', 'CONJ', 'и'),
#  ('ADV', 'NOUN', 'весьма'),
#  ('VERB', 'NOUN', 'погиб'),
#  ('PUNCT', 'ADP', '['),
#  ('ADP', 'NOUN', 'кроме'),
#  ('PUNCT', 'ADP', ']'),
#  ('NOUN', 'ADV', 'пророка'),
#  ('H', 'ADJ', 'тем_самым'),
#  ('PUNCT', 'ADP', '['),
#  ('VERB', 'PRON', 'гони'),
#  ('ADJ', 'VERB', 'виноват'),
#  ('PRON', 'CONJ', 'что'),
#  ('ADV', 'PRON', 'чего'),
#  ('ADV', 'ADJ', 'дорого'),
#  ('CONJ', 'NOUN', 'Раз'),
#  ('ADV', 'NOUN', 'верхом'),
#  ('PRON', 'CONJ', 'Что'),
#  ('VERB', 'NOUN', 'есть'),
#  ('VERB', 'NOUN', 'дребезжа'),
#  ('VERB', 'NOUN', 'лязгая'),
#  ('NOUN', 'ADP', 'эскиза'),
#  ('ADV', 'NOUN', 'сверху'),
#  ('PART', 'CONJ', 'и'),
#  ('NOUN', 'ADV', 'бесконечность'),
#  ('PRON', 'DET', 'его'),
#  ('VERB', 'NOUN', 'испугала'),
#  ('NOUN', 'CONJ', 'Ад'),
#  ('NOUN', 'ADJ', 'рая'),
#  ('PRON', 'DET', 'Его'),
#  ('VERB', 'NOUN', 'одолел'),
#  ('VERB', 'NOUN', 'руководствуясь'),
#  ('PART', 'NOUN', 'аж'),
#  ('ADV', 'ADJ', 'врукопашную'),
#  ('ADV', 'ADP', 'вокруг'),
#  ('PRON', 'DET', 'ее'),
#  ('PART', 'VERB', 'Пожалуйста'),
#  ('NOUN', 'ADJ', 'милый'),
#  ('PRON', 'DET', 'все'),
#  ('ADJ', 'VERB', 'Подавляющая'),
#  ('PART', 'INTJ', 'Ну'),
#  ('PART', 'CONJ', 'и'),
#  ('DET', 'PRON', 'то'),
#  ('CONJ', 'PART', 'и'),
#  ('INTJ', 'VERB', 'увы'),
#  ('ADJ', 'ADV', 'совместимо'),
#  ('ADJ', 'NOUN', 'семейной'),
#  ('NOUN', 'ADJ', 'нарочных'),
#  ('PRON', 'DET', 'их'),
#  ('ADJ', 'NOUN', 'соседнюю'),
#  ('PART', 'CONJ', 'ни'),
#  ('ADV', 'PRON', 'ничего'),
#  ('PRON', 'CONJ', 'что'),
#  ('PRON', 'CONJ', 'Что'),
#  ('PART', 'CONJ', 'и'),
#  ('PART', 'CONJ', 'Да'),
#  ('PRON', 'CONJ', 'что'),
#  ('ADJ', 'VERB', 'присуща'),
#  ('ADJ', 'ADV', 'крупнее'),
#  ('NOUN', 'ADJ', 'случая'),
#  ('ADP', 'NOUN', 'Благодаря'),
#  ('ADV', 'ADJ', 'планомерно'),
#  ('ADJ', 'ADV', 'реально'),
#  ('PART', 'CONJ', 'как_будто'),
#  ('NOUN', 'ADP', 'Визг'),
#  ('NOUN', 'ADP', 'визг'),
#  ('ADP', 'PART', 'вне'),
#  ('NOUN', 'PRON', 'Ом'),
#  ('DET', 'PRON', 'это'),
#  ('ADV', 'ADP', 'зря'),
#  ('DET', 'PRON', 'этом'),
#  ('ADJ', 'ADV', 'тихо'),
#  ('CONJ', 'PART', 'и'),
#  ('NOUN', 'ADJ', 'равных'),
#  ('PRON', 'CONJ', 'что'),
#  ('PRON', 'DET', 'ее'),
#  ('CONJ', 'ADV', 'только'),
#  ('ADJ', 'DET', 'тихое'),
#  ('ADJ', 'VERB', 'жив'),
#  ('INTJ', 'ADV', 'Боже'),
#  ('CONJ', 'ADV', 'как'),
#  ('VERB', 'NOUN', 'постарела'),
#  ('ADJ', 'NOUN', 'рукописных'),
#  ('CONJ', 'PART', 'и'),
#  ('PART', 'CONJ', 'и'),
#  ('ADV', 'ADP', 'взамен'),
#  ('VERB', 'NOUN', 'реветь'),
#  ('CONJ', 'ADV', 'как'),
#  ('PRON', 'DET', 'Все'),
#  ('ADJ', 'NOUN', 'достойны'),
#  ('NOUN', 'PRON', 'сон'),
#  ('ADV', 'CONJ', 'как'),
#  ('ADP', 'ADV', 'внутри'),
#  ('PRON', 'DET', 'все'),
#  ('ADJ', 'ADV', 'хорошо'),
#  ('ADJ', 'DET', 'таковые'),
#  ('DET', 'PRON', 'его'),
#  ('DET', 'PRON', 'ее'),
#  ('ADP', 'ADV', 'относительно'),
#  ('ADV', 'NOUN', 'прочь'),
#  ('CONJ', 'PART', 'и'),
#  ('ADJ', 'NOUN', 'лисьей'),
#  ('ADJ', 'ADV', 'достаточно'),
#  ('ADJ', 'VERB', 'Дробовая'),
#  ('ADV', 'CONJ', 'Пока'),
#  ('ADV', 'ADJ', 'регулярно'),
#  ('ADV', 'NOUN', 'полностью'),
#  ('NOUN', 'ADJ', 'неправда'),
#  ('ADV', 'ADJ', 'наготове'),
#  ('NOUN', 'PRON', 'имя'),
#  ('DET', 'PRON', 'всем'),
#  ('NOUN', 'VERB', 'дело'),
#  ('DET', 'PRON', 'того'),
#  ('PART', 'CONJ', 'И'),
#  ('NOUN', 'ADJ', 'многоточием'),
#  ('PART', 'CONJ', 'и'),
#  ('NOUN', 'ADJ', 'покое'),
#  ('ADV', 'NOUN', 'жарко'),
#  ('ADP', 'ADV', 'напротив'),
#  ('NOUN', 'ADJ', 'кровати'),
#  ('DET', 'PRON', 'Это'),
#  ('PART', 'CONJ', 'и'),
#  ('NUM', 'NOUN', 'трех'),
#  ('PRON', 'DET', 'Его'),
#  ('NUM', 'ADJ', 'шестеро'),
#  ('NOUN', 'DET', 'омуте'),
#  ('VERB', 'NOUN', 'слушай'),
#  ('PART', 'CONJ', 'и'),
#  ('DET', 'PRON', 'ее'),
#  ('PART', 'CONJ', 'и'),
#  ('VERB', 'CONJ', 'иди'),
#  ('ADJ', 'NOUN', 'Ранней'),
#  ('NOUN', 'ADJ', 'весной'),
#  ('ADJ', 'NOUN', 'звериных'),
#  ('H', 'CONJ', 'однако'),
#  ('DET', 'PRON', 'все'),
#  ('PRON', 'DET', 'ее'),
#  ('NOUN', 'ADJ', 'небесам'),
#  ('DET', 'PRON', 'ее'),
#  ('ADP', 'ADV', 'мимо'),
#  ('NOUN', 'ADJ', 'ушей'),
#  ('ADV', 'CONJ', 'Как'),
#  ('ADJ', 'NOUN', 'грешен'),
#  ('PART', 'CONJ', 'ни'),
#  ('NOUN', 'PRON', 'тона'),
#  ('H', 'VERB', 'Может'),
#  ('PART', 'CONJ', 'ни'),
#  ('ADV', 'CONJ', 'как'),
#  ('ADV', 'ADP', 'против'),
#  ('ADV', 'ADP', 'вокруг'),
#  ('ADJ', 'ADV', 'таинственнее'),
#  ('ADV', 'DET', 'оттого'),
#  ('ADV', 'CONJ', 'пока'),
#  ('NOUN', 'ADJ', 'новенькая'),
#  ('ADV', 'PRON', 'ничего'),
#  ('PART', 'INTJ', 'Ну'),
#  ('PART', 'CONJ', 'и'),
#  ('ADV', 'NOUN', 'очень'),
#  ('PART', 'CONJ', 'да'),
#  ('ADJ', 'VERB', 'принято'),
#  ('ADJ', 'NOUN', 'заключен'),
#  ('VERB', 'NOUN', 'строим'),
#  ('PRON', 'DET', 'их'),
#  ('PART', 'ADV', 'так'),
#  ('ADJ', 'ADV', 'вкуснее'),
#  ('VERB', 'NOUN', 'Разорвите'),
#  ('VERB', 'NOUN', 'разорвете'),
#  ('NOUN', 'ADJ', 'оковы'),
#  ('ADJ', 'DET', 'таковой'),
#  ('ADV', 'NOUN', 'дома'),
#  ('PRON', 'DET', 'ее'),
#  ('VERB', 'NOUN', 'пригласили'),
#  ('ADV', 'ADJ', 'немного'),
#  ('ADJ', 'ADV', 'лучше'),
#  ('NOUN', 'VERB', 'несправедливость'),
#  ('DET', 'PRON', 'тем'),
#  ('CONJ', 'ADP', 'плюс'),
#  ('VERB', 'ADJ', 'Зная'),
#  ('NOUN', 'ADJ', 'преградой'),
#  ('ADV', 'ADJ', 'Внешне'),
#  ('PART', 'CONJ', 'и'),
#  ('PRON', 'DET', 'ее'),
#  ('VERB', 'PRON', 'бойся'),
#  ('H', 'VERB', 'Может'),
#  ('ADJ', 'ADP', 'безвредна'),
#  ('ADV', 'CONJ', 'Когда'),
#  ('ADV', 'CONJ', 'как'),
#  ('NOUN', 'ADP', 'кредо'),
#  ('VERB', 'H', 'значит'),
#  ('INTJ', 'VERB', 'есть'),
#  ('ADV', 'CONJ', 'как'),
#  ('PRON', 'ADV', 'мною'),
#  ('VERB', 'ADP', 'назову'),
#  ('ADP', 'ADV', 'впереди'),
#  ('VERB', 'NOUN', 'извините'),
#  ('PRON', 'DET', 'его'),
#  ('VERB', 'ADV', 'волновало'),
#  ('ADJ', 'NOUN', 'дики'),
#  ('ADJ', 'NOUN', 'полон'),
#  ('NOUN', 'VERB', 'пыли'),
#  ('VERB', 'NOUN', 'кричат'),
#  ('ADJ', 'ADV', 'видно'),
#  ('CONJ', 'PRON', 'что'),
#  ('PART', 'CONJ', 'и'),
#  ('INTJ', 'PRON', 'ммм'),
#  ('DET', 'PRON', 'то'),
#  ('NOUN', 'VERB', 'выход'),
#  ('H', 'VERB', 'выходит'),
#  ('PART', 'CONJ', 'и'),
#  ('ADV', 'ADJ', 'порой'),
#  ('ADV', 'CONJ', 'как'),
#  ('ADJ', 'ADV', 'далеко'),
#  ('ADJ', 'NOUN', 'отделены'),
#  ('NOUN', 'VERB', 'пилы'),
#  ('NOUN', 'CONJ', 'Ноут'),
#  ('PRON', 'NOUN', 'Вами'),
#  ('NOUN', 'ADJ', 'наличными'),
#  ('VERB', 'NOUN', 'истечет'),
#  ('NUM', 'ADJ', 'одному'),
#  ('NOUN', 'PRON', 'имя'),
#  ('DET', 'PRON', 'того'),
#  ('DET', 'PRON', 'все'),
#  ('PRON', 'DET', 'все'),
#  ('ADJ', 'VERB', 'позапрошлого'),
#  ('ADJ', 'ADV', 'честолюбива'),
#  ('ADV', 'NOUN', 'Отныне'),
#  ('ADJ', 'NOUN', 'богатом'),
#  ('PRON', 'CONJ', 'то'),
#  ('PART', 'VERB', 'Нет'),
#  ('ADJ', 'DET', 'многие'),
#  ('NUM', 'ADP', '3'),
#  ('NOUN', 'ADP', 'спрос'),
#  ('PART', 'CONJ', 'ни'),
#  ('PART', 'CONJ', 'и'),
#  ('CONJ', 'PART', 'не_то'),
#  ('CONJ', 'PART', 'не_то'),
#  ('NOUN', 'VERB', 'злобы'),
#  ('ADJ', 'ADV', 'уместно'),
#  ('NOUN', 'ADJ', 'изделий'),
#  ('NOUN', 'VERB', 'гранул'),
#  ('PUNCT', 'ADP', ';'),
#  ('ADJ', 'NOUN', 'пористого'),
#  ('PUNCT', 'ADP', ';'),
#  ('ADV', 'ADJ', 'биологически'),
#  ('PUNCT', 'ADP', ';'),
#  ('ADJ', 'NOUN', 'рекордном'),
#  ('VERB', 'NOUN', 'рос'),
#  ('NOUN', 'ADJ', 'настоящего'),
#  ('NOUN', 'VERB', 'настил'),
#  ('ADV', 'NOUN', 'местами'),
#  ('NOUN', 'ADJ', 'равновесие'),
#  ('ADV', 'CONJ', 'как'),
#  ('PRON', 'DET', 'всем'),
#  ('DET', 'PRON', 'это'),
#  ('PRON', 'CONJ', 'Что'),
#  ('ADV', 'NOUN', 'метко'),
#  ('DET', 'PRON', 'их'),
#  ('NOUN', 'VERB', 'несчастий'),
#  ('ADV', 'CONJ', 'Когда'),
#  ('PRON', 'DET', 'все'),
#  ('VERB', 'NOUN', 'написала'),
#  ('ADV', 'VERB', 'вдали'),
#  ('ADJ', 'NOUN', 'синей'),
#  ('VERB', 'ADP', 'зарос'),
#  ('ADJ', 'NOUN', 'толстой')]

# %%
[-np.log(x) for x in predict_pos('Чей', '<START>', '<START>')]
# Out:
# 8.601719112782513

# %%
predict_pos(obs[0], '<START>', '<START>')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-d7886ba0ce75> in <module>()
# ----> 1 predict_pos(obs[0], '<START>', '<START>')
#
# NameError: name 'obs' is not defined

# %%
def viterbi(obs, states):
    V = [{}]
    
    pred_init_states = [-np.log(x) for x in predict_pos(obs[0], '<START>', '<START>')]
    
    for i in range(len(states)):
        V[0][states[i]] = {"prob": pred_init_states[i], "prev": None}
    # Run Viterbi when t > 0
    
    
    for t in range(1, len(obs)):
        V.append({})
        
        max_tr_prob = 0
        prev_state = None
            
        for prev_st in states:
            prob = V[t-1][prev_st]["prob"]*predict_pos(obs[t], obs[t-1], prev_st)
            if prob == max_tr_prob:
                max_prob = prob
                prev_state = prev_st
        
        V[t]['prob'] = max_tr_prob
        V[t]['prev'] = prev_state
            
    for line in dptable(V):
        print(line)
    opt = []
    # The highest probability
    max_prob = max(value["prob"] for value in V[-1].values())
    previous = None
    # Get most probable state and its backtrack
    for st, data in V[-1].items():
        if data["prob"] == max_prob:
            opt.append(st)
            previous = st
            break
    # Follow the backtrack till the first observation
    for t in range(len(V) - 2, -1, -1):
        opt.insert(0, V[t + 1][previous]["prev"])
        previous = V[t + 1][previous]["prev"]

    print('The steps of states are ' + ' '.join(opt) + ' with highest probability of %s' % max_prob)

def dptable(V):
    # Print a table of steps from dictionary
    yield " ".join(("%12d" % i) for i in range(len(V)))
    for state in V[0]:
        yield "%.7s: " % state + " ".join("%.7s" % ("%f" % v[state]["prob"]) for v in V)

# %%
viterbi(test_current_word[:10], clf.classes_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-412d1a15d26e> in <module>()
# ----> 1 viterbi(test_current_word[:10], clf.classes_)
#
# <ipython-input-46-f3e1fb8a8cc0> in viterbi(obs, states)
#      17         for prev_st in states:
#      18             prob = V[t-1][prev_st]["prob"]*predict_pos(obs[t], obs[t-1], prev_st)
# ---> 19             if prob == max_tr_prob:
#      20                 max_prob = prob
#      21                 prev_state = prev_st
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
obs, states = test_current_word[:10], clf.classes_

V = [{}]

pred_init_states = [-np.log(x) for x in predict_pos(obs[0], '<START>', '<START>')]

for i in range(len(states)):
    V[0][states[i]] = {"prob": pred_init_states[i], "prev": None}
# Run Viterbi when t > 0


for t in range(1, len(obs)):
    V.append({})

    
    cur_state = None

    for st in states:
        probs = [-np.log(x) for x in predict_pos(obs[t], obs[t-1], st)]
        max_tr_prob = 0
        prev_state = None
        for i in range(len(states)):
            prob = V[t-1][prev_st]["prob"]*probs[i]
            if prob > max_tr_prob:
                max_prob = prob
                prev_state = prev_st
                cur_state = states[i]

    V[t][cur_state] = {'prob':max_tr_prob,'prev':prev_state}

for line in dptable(V):
    print(line)
opt = []
# The highest probability
max_prob = max(value["prob"] for value in V[-1].values())
previous = None
# Get most probable state and its backtrack
for st, data in V[-1].items():
    if data["prob"] == max_prob:
        opt.append(st)
        previous = st
        break
# Follow the backtrack till the first observation
for t in range(len(V) - 2, -1, -1):
    opt.insert(0, V[t + 1][previous]["prev"])
    previous = V[t + 1][previous]["prev"]

print('The steps of states are ' + ' '.join(opt) + ' with highest probability of %s' % max_prob)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-bed8e8d3b3a5> in <module>()
#      20         probs = [-np.log(x) for x in predict_pos(obs[t], obs[t-1], prev_st)]
#      21         for i in range(len(states)):
# ---> 22             prob = V[t-1][prev_st]["prob"]*probs[i]
#      23             if prob > max_tr_prob:
#      24                 max_prob = prob
#
# KeyError: 'ADJ'

# %%
cur_states
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-abbccb9ff518> in <module>()
# ----> 1 cur_states
#
# NameError: name 'cur_states' is not defined
