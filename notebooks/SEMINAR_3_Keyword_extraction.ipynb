# %%
import json, os
import pandas as pd
from nltk.corpus import stopwords
import numpy as np
from pymorphy2 import MorphAnalyzer
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
morph = MorphAnalyzer()
stops = set(stopwords.words('russian'))

# %%
pd.set_option('display.max_colwidth', 1000)

# %%
PATH_TO_DATA = './data'

# %%
files = [os.path.join(PATH_TO_DATA, file) for file in os.listdir(PATH_TO_DATA)]

# %%
files[0]
# Out:
# './data/ng_0.jsonlines.zip'

# %%
data = pd.read_json(files[0], lines=True)

# %%
data.loc[0:10, ["keywords"]]
# Out:
#                                                                                                                                                                                                                                                          keywords
# 0                                                                                                                                                                                                                           [яблоко, молодежь, молодежное яблоко]
# 1                                                                                                                                                                                                                                                  [газпром, газ]
# 2   [франсуа рабле, сервантес, шекспир, конан дойл, михаил булгаков, александр грин, борхес, босх, маркес, герман гессе, голландская живопись, гаргантюа и пантагрюэль, дон кихот, мастер и маргарита, москва, россия, история, поэзия, шотландия, баллада, пере]
# 3                                                                                                                                                                                                        [владивосток, суд, ким, футина, выборы, боевое братство]
# 4                                                                                                                                                                                     [новая москва, подмосковье, благоустройство, тинао, городская среда, парки]
# 5                                                                                                                                                                                                               [автоспорт, формула1, гонки, хэмилтон, квят, сша]
# 6                                                                                                                                                                                                                            [ведущие политики, рейтинг, февраль]
# 7                                                                                                                                                                                                [законы, культура, концепция, уголовные дела, платформа, аресты]
# 8                                                                                                                                                                                                [сирия, вооруженный конфликт, газ, углеводороды, турецкий поток]
# 9                                                                                                                                                                                                                                    [фсб, иг, калужская область]
# 10                                                                                                                                                                                  [проза, фантастика, поезд, стихи, переводы, химия, контрабанда, галлюцинации]

# %%
def evaluate(true_kws, predicted_kws):
    assert len(true_kws) == len(predicted_kws)
    
    precisions = []
    recalls = []
    f1s = []
    jaccards = []
    
    for i in range(len(true_kws)):
        true_kw = set(true_kws[i])
        predicted_kw = set(predicted_kws[i])
        
        tp = len(true_kw & predicted_kw)
        union = len(true_kw | predicted_kw)
        fp = len(predicted_kw - true_kw)
        fn = len(true_kw - predicted_kw)
        
        if (tp+fp) == 0:
            prec = 0
        else:
            prec = tp / (tp + fp)
        
        if (tp+fn) == 0:
            rec = 0
        else:
            rec = tp / (tp + fn)
        if (prec+rec) == 0:
            f1 = 0
        else:
            f1 = (2*(prec*rec))/(prec+rec)
            
        jac = tp / union
        
        precisions.append(prec)
        recalls.append(rec)
        f1s.append(f1)
        jaccards.append(jac)
    print('Precision - ', round(np.mean(precisions), 2))
    print('Recall - ', round(np.mean(recalls), 2))
    print('F1 - ', round(np.mean(f1s), 2))
    print('Jaccard - ', round(np.mean(jaccards), 2))

# %%
evaluate(data['keywords'], data['keywords'])
# Out:
# Precision -  1.0
# Recall -  1.0
# F1 -  1.0
# Jaccard -  1.0

# %% [markdown]
# Давайте посмотрим какие обычно ключевые слова.

# %% [markdown]
# # Тупое решение.

# %% [markdown]
# Давайте не будем думать, а попробуем сразу придумать какое-то решение.

# %% [markdown]
# Возьмем первые 5 слов из заголовка.

# %%
evaluate(data['keywords'], data['title'].apply(lambda x: x.lower().split()[:5]))
# Out:
# Precision -  0.06
# Recall -  0.06
# F1 -  0.06
# Jaccard -  0.03

# %% [markdown]
# Или 10.

# %%
evaluate(data['keywords'], data['title'].apply(lambda x: x.lower().split()[:10]))
# Out:
# Precision -  0.06
# Recall -  0.07
# F1 -  0.06
# Jaccard -  0.03

# %% [markdown]
# Теперь попробуем взять самые частотные слова.

# %%
evaluate(data['keywords'], data['content'].apply(lambda x: [x[0] for x in Counter(x.lower().split()).most_common(10)]))
# Out:
# Precision -  0.02
# Recall -  0.04
# F1 -  0.02
# Jaccard -  0.01

# %% [markdown]
# Или вообще рандомные слова.

# %%
evaluate(data['keywords'], data['content'].apply(lambda x: np.random.choice(list(set(x.lower().split())), 10)))
# Out:
# Precision -  0.0
# Recall -  0.01
# F1 -  0.01
# Jaccard -  0.0

# %% [markdown]
# Теперь давайте посмотрим, что вообще извлекается.

# %%
data['title'].apply(lambda x: x.lower().split()[:10]).head(10)
# Out:
# 0                         ["молодежное, "яблоко":, оппозиционная, деятельность, становится, опасной]
# 1                                                                 ["газпрома", на, всех, не, хватит]
# 2                                                   [бесконечная, партия, в, четырехмерные, шахматы]
# 3    [экс-депутат,, осужденная, за, фальсификацию, выборов,, оказалась, членом, "боевого, братства"]
# 4                               [новая, москва, останется, территорией, экологической, безопасности]
# 5                                [f1., гран-при, сша, прошел, без, четырех, машин, и, со, «стопкой»]
# 6                                          [100, ведущих, политиков, россии, в, феврале, 2018, года]
# 7                                               [закон, "о, культуре", принимают, на, фоне, арестов]
# 8                                    [насколько, реальна, газовая, подоплека, сирийского, конфликта]
# 9                                  [фсб:, в, калужской, области, задержаны, четверо, участников, иг]
# Name: title, dtype: object

# %%
data['content'].apply(lambda x: [x[0] for x in Counter(x.lower().split()).most_common(10)]).head(10)
# Out:
# 0                                         [в, и, на, что, не, –, его, «молодежное, с, из]
# 1                                              [в, и, на, –, млрд., куб., по, к, газа, м]
# 2                                                   [в, –, и, не, я, но, что, это, на, с]
# 3                                         [в, на, и, ким, –, по, что, он, видео, зинаиды]
# 4                             [в, и, на, новой, площадью, –, с, развития, москвы, парков]
# 5                                               [в, на, и, не, с, но, уже, что, у, гонки]
# 6                                    [на, в, (с, место)., и, рф, позиции, влияние, по, с]
# 7                                          [в, и, –, по, с, культуре, будет, из, не, как]
# 8                                                [в, и, на, с, что, для, по, –, газа, не]
# 9    [в, террористической, организации, –, задержаны, рф, он, по, возглавляемой, «спящей]
# Name: content, dtype: object

# %% [markdown]
# Когда выбираются самые частотные слова, выбираются всякие стоп-слова. Также из-за плохой токенизации некоторые слова в обоих списках - пунктуация или слова с пунктуацией на концах.

# %% [markdown]
# ## Очищаем текст.

# %%
from string import punctuation
from nltk.corpus import stopwords
punct = set(punctuation+'«»—…“”*№–')
stops = set(stopwords.words('russian'))

def delete_punct_on_edges(word):
    if len(word) < 2:
        
        if not word or word in punct:
            return None
        else:
            # если какая-то буква то выдаем
            return word

    if word[0] not in punct:

        if word[-1] not in punct:
            return word
        else:
            return delete_punct_on_edges(word[:-1])
    else:
        return delete_punct_on_edges(word[1:])
      


def normalize(text):
    
    words = [delete_punct_on_edges(word) for word in text.lower().split()]
    words = [morph.parse(word)[0].normal_form for word in words if word and word not in stops]

    return words

# %%
data['content_norm'] = data['content'].apply(normalize)

# %%
data['title_norm'] = data['title'].apply(normalize)

# %%
data['title_norm'].head(10)
# Out:
# 0            [молодёжный, яблоко, оппозиционный, деятельность, становиться, опасный]
# 1                                                                 [газпром, хватить]
# 2                                      [бесконечный, партия, четырехмерный, шахматы]
# 3    [экс-депутат, осудить, фальсификация, выбор, оказаться, член, боевой, братство]
# 4                 [новый, москва, остаться, территория, экологический, безопасность]
# 5                         [f1, гран-при, сша, пройти, четыре, машина, стопка, штраф]
# 6                                [100, ведущий, политик, россия, февраль, 2018, год]
# 7                                           [закон, культура, принимать, фон, арест]
# 8                     [насколько, реальный, газовый, подоплёка, сирийский, конфликт]
# 9                       [фсб, калужский, область, задержать, четверо, участник, иго]
# Name: title_norm, dtype: object

# %%
evaluate(data['keywords'], data['content_norm'].apply(lambda x: [x[0] for x in Counter(x).most_common(10)]))
# Out:
# Precision -  0.11
# Recall -  0.21
# F1 -  0.14
# Jaccard -  0.08

# %%
evaluate(data['keywords'],data['title_norm'].apply(lambda x: x[:10]))
# Out:
# Precision -  0.13
# Recall -  0.14
# F1 -  0.12
# Jaccard -  0.07

# %% [markdown]
# Качество сильно улучшилось! Можно теперь ещё раз посмотреть, что плохого извлекается.

# %%
data['content_norm'].apply(lambda x: [x[0] for x in Counter(x).most_common(10)]).head(20)
# Out:
# 0                   [яблоко, молодёжный, который, год, акция, активист, это, деятельность, наш, политика]
# 1                               [миллиард, газа, год, куб, метр, газпром, добыча, который, должный, 2020]
# 2                                          [год, это, книга, роман, писать, тот, выйти, один, мир, очень]
# 3                      [ким, зинаида, видео, журналист, год, судебный, бывший, свидетель, рубль, который]
# 4                      [площадь, новый, территория, москва, га, который, тинао, парк, парковый, развитие]
# 5                                [гонка, который, команда, позиция, место, два, один, круг, из-за, пилот]
# 6               [место, влияние, рф, позиция, глава, россия, президент, политический, сергей, российский]
# 7                [культура, закон, стд, который, сфера, предложить, разработать, быть, концепция, услуга]
# 8                        [газопровод, сирия, год, турция, газа, россия, европа, катар, который, турецкий]
# 9        [организация, цос, участник, рф, террористический, задержать, центр, сообщить, говориться, 2018]
# 10                        [тихон, стихомант, это, старик, журибеда, время, казак, сэмена, говорить, отец]
# 11                    [жильё, метр, кв, год, миллион, жилищный, население, строительство, спрос, прогноз]
# 12                [российский, зритель, стать, кино, театр, год, хороший, результат, аудитория, получить]
# 13                    [революция, фестиваль, ленин, фильм, хороший, награда, миронов, делать, один, роль]
# 14               [вечер, фёдоров, книга, балашов, который, виктория, произведение, женщина, герой, елена]
# 15    [который, сирийский, переговоры, сторона, франция, резолюция, макрон, оон, президент, гуманитарный]
# 16                                   [суд, рф, кс, акционер, юкос, запрос, человек, еспч, минюст, бывший]
# 17            [электромобиль, год, тысяча, кобальт, который, компания, аккумулятор, это, автомобиль, том]
# 18                        [хороший, фильм, оскар, год, главный, один, который, стать, церемония, женщина]
# 19                   [трасса, сабина, нюрбургринг, wtcc, пилотесса, гонка, тс1, автомобиль, шмитц, также]
# Name: content_norm, dtype: object

# %% [markdown]
# Ещё остались некоторые стоп-слова. Вместо того, чтобы расширять список, давайте попробуем отсеить несуществительные.

# %%
def normalize(text):
    
    words = [delete_punct_on_edges(word) for word in text.lower().split()]
    words = [morph.parse(word)[0] for word in words if word and word not in stops]
    words = [word.normal_form for word in words if word.tag.POS == 'NOUN']

    return words

# %%
data['content_norm'] = data['content'].apply(normalize)

# %%
evaluate(data['keywords'], data['content_norm'].apply(lambda x: [x[0] for x in Counter(x).most_common(5)]))
# Out:
# Precision -  0.17
# Recall -  0.17
# F1 -  0.16
# Jaccard -  0.1

# %% [markdown]
# Ещу улучшения!

# %%
data['content_norm'].apply(lambda x: [x[0] for x in Counter(x).most_common(10)])
# Out:
# 0                         [яблоко, год, акция, активист, деятельность, политика, власть, человек, жизнь, выборы]
# 1                              [миллиард, год, куб, газа, метр, газпром, добыча, производитель, страна, прогноз]
# 2                                  [год, книга, роман, мир, жанр, стихотворение, перевод, читатель, том, россия]
# 3                        [ким, зинаида, видео, год, журналист, экспертиза, свидетель, рубль, процесс, заседание]
# 4                                  [площадь, москва, территория, га, тинао, парка, парк, столица, развитие, год]
# 5                                 [гонка, команда, позиция, место, круг, пилот, бокс, чемпионат, заезд, дженсон]
# 6                              [место, влияние, рф, позиция, глава, россия, президент, сергей, рейтинг, участие]
# 7                   [культура, закон, сфера, учреждение, изменение, концепция, услуга, проект, сообщество, дело]
# 8                                   [газопровод, сирия, год, турция, газа, европа, россия, катар, поток, проект]
# 9                         [организация, участник, рф, центр, ячейка, эмиссар, область, сирия, деятельность, год]
# 10                              [тихон, стихомант, журибеда, старик, время, казак, сэмена, отец, голос, человек]
# 11                      [жильё, метр, год, миллион, население, спрос, строительство, прогноз, рост, предложение]
# 12                   [зритель, год, театр, кино, исследование, результат, аудитория, фильм, сеанс, деятельность]
# 13                        [революция, фестиваль, ленин, фильм, награда, миронов, роль, сахалин, работа, зритель]
# 14                        [вечер, фёдоров, книга, балашов, виктория, произведение, женщина, герой, елена, жизнь]
# 15                     [переговоры, макрон, оон, сторона, франция, резолюция, президент, дриана, лавров, россия]
# 16                                      [суд, рф, человек, минюст, акционер, еспч, право, юкос, запрос, решение]
# 17                [электромобиль, год, тысяча, кобальт, компания, аккумулятор, автомобиль, том, цена, агентство]
# 18                                [фильм, оскар, год, церемония, женщина, актёр, статуэтка, приз, мужчина, роль]
# 19                    [нюрбургринг, трасса, сабина, автомобиль, пилотесса, шмитц, гонка, участие, рен, автодром]
# 20                             [год, книга, литература, перевод, франция, язык, день, россия, александр, виктор]
# 21                         [сирия, дамаск, война, москва, формирование, армия, военный, вашингтон, сила, войско]
# 22                                [шельф, год, точка, страна, полюс, граница, переговоры, лёд, зрение, километр]
# 23                                    [метр, поэт, центр, март, александр, библиотека, книга, др, дом, владимир]
# 24                 [пассажир, авиакомпания, победа, багаж, тариф, лоукостер, полёт, борт, ространснадзор, пакет]
# 25                        [фильм, серебряков, идея, культура, россия, совет, человек, пожигайло, актёр, история]
# 26                     [температура, земля, энергия, поток, тепло, теплов, глубина, скважина, источник, система]
# 27                       [власть, собчак, система, электорат, время, оппозиция, фигура, интерес, партия, проект]
# 28                             [саммит, путин, встреча, день, президент, буш, россия, вашингтон, саванна, место]
# 29                                [сальери, моцарт, зависть, человек, жизнь, результат, гений, бог, мир, музыка]
#                                                          ...
# 969                [год, украина, отношение, украинец, показатель, ситуация, россия, нато, эксперт, государство]
# 970                              [вода, ресурс, год, проблема, россия, вод, труба, озеро, нанотехнология, объём]
# 971                             [женщина, обложка, выставка, журнал, жизнь, год, алексей, власть, венгеров, век]
# 972                       [мюллер, папа, кардинал, конгрегация, франциск, префект, год, понтифик, пост, герхард]
# 973                             [ольга, парти, карл, фидель, жизнь, гевар, самоубийство, смысл, посольство, год]
# 974                              [финляндия, шайба, период, счёт, ворот, минута, сборная, россия, сочи, селанна]
# 975                         [высоцкий, программа, январь, первое, канал, владимир, год, премьера, день, человек]
# 976                              [терроризм, сша, рамсфелд, война, меморандум, борьба, ирак, буш, вопрос, новое]
# 977                        [препарат, год, лекарство, цена, болезнь, бюджет, мир, механизм, термин, регистрация]
# 978                                 [самолёт, тысяча, рейс, год, океан, поиск, зона, австралия, часть, фрагмент]
# 979             [фильтр, губернаторов, выбор, президент, россия, послание, страна, подпись, претендент, область]
# 980                            [гто, гиря, губернатор, чиновник, программа, участие, пора, условие, весна, друг]
# 981    [совет, движение, отделение, баронов, координатор, собчак, руководство, соловьев, источник, председатель]
# 982                           [система, человек, интеллект, робот, страна, мир, машина, проблема, процесс, боев]
# 983                             [москва, площадка, город, день, сентябрь, столица, тверская, парк, улица, парка]
# 984                                [страна, власть, россия, жизнь, борьба, курс, управление, сила, человек, год]
# 985                        [мигрант, тысяча, россия, работа, рубль, рф, гастарбайтер, год, страна, исследование]
# 986                                    [год, мвф, украина, программа, реформа, суд, выплата, цена, фонд, кредит]
# 987               [пичугин, дело, помилование, ходорковский, год, юкос, президент, следствие, решение, убийство]
# 988              [год, смертность, рак, снижение, профилактика, россия, мужчина, курение, потребление, скрининг]
# 989                          [организация, газа, заседание, россия, москва, опека, создание, страна, иран, фсэг]
# 990            [кпрф, рашкина, валерий, горком, руководство, коммунист, участник, организатор, революция, акция]
# 991          [москва, человек, жизнь, год, проект, программа, долголетие, поколение, продолжительность, участие]
# 992              [акция, партия, яблоко, новосибирск, сторонник, год, регион, власть, монстрация, представитель]
# 993              [криптовалюта, страна, крипторубль, год, валюта, минфин, биткоина, новость, человек, бизнесмен]
# 994                          [ес, политика, страна, европа, брюссель, орбан, правый, венгрия, евросоюз, эксперт]
# 995                             [выброс, развитие, цель, газ, уровень, год, соглашение, сторона, климат, страна]
# 996                              [коваль, юрий, писатель, книга, человек, слово, иосич, клуб, милиционер, осина]
# 997                                 [фильм, режиссёр, год, кино, фестиваль, приз, зритель, огонь, внимание, дух]
# 998    [война, экономика, средство, безопасность, вопрос, проблема, знание, направление, технология, управление]
# Name: content_norm, Length: 999, dtype: object

# %% [markdown]
# Не очень значимые слова все ещё остались. Давайте попробуем отсеять стоп-слова с помощью idf.

# %%
data['content_norm_str'] = data['content'].apply(lambda x: ' '.join(normalize(x)))

# %%
tfidf = TfidfVectorizer(ngram_range=(1,2), min_df=5)

# %%
tfidf.fit(data['content_norm_str'])
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.float64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=5,
#         ngram_range=(1, 2), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
id2word = {i:word for i,word in enumerate(tfidf.get_feature_names())}

# %%
texts_vectors = tfidf.transform(data['content_norm_str'])

# %%
keywords = [[id2word[w] for w in top] for top in texts_vectors.toarray().argsort()[:,:-6:-1]]

# %%
keywords
# Out:
# [['яблоко', 'активист', 'акция', 'дарья', 'деятельность'],
#  ['миллиард куб', 'куб метр', 'куб', 'газпром', 'газа'],
#  ['роман', 'книга', 'жанр', 'стихотворение', 'перевод'],
#  ['ким', 'зинаида', 'видео', 'экспертиза', 'свидетель'],
#  ['га', 'площадь', 'парка', 'парк', 'площадь га'],
#  ['гонка', 'команда', 'бокс', 'баттон', 'позиция'],
#  ['го', 'влияние', 'место', 'рф', 'позиция'],
#  ['культура', 'закон', 'сфера услуга', 'концепция', 'учреждение'],
#  ['газопровод', 'катар', 'сирия', 'турция', 'газа'],
#  ['рф организация', 'год участник', 'участник', 'территория сирия', 'ячейка'],
#  ['тихон', 'старик', 'подушка', 'отец', 'поезд'],
#  ['жильё', 'метр', 'миллион', 'спрос', 'доход население'],
#  ['кино', 'зритель', 'театр', 'аудитория', 'бутусов'],
#  ['фестиваль', 'ленин', 'революция', 'сахалин', 'награда'],
#  ['фёдоров', 'виктория', 'вечер', 'женщина', 'произведение'],
#  ['макрон', 'резолюция', 'переговоры', 'оон', 'франция'],
#  ['акционер', 'минюст', 'юкос', 'суд', 'постановление'],
#  ['аккумулятор', 'бензин', 'автомобиль', 'сколково', 'батарея'],
#  ['фильм', 'оскар', 'статуэтка', 'церемония', 'женщина'],
#  ['трасса', 'гонка', 'автомобиль', 'рен', 'участие гонка'],
#  ['книга', 'перевод', 'литература', 'салон', 'франция'],
#  ['дамаск', 'сирия', 'ополчение', 'вашингтон', 'формирование'],
#  ['шельф', 'полюс', 'хребет', 'точка', 'лёд'],
#  ['метр', 'поэт', 'библиотека', 'март', 'др'],
#  ['авиакомпания', 'пассажир', 'тариф', 'победа', 'полёт'],
#  ['серебряков', 'фильм', 'актёр', 'культура', 'пионер'],
#  ['температура', 'тепло', 'теплов', 'скважина', 'энергия'],
#  ['собчак', 'электорат', 'власть', 'система', 'фигура'],
#  ['саммит', 'буш', 'путин', 'си', 'встреча'],
#  ['зависть', 'гений', 'пушкин', 'музыка', 'бог'],
#  ['сирия', 'группировка', 'анкара', 'иерусалим', 'дамаск'],
#  ['мо', 'управление', 'закупка', 'пентагон', 'приобретение'],
#  ['предмет', 'наука', 'украина', 'химия', 'биология'],
#  ['водохранилище', 'система', 'волга', 'метр', 'река'],
#  ['поэтесса', 'кирилл', 'стих', 'поэт', 'нина'],
#  ['наблюдатель', 'голосование', 'алексей', 'выборы', 'жалоба'],
#  ['снег', 'кошка', 'призрак', 'ветер', 'букет'],
#  ['университет', 'рейтинг', 'вуз', 'добыча ископаемое', 'предмет'],
#  ['теракт', 'метро', 'токио', 'полиция', 'год'],
#  ['крым', 'реабилитация', 'закон', 'суд', 'право'],
#  ['экранизация', 'герой', 'мука', 'революция', 'нтв'],
#  ['русало', 'технология', 'экология', 'производство', 'предприятие'],
#  ['оргкомитет', 'сочи', 'хоккей', 'олимпиада', 'программа'],
#  ['дерево', 'кустарник', 'тысяча дерево', 'тысяча', 'растение'],
#  ['книга', 'метр', 'мемуары', 'аннотация', 'поэт прозаик'],
#  ['марс', 'маск', 'маска', 'илона', 'база'],
#  ['фсб', 'приказ', 'ключ', 'суд', 'переписка'],
#  ['образование',
#   'минобрнаука',
#   'рф глава',
#   'министр образование',
#   'мониторинг'],
#  ['аль', 'каида', 'аль каида', 'заявление', 'теракт'],
#  ['нарушение', 'выборы', 'штаб', 'голосование', 'путин'],
#  ['би', 'отравление солсбери', 'путин вопрос', 'джереми', 'политика дело'],
#  ['сша', 'вашингтон', 'россия', 'оружие', 'договор'],
#  ['власть', 'народ', 'конституция', 'ельцин', 'горбачев'],
#  ['украина', 'память', 'период', 'ссср', 'институт'],
#  ['байкал', 'озеро', 'озеро байкал', 'акция', 'марафон'],
#  ['мексика', 'вмешательство', 'выбор', 'обвинение', 'мексиканец'],
#  ['пастернак', 'стих', 'книга', 'пол', 'борис'],
#  ['фильм', 'оскар', 'статуэтка', 'церемония', 'женщина'],
#  ['пакистан', 'газопровод', 'афганистан', 'индия', 'строительство'],
#  ['олимпиада', 'школьник', 'призёр', 'победитель', 'тысяча рубль'],
#  ['клетка', 'железо', 'процесс', 'пастер', 'испытание'],
#  ['рейс', 'авиакомпания', 'угроза', 'самолёт', 'полёт'],
#  ['выброс', 'газа', 'планет', 'рост', 'год'],
#  ['самолёт', 'татарстан', 'аэропорт', 'катастрофа', 'казань'],
#  ['сущность', 'власть', '70', 'государство', 'пребывание'],
#  ['культура', 'книга', 'чтение', 'энтузиаст', 'формат'],
#  ['поэтесса', 'сон', 'книга', 'читатель', 'поэт'],
#  ['герой', 'антиутопия', 'книга', 'автор', 'мария'],
#  ['рождаемость', 'коэффициент', 'год', 'ребёнок', 'женщина'],
#  ['ссср', 'москва', 'учреждение', 'переулок', 'улица'],
#  ['наблюдатель', 'голосование', 'участок', 'столица', 'избиратель'],
#  ['концерн', 'марио', 'компания', 'проект', 'бизнес'],
#  ['родитель', 'школа', 'учитель', 'задание', 'ребёнок'],
#  ['бог', 'стихотворение', 'поэт', 'человек', 'иисус'],
#  ['внешность', 'раб', 'лес', 'лицо', 'дело рука'],
#  ['пакистан', 'газопровод', 'афганистан', 'индия', 'строительство'],
#  ['протест', 'акция', 'инаугурация', 'оппозиция', 'май'],
#  ['миллиард', 'миллиард доллар', 'доллар', 'боев', 'ввс'],
#  ['сочи', 'олимпиада', 'миллиард рубль', 'минтранс', 'строительство'],
#  ['подмосковье', 'регион', 'год', 'тысяча', 'область'],
#  ['соотечественник', 'переселение', 'программа', 'справка', 'рф'],
#  ['конкурс', 'финалист', 'структура', 'человек отношение', 'конкурс лидер'],
#  ['эко', 'жизнь', 'бог', 'ди', 'умберто эко'],
#  ['пользователь', 'портал', 'голосование', 'проект', 'гражданин'],
#  ['папа', 'франциск', 'кардинал', 'епископ', 'ватикан'],
#  ['поставка', 'экспорт', 'нефть', 'танкер', 'газа'],
#  ['пропуск', 'охранник', 'машина', 'этаж', 'дед'],
#  ['князь', 'владимир', 'русь', 'жена', 'сын'],
#  ['опека', 'нефть', 'цена', 'рынок', 'добыча'],
#  ['занятие', 'секция', 'курс', 'центр', 'старший поколение'],
#  ['абхазия', 'съезд', 'доброволец', 'война', 'батальон'],
#  ['регулирование', 'выброс', 'квота', 'налог', 'рынок'],
#  ['электроэнергетика', 'электроэнергия', 'энергетика', 'энергия', 'год'],
#  ['вещество', 'новичок', 'кгб', 'скрипаль', 'спецслужба'],
#  ['отец', 'василий', 'княжество', 'престол', 'листок'],
#  ['сергей собянин', 'собянин', 'объект', 'банкротство', 'квартира'],
#  ['румыния', 'молдова', 'автономия', 'объединение', 'молдавия'],
#  ['египет', 'аэс', 'росатом', 'реактор', 'энергоблок'],
#  ['церковь', 'иерусалим', 'налог', 'мэрия', 'храм гроб'],
#  ['королевство', 'великобритания', 'дипломат', 'россия', 'нато'],
#  ['флот', 'авария', 'миля', 'авианосец', 'крушение'],
#  ['фестиваль', 'ленин', 'революция', 'сахалин', 'награда'],
#  ['бригада', 'ополчение', 'сила', 'войско', 'оборона'],
#  ['омар', 'мама', 'губа', 'сара', 'девушка'],
#  ['кредитор', 'греция', 'ципраса', 'грек', 'еврозона'],
#  ['дамаск', 'сирия', 'ополчение', 'африна', 'вашингтон'],
#  ['рождаемость', 'интернет', 'секс', 'россиянин', 'автомобиль'],
#  ['травма', 'общество', 'страна', 'развитие', 'россия'],
#  ['резиденция', 'оппозиция', 'саакашвили', 'сторонник', 'акция'],
#  ['врач', 'кабинет', 'поликлиника', 'практика', 'пациент'],
#  ['препарат',
#   'министр здравоохранение',
#   'вероника',
#   'ресурс закупка',
#   'поручение президент'],
#  ['сборная', 'финляндия', 'латвия', 'канадец', 'матч'],
#  ['чёрный', 'праздник', 'поэзия', 'клуб', 'вечер'],
#  ['юрий', 'книга', 'писатель', 'отрыв', 'бессмертие'],
#  ['опера', 'сотрудничество', 'обмен', 'постановка', 'культура'],
#  ['месторождение', 'газпром', 'лицензия', 'конкурс', 'бюджет миллиард'],
#  ['герой', 'фильм', 'кевин', 'воспоминание', 'режиссёр'],
#  ['синай', 'часы минута', 'совещание', 'часы', 'самолёт'],
#  ['путин', 'разделение власть', 'разделение', 'власть', 'россия'],
#  ['отход', 'захоронение', 'экология', 'россия', 'сотрудничество'],
#  ['дамаск', 'сирия', 'коалиция', 'турция', 'манбидж'],
#  ['колумбия', 'килограмм', 'наркотик', 'контейнер', 'изъятие'],
#  ['грузия', 'абхазия', 'нато', 'осетия', 'саакашвили'],
#  ['аккаунт', 'соцсеть', 'объявление', 'страница', 'законодатель'],
#  ['мусор', 'завод', 'отход', 'диоксид', 'сжигание'],
#  ['биосфера', 'вымирание', 'вид', 'миллион год', 'планета'],
#  ['конгрессмен',
#   'палата представитель',
#   'палата',
#   'представитель',
#   'глава министерство'],
#  ['суд', 'журналистка', 'слушатель', 'арест', 'петербург'],
#  ['климат', 'изменение климат', 'ураган', 'изменение', 'температура'],
#  ['женщина', 'водитель', 'распоряжение', 'право', 'машина'],
#  ['румыния', 'армия', 'нато', 'молдавия', 'молдова'],
#  ['соглашение', 'сша', 'торговля', 'импорт', 'квота'],
#  ['ливия', 'кампания', 'миллион евро', 'евро', 'париж'],
#  ['интеллект', 'тело', 'человек', 'боль', 'машина'],
#  ['мгу', 'студент', 'футбол', 'чемпионат', 'чемпионат мир'],
#  ['доказательство', 'фсб', 'дочь', 'россия отравление', 'россия министр'],
#  ['законопроект', 'нато', 'украина', 'главнокомандующий', 'оборона'],
#  ['санкция', 'лавров', 'оружие', 'дезинформация', 'россия'],
#  ['стих', 'тишина', 'рассказ', 'ян', 'буним'],
#  ['крокодил', 'отдых', 'боль', 'бассейн', 'место отдых'],
#  ['церковь', 'иерусалим', 'храм гроб', 'мэрия', 'гроб'],
#  ['руководитель', 'школа', 'родитель', 'ребёнок', 'девочка'],
#  ['выбор', 'работодатель', 'предприниматель', 'выборы', 'голосование'],
#  ['листок', 'поэзия', 'чувство', 'правота', 'жизнь'],
#  ['иностранец', 'икра', 'ракета', 'пример', 'жена'],
#  ['вертолёт', 'машина', 'оборудование', 'малое', 'ростёха'],
#  ['лошадь', 'ди', 'мороз', 'россиянин', 'житель'],
#  ['наталья', 'книга', 'поляков', 'стихотворение', 'типография'],
#  ['команда', 'себастьян', 'нико', 'гонка', 'себастьян феттель'],
#  ['япония', 'правление', 'премьер', 'год', 'страна'],
#  ['пакет', 'оператор', 'закон', 'спецслужба', 'переписка'],
#  ['польша', 'закон', 'еврей', 'сенат', 'поляк'],
#  ['улица', 'площадь', 'благоустройство', 'кольцо', 'находка'],
#  ['хэмилтон', 'пилот', 'льюис', 'росберг', 'гонка'],
#  ['митинг', 'профсоюз', 'илья', 'журналист', 'крым'],
#  ['ходорковский', 'медиа', 'сми', 'власть', 'журналист'],
#  ['пас', 'константин косачев', 'косачев', 'совет европа', 'ассамблея'],
#  ['экспедиция', 'недра', 'проба', 'право', 'арктика'],
#  ['дождь', 'сентябрь', 'ветер', 'провинция', 'китай'],
#  ['цб', 'экономика', 'инфляция', 'минэкономразвития', 'центробанк'],
#  ['росатом', 'египет', 'эль', 'станция', 'контракт'],
#  ['епархия', 'игорь', 'приход', 'прихожанин', 'священник'],
#  ['спектакль', 'постановка', 'театр', 'фестиваль', 'зритель'],
#  ['ер', 'партия', 'медведев', 'путин', 'партия власть'],
#  ['компенсация', 'юкос', 'выплата', 'конституция', 'размер'],
#  ['церковь', 'университет', 'храм', 'вуз', 'патриарх'],
#  ['мо', 'управление', 'закупка', 'пентагон', 'приобретение'],
#  ['пресс', 'трамп', 'пресса', 'фильм', 'президент'],
#  ['участок', 'голосование', 'мчс россия', 'проведение выбор', 'область'],
#  ['регистрация', 'володин', 'госдума', 'глаз', 'депутат'],
#  ['грузия', 'мэрия', 'акция', 'тбилиси', 'мвд'],
#  ['закон', 'язык', 'украина', 'киев', 'суд'],
#  ['опека', 'барра', 'нефтедобыча', 'добыча', 'сокращение'],
#  ['комиссаров', 'депутат', 'стол', 'журналист', 'жюри'],
#  ['поход', 'муза', 'велосипед', 'дорога', 'километр'],
#  ['джонсон', 'скрипаль', 'полиция', 'россия', 'полковник'],
#  ['подпись', 'кандидат', 'горбунов', 'умерший', 'жалоба'],
#  ['авианосец', 'строительство комплекс', 'базирование', 'шторм', 'комплекс'],
#  ['завод', 'производство', 'свинец', 'строительство', 'аккумулятор'],
#  ['нация', 'народ', 'население', 'идентичность', 'национальность'],
#  ['юнеско', 'заповедник', 'трасса', 'эколог', 'строительство'],
#  ['явка', 'медведев', 'зюганов', 'голос', 'избиратель'],
#  ['дед', 'лиза', 'птица', 'банка', 'полка'],
#  ['берег', 'вода', 'язык', 'отдых', 'пляж'],
#  ['образование', 'система', 'преподаватель', 'работник', 'обучение'],
#  ['беляков', 'препарат', 'законопроект', 'средство', 'исследование'],
#  ['создатель', 'выставка', 'творчество', 'художник', 'выставка работа'],
#  ['компания', 'стенд', 'выставка', 'макет', 'стенд компания'],
#  ['венесуэла', 'нефть', 'монета', 'валюта', 'энергоресурсы'],
#  ['приднестровье', 'молдова', 'оружие', 'армия', 'вооружение'],
#  ['миротворец', 'беларусь', 'украина', 'минск', 'белоруссия'],
#  ['колония', 'заключённый', 'женщина', 'наказание', 'вербовка'],
#  ['песнь', 'диссидент', 'книжка', 'книга', 'народ'],
#  ['мощность', 'ветроэнергетика', 'ветроустановка', 'миллиард евро', 'год'],
#  ['фильм', 'тоня', 'драма', 'оскар', 'целое'],
#  ['иго', 'нефть', 'террорист', 'переработка', 'объект'],
#  ['гута', 'самолёт цель', 'аль ислам', 'прекращение огонь', 'пригород'],
#  ['ислам', 'германия', 'храм', 'марш', 'конфессия'],
#  ['вид', 'миллион', 'биосфера', 'биоразнообразие', 'животное'],
#  ['год учёт', 'организация год', 'узбекистан', 'рассмотрение', 'понедельник'],
#  ['администрирование', 'взнос', 'министерство финансы', 'страхов', 'налог'],
#  ['лукашенко', 'патриарх', 'папа', 'встреча', 'белоруссия'],
#  ['кндр', 'корея', 'пхеньян', 'олимпиада', 'тиллерсон'],
#  ['израиль', 'террорист', 'араб', 'иудей', 'убийца'],
#  ['путин', 'явка', 'газета', 'выбор', 'переизбрание'],
#  ['отравление', 'скрипаль', 'конъюнктура', 'запад', 'власть'],
#  ['книжка', 'таллин', 'рыцарь', 'задание', 'ласточка'],
#  ['доклад', 'нато', 'данил', 'безопасность', 'ситуация'],
#  ['самолёт', 'турция', 'экипаж', 'вертолёт', 'су'],
#  ['григорий', 'соломон', 'зинаида', 'философ', 'мыслитель'],
#  ['пушкин', 'читатель', 'книга', 'поэт', 'читатель книга'],
#  ['собчак', 'крым', 'штаб', 'ксения', 'эфир'],
#  ['сбор', 'военный', 'лукашенко', 'военный эксперт', 'мужчина'],
#  ['гудков', 'партия', 'собчак', 'яблоко', 'явлинский'],
#  ['клетка', 'матрица', 'вода', 'титан', 'физиология'],
#  ['путин', 'электорат', 'избиратель', 'явка', 'выбор'],
#  ['нация', 'народ', 'население', 'идентичность', 'национальность'],
#  ['доллар', 'рубль', 'цена', 'нефть', 'доллар баррель'],
#  ['индия', 'пакистан', 'сша', 'исламабад', 'вашингтон'],
#  ['рассуждение', 'человек', 'представление', 'эволюция', 'реакция'],
#  ['нарушение право', 'произвол', 'конкурс', 'инвалид', 'милиция'],
#  ['талибан', 'афганистан', 'талиб', 'провинция', 'мулла'],
#  ['умберто', 'умберто эко', 'эко', 'литр', 'треугольник'],
#  ['словарь', 'авторство', 'онлайн', 'пользователь', 'терминология'],
#  ['доминика', 'кофе', 'клиент', 'собес', 'гарри'],
#  ['трансформация', 'энергетика', 'компания', 'индустрия', 'технология'],
#  ['мусульманин', 'экстремизм', 'заключённый', 'колония', 'тюрьма'],
#  ['цивилизация', 'существо', 'вирус', 'интеллект', 'живой существо'],
#  ['дагестан', 'республика', 'чечня', 'селение', 'ислам'],
#  ['комиссия', 'мак', 'представитель', 'авиация', 'транспорт'],
#  ['теракт', 'метро', 'токио', 'полиция', 'год'],
#  ['метр центрполиграф', 'центрполиграф', 'детектив', 'литература', 'метр'],
#  ['гонка', 'трасса', 'круг', 'роба', 'бочка'],
#  ['грузия', 'турция', 'тбилиси', 'анкара', 'разведка'],
#  ['заседание', 'банка', 'энергетика', 'туркменистан', 'румыния'],
#  ['церемония', 'церемония закрытие', 'игра', 'закрытие', 'стадион'],
#  ['газа', 'куб метр', 'куб', 'миллиард куб', 'газопровод'],
#  ['рада', 'надежда', 'юрий луценко', 'луценко', 'действие оружие'],
#  ['роман', 'книга', 'жанр', 'стихотворение', 'перевод'],
#  ['таня', 'бек', 'литература', 'татьяна бек', 'встреча'],
#  ['пользователь', 'карта', 'фонд', 'мошенник', 'сумма тысяча'],
#  ['кандидат', 'подпись', 'выборы', 'избирком', 'парнас'],
#  ['хокинг', 'стивен', 'стивен хокинг', 'год', 'дыра'],
#  ['собчак', 'пожар', 'дом', 'волгоград', 'чп'],
#  ['дождь', 'житель', 'город', 'германия', 'горожанин'],
#  ['допрос', 'пас', 'страсбург', 'киев', 'заседание'],
#  ['украина', 'нато', 'венгрия', 'комиссия', 'язык'],
#  ['румыния', 'армия', 'нато', 'молдавия', 'молдова'],
#  ['украина', 'крым', 'постановление', 'агрессия', 'рф'],
#  ['композиция', 'телевизор', 'искусство', 'федора', 'альбом'],
#  ['поликлиника', 'врач', 'здравоохранение', 'пациент', 'год'],
#  ['великобритания', 'соглашение', 'климат', 'хранение', 'финансирование'],
#  ['порошенко', 'симпатия', 'тимошенко', 'опрос', 'партия'],
#  ['книга', 'папа', 'вадим', 'книга книга', 'детство'],
#  ['титов', 'встреча', 'путин', 'глава государство', 'состав'],
#  ['нато', 'членство', 'украина', 'план действие', 'порошенко'],
#  ['рождаемость', 'коэффициент', 'год', 'ребёнок', 'женщина'],
#  ['биржа', 'рынок', 'инфраструктура', 'экономика', 'торговля'],
#  ['матч', 'игра', 'клуб', 'традиция', 'команда'],
#  ['театр', 'спектакль', 'фестиваль', 'постановка', 'домик'],
#  ['байкал', 'озеро байкал', 'озеро', 'экология', 'русало'],
#  ['наука', 'бизнес', 'проект', 'знание', 'исследование'],
#  ['команда', 'шина', 'гонка', 'круг', 'подиум'],
#  ['язык', 'графика', 'единство', 'народ', 'республика'],
#  ['республика корея', 'корея', 'производительность', 'республика', 'ввп'],
#  ['осколок', 'тело', 'падение', 'земля', 'челябинск'],
#  ['вто', 'абхазия', 'тбилиси', 'грузия', 'россия'],
#  ['победа', 'путин', 'россия', 'владимир путин', 'партия'],
#  ['режиссёр', 'сцена театр', 'театр', 'сцена', 'создание'],
#  ['молдавия', 'додон', 'автономия', 'совет', 'игорь додон'],
#  ['джаз', 'др', 'челябинск', 'книга', 'севастополь'],
#  ['огонь', 'чудо', 'пасха', 'гроб', 'обряд'],
#  ['санкция', 'шельф', 'нефть', 'сотрудничество', 'проект'],
#  ['газа', 'миллиард куб', 'куб метр', 'болгария', 'куб'],
#  ['ас сися', 'сися', 'ас', 'египет', 'египтянин'],
#  ['раввин', 'еврей', 'литр', 'израиль', 'миссия'],
#  ['игра', 'волонтёр', 'медаль', 'спортсмен', 'область'],
#  ['язык', 'член правительство', 'республика', 'совещание', 'шутка'],
#  ['оркестр', 'татарстан', 'музыкант', 'музыка', 'коллектив'],
#  ['пехота', 'вмс', 'система', 'разведка', 'сша'],
#  ['колледж', 'онлайн', 'заявление', 'медик', 'запись'],
#  ['команда', 'гонка', 'пит', 'пилот', 'бразилия'],
#  ['бен', 'тунис', 'революция', 'год', 'режим'],
#  ['волкер', 'киев', 'миссия', 'обсе', 'украина'],
#  ['крым', 'полуостров', 'вод', 'куб метр', 'куб'],
#  ['дивизия', 'техника', 'год состав', 'армия', 'орден'],
#  ['энергетика', 'развитие энергетика', 'дипломатия', 'развитие', 'технология'],
#  ['ес', 'британия', 'партнерство', 'германия', 'страна ес'],
#  ['григорий', 'соломон', 'зинаида', 'философ', 'мыслитель'],
#  ['мечеть', 'республика', 'ингушетия', 'муфтий', 'акция'],
#  ['великобритания', 'захаров', 'газета', 'дочь', 'адрес россия'],
#  ['гонка', 'михаил', 'итальянец', 'заезд', 'пилот'],
#  ['спектакль', 'театр', 'опера', 'лиза', 'герман'],
#  ['балет', 'танец', 'театр', 'спектакль', 'музыка'],
#  ['стоимость', 'прокладка', 'миллиард евро', 'проект', 'евро'],
#  ['мыслитель', 'культура', 'литература', 'философия', 'зарубежье'],
#  ['якутия', 'восстание', 'книга', 'сибирь', 'леонид'],
#  ['отход', 'производство', 'русало', 'очистка', 'пыль'],
#  ['касьянов', 'парнас', 'партия', 'съезд', 'праймериза'],
#  ['пилот', 'гонка', 'чемпионат', 'очки', 'поворот'],
#  ['ракета', 'бомбардировщик', 'су', 'авиация', 'корабль'],
#  ['жизнь', 'чиновник', 'описание', 'книга', 'александр'],
#  ['ольга', 'журналистка', 'прокуратура', 'дума', 'депутат дума'],
#  ['зарплата', 'опрос', 'респондент', 'статистика', 'задержка'],
#  ['манёвр', 'бюджет', 'пошлина', 'налог', 'администрирование'],
#  ['взнос', 'разоружение', 'совет европа', 'европа', 'путин'],
#  ['трамп',
#   'ссылка представитель',
#   'представитель администрация',
#   'президент федерация',
#   'путин'],
#  ['электроэнергия', 'установка', 'принцип работа', 'изобретение', 'кирилл'],
#  ['донбасс', 'миротворец', 'украина', 'волкер', 'киев'],
#  ['интернет', 'власть', 'сеть', 'общество', 'анонимность'],
#  ['армения', 'кандидат', 'президент', 'депутат', 'партия'],
#  ['американец', 'терроризм', 'культура', 'америка', 'человек'],
#  ['нурсултан назарбаев', 'нурсултан', 'назарбаев', 'россия китай', 'азия'],
#  ['бог', 'стихотворение', 'поэт', 'человек', 'иисус'],
#  ['авиакатастрофа', 'самолёт', 'крушение', 'песок', 'минобороны'],
#  ['троцкий', 'ленин', 'революция', 'лариса', 'теория'],
#  ['вертолёт', 'комплекс', 'ми', 'оборона', 'боев'],
#  ['интернет', 'газета', 'политика', 'сми', 'информация'],
#  ['ингушетия', 'боевик', 'ранение', 'милиция', 'сотрудник'],
#  ['добыча', 'нефтедобыча', 'пик', 'показатель', 'год'],
#  ['сочи', 'билет', 'трасса', 'мероприятие', 'при'],
#  ['генерал лейтенант', 'лейтенант', 'генерал', 'большевик', 'красных'],
#  ['арктика', 'нефть', 'добыча', 'месторождение', 'сибирь'],
#  ['фильм', 'кино', 'студия', 'продюсер', 'куликов'],
#  ['высоцкий', 'владимир высоцкий', 'книга', 'дядя', 'достоевский'],
#  ['воробьев', 'губернатор', 'благоустройство', 'андрей', 'здравоохранение'],
#  ['табаков', 'священник', 'воля', 'рпц', 'спектакль'],
#  ['книга', 'метр', 'андрей', 'редактор', 'автор'],
#  ['продукция', 'предприятие', 'производство', 'год', 'вертолёт'],
#  ['компания', 'стенд', 'выставка', 'макет', 'стенд компания'],
#  ['ес', 'саммит', 'конституция', 'виза', 'ряд вопрос'],
#  ['цик', 'недоверие', 'состав', 'лидер', 'украина'],
#  ['герой', 'антиутопия', 'книга', 'автор', 'мария'],
#  ['болгария', 'патриарх', 'кирилл', 'патриарх кирилл', 'передача'],
#  ['конкурс', 'опера', 'театр', 'солист', 'песня'],
#  ['иск', 'арбитраж', 'суд', 'инвестор', 'юкос'],
#  ['преступность', 'прокуратура', 'депутат', 'республика', 'служба'],
#  ['инстинкт', 'журналистка', 'домогательство', 'чемпионат', 'депутат'],
#  ['доход', 'доход население', 'год доход', 'уровень год', 'население'],
#  ['япония', 'компания', 'сотрудничество', 'газа', 'проект'],
#  ['сирия', 'сила', 'россия', 'средство поражение', 'возможность'],
#  ['газопровод', 'катар', 'сирия', 'турция', 'газа'],
#  ['еаэс', 'соглашение', 'цепочка', 'услуга', 'страна'],
#  ['кино', 'зритель', 'театр', 'аудитория', 'бутусов'],
#  ['апелляция', 'защита', 'минобрнаука', 'диссертация', 'диплом'],
#  ['дамаск', 'сирия', 'ополчение', 'вашингтон', 'формирование'],
#  ['росатом', 'ветроэнергетика', 'энергетика', 'строительство', 'мощность'],
#  ['греция', 'рынок', 'еврозона', 'инвестор', 'китай'],
#  ['философия', 'революция', 'николай', 'философ', 'учение'],
#  ['декрет', 'лукашенко', 'экономика', 'белоруссия', 'министерство'],
#  ['клетка', 'железо', 'процесс', 'пастер', 'испытание'],
#  ['ветеран', 'фонд', 'память', 'поколение', 'россия организация'],
#  ['таня', 'бек', 'литература', 'татьяна бек', 'встреча'],
#  ['аэс', 'реактор', 'мощность', 'энергоблок', 'авария'],
#  ['ливан', 'большинство', 'оппозиция', 'коалиция', 'мишель'],
#  ['ислам', 'мусульманин', 'азия', 'узбекистан', 'кавказ'],
#  ['григорий', 'философ культуролог', 'эссеист', 'писатель философ', 'рая'],
#  ['саакашвили', 'киев', 'украина', 'суд', 'заседание'],
#  ['человек', 'молодая человек', 'молодая', 'церковь', 'ребёнок'],
#  ['чечня', 'комиссар', 'томас', 'правозащитник', 'человек'],
#  ['медведь', 'арктика', 'слон', 'абхазия', 'флаг'],
#  ['приднестровье', 'молдавия', 'украина', 'кишинев', 'молдова'],
#  ['книга', 'сборник', 'чтение', 'книжка', 'память'],
#  ['сурайкин', 'бабурин', 'павел', 'грудинин', 'выбор'],
#  ['пресса', 'журналист', 'азербайджан', 'баку', 'нападение'],
#  ['преступление', 'раскрытие', 'скрипаль', 'отравление', 'юрист'],
#  ['митинг', 'шествие', 'немцов', 'борис немцов', 'оргкомитет'],
#  ['монархия', 'фантастика', 'империя', 'фантаст', 'историк'],
#  ['швейцария', 'вто', 'йозеф', 'россия вто', 'инвестиция'],
#  ['конфликт', 'вооружение', 'противостояние', 'сша', 'война'],
#  ['роман', 'критика', 'критик', 'литература', 'суждение'],
#  ['эйзенштейн', 'фильм', 'мексика', 'режиссёр', 'оттенок'],
#  ['русало', 'технология', 'экология', 'производство', 'предприятие'],
#  ['демография', 'сфера', 'парламентарий', 'путин', 'палата'],
#  ['танк', 'израиль', 'защита', 'бронетехника', 'ракета'],
#  ['байкал', 'приток', 'осадка', 'осадок', 'куб'],
#  ['происшествие', 'школа', 'ученик школа', 'пистолет', 'пострадавший'],
#  ['русало', 'технология', 'экология', 'производство', 'предприятие'],
#  ['сирия', 'авиация', 'ракета', 'самолёт', 'путин'],
#  ['конкурс', 'лифт', 'тысяча', 'победитель', 'участник'],
#  ['путин', 'развитие страна', 'допуск', 'предложение', 'программа'],
#  ['арктика', 'нефть', 'платформа', 'шельф', 'добыча'],
#  ['секунда', 'эфир', 'программа', 'время', 'телевидение'],
#  ['год дата', 'тэс', 'постановление правительство', 'мощность мвт', 'тасс'],
#  ['губернатор', 'коллега', 'богдан', 'энтузиаст', 'династия'],
#  ['посол', 'рен', 'финляндия', 'рабочий', 'рабочий день'],
#  ['строительство', 'заповедник', 'сочи', 'трасса', 'игра'],
#  ['муфтий', 'мусульманин', 'деятель', 'автор', 'ислам'],
#  ['парк', 'билет', 'посетитель', 'фонтан', 'матч'],
#  ['контингент', 'операция', 'конфликт', 'украина', 'резолюция'],
#  ['литва', 'область', 'ес', 'проблема', 'рф'],
#  ['жюри', 'приз', 'награда', 'фильм', 'берлинал'],
#  ['мелочь', 'кот', 'шляпа', 'сквер', 'кинотеатр'],
#  ['гудков', 'кандидат', 'мэр', 'явлинский', 'праймериза'],
#  ['ввст', 'оружие', 'экспорт', 'китай', 'рынок'],
#  ['льюис', 'андерсон', 'нить', 'режиссёр', 'герой'],
#  ['герр', 'ренэ', 'ренэ герр', 'романов', 'художник'],
#  ['фильм', 'роберт', 'женщина', 'мужчина', 'жена'],
#  ['конгрегация', 'папа', 'франциск', 'богослужение', 'епископ'],
#  ['поезд', 'вагон', 'старушка', 'степь', 'коран'],
#  ['худрук', 'театр', 'директор', 'миллион рубль', 'платформа'],
#  ['рождаемость', 'интернет', 'секс', 'россиянин', 'автомобиль'],
#  ['турция', 'анкара', 'политика', 'идеология', 'доктрина'],
#  ['скульптура', 'коллекция', 'картина', 'портрет', 'год состояние'],
#  ['ас сися', 'сися', 'ас', 'египет', 'египтянин'],
#  ['собчак', 'пожар', 'дом', 'волгоград', 'чп'],
#  ['помпео', 'трамп', 'тиллерсон', 'госсекретарь', 'цру'],
#  ['путин', 'разделение власть', 'разделение', 'власть', 'россия'],
#  ['путь сообщение', 'воспоминание', 'дума', 'костюм', 'сообщение'],
#  ['обращение', 'закон', 'животное', 'лишение свобода', 'лишение'],
#  ['чехов', 'ольга', 'сказка', 'картина мир', 'вод'],
#  ['стих', 'тишина', 'рассказ', 'ян', 'буним'],
#  ['пласт', 'скважина', 'нефть', 'трещина', 'добыча'],
#  ['ребёнок', 'родитель', 'класс', 'школа', 'образование'],
#  ['соль', 'яд', 'минздрав', 'алкоголь', 'критерий'],
#  ['поезд', 'километр', 'час', 'китай', 'скорость'],
#  ['грузия', 'ответственность', 'кооперация', 'оппозиция власть', 'москва'],
#  ['япония', 'остров', 'путин', 'токио', 'переговоры'],
#  ['вод', 'очистка', 'вода', 'завод', 'система'],
#  ['русь', 'карьер', 'жизнь', 'вера', 'сердце'],
#  ['дурак', 'платон', 'монумент', 'жена', 'толерантность'],
#  ['камень', 'башня', 'кусок', 'берег', 'пруд'],
#  ['закон', 'агрессия', 'украина', 'оон', 'объявление'],
#  ['вздох', 'бабушка', 'покупка', 'дедушка', 'мама'],
#  ['вто',
#   'азербайджан',
#   'руководство республика',
#   'переговоры страна',
#   'замглавы мид'],
#  ['эстония', 'латвия', 'убыток', 'оккупация', 'ущерб'],
#  ['людвиг', 'музей', 'поп', 'выставка', 'арт'],
#  ['росатом', 'закупка', 'поставщик', 'корпорация', 'госкорпорация'],
#  ['экзамен', 'законопроект', 'уровень подготовка', 'крым', 'форма'],
#  ['мо', 'управление', 'закупка', 'пентагон', 'приобретение'],
#  ['аравия', 'бен', 'трамп', 'сша', 'катар'],
#  ['успех', 'достижение', 'власть', 'патриотизм', 'культура'],
#  ['премия', 'ярмарка', 'лауреат', 'поэт', 'поэзия'],
#  ['автомобиль', 'актор', 'человек', 'водитель', 'телефон'],
#  ['заболевание', 'лечение', 'воздух', 'препарат', 'пыль'],
#  ['фильм', 'герой', 'рыцарь', 'кубок', 'девушка'],
#  ['квт час', 'квт', 'декабрь год', 'электроэнергия', 'год'],
#  ['ракета', 'комплекс', 'испытание', 'боев', 'полёт'],
#  ['соловьев', 'академия', 'студент', 'увольнение', 'ректор'],
#  ['операция', 'сила операция', 'израиль', 'крым', 'спецназ'],
#  ['миллиард', 'ук', 'рубль', 'миллиард рубль', 'операция'],
#  ['гонка', 'пилот', 'лада', 'трасса', 'машина'],
#  ['занятость', 'работник', 'труд', 'группа', 'человек'],
#  ['патрик', 'ирландия', 'день', 'символ', 'пиво'],
#  ['семинар', 'экскурсия', 'мастер класс', 'антология', 'знакомство'],
#  ['вр', 'газа', 'утилизация', 'факел', 'газ'],
#  ['дамаск', 'сирия', 'ополчение', 'вашингтон', 'формирование'],
#  ['взрыв', 'индонезия', 'теракт', 'остров', 'австралиец'],
#  ['хокинг', 'стивен', 'год', 'стивен хокинг', 'дыра'],
#  ['знание', 'реальность', 'познание', 'будущее', 'развитие'],
#  ['берег', 'евфрат', 'форсирование', 'плацдарм', 'река'],
#  ['церковь', 'албания', 'католик', 'религия', 'собор'],
#  ['сон', 'фаза', 'цикл', 'минута', 'человек'],
#  ['музей', 'церемония', 'выставка', 'искусство', 'основатель'],
#  ['скора', 'бригада', 'скора помощь', 'вызов', 'станция'],
#  ['беспилотник', 'компания', 'аппарат', 'система', 'макет'],
#  ['книга', 'физик', 'теоретик', 'расстрел', 'теория'],
#  ['бундестаг', 'коалиция', 'договор', 'социал демократ', 'социал'],
#  ['приднестровье', 'кишинев', 'тирасполь', 'ес', 'додон'],
#  ['вагон', 'рельс', 'дорога', 'паровоз', 'поезд'],
#  ['пхеньян', 'кндр', 'диалог', 'корея', 'ким'],
#  ['сталин', 'народ', 'немец', 'депортация', 'чеченец'],
#  ['мост', 'уголь', 'хакасия', 'строительство', 'месторождение'],
#  ['греция', 'референдум', 'ципраса', 'бундестаг', 'евро'],
#  ['судья', 'стража', 'жалоба', 'следователь', 'арест'],
#  ['фильм', 'священник', 'клуб', 'драма', 'мальчик'],
#  ['ким', 'чен', 'ким чен', 'кндр', 'праздник'],
#  ['таджикистан', 'свобода', 'душанбе', 'группировка государство', 'иго рф'],
#  ['доход', 'теория', 'цена нефть', 'бюджет', 'расход'],
#  ['новичок', 'солсбери', 'рф', 'мид', 'яд'],
#  ['вода', 'плотность', 'луч', 'вод', 'электрон'],
#  ['герр', 'ренэ', 'ренэ герр', 'романов', 'художник'],
#  ['мид', 'англичанин', 'шеф', 'посольство', 'кгб'],
#  ['греция', 'кредитор', 'афина', 'дефолт', 'саммит'],
#  ['горький', 'фабрика', 'роман', 'дело', 'крестьянин'],
#  ['миллион том', 'год', 'том', 'уголь', 'добыча'],
#  ['иван', 'аргентина', 'храм', 'фонд', 'священнослужитель'],
#  ['фильм', 'теракт', 'бекмамбетов', 'героиня', 'профиль'],
#  ['выплата', 'доход', 'январь', 'январь год', 'год выплата'],
#  ['арктика', 'ледокол', 'музей', 'петербург', 'утилизация'],
#  ['афганистан', 'азия', 'иго', 'боевик', 'сирия'],
#  ['туркменистан', 'сын', 'преемник', 'выбор', 'нурсултан'],
#  ['конференция', 'мюнхен', 'встреча', 'вольфганг', 'франция германия'],
#  ['рада', 'депутат', 'генпрокуратура', 'генпрокурор', 'теракт'],
#  ['израиль', 'удар', 'пво', 'сирия', 'ракета'],
#  ['истребитель', 'самолёт', 'сирия', 'воздух', 'ракета'],
#  ['горький', 'максим', 'писатель', 'никитин', 'алексей'],
#  ['фильм', 'женщина', 'режиссёр', 'комедия', 'приз'],
#  ['инстинкт', 'журналистка', 'домогательство', 'чемпионат', 'депутат'],
#  ['любовь', 'измена', 'секс', 'женщина', 'культ'],
#  ['луиджи', 'ричард', 'друг', 'пощёчина', 'друг друг'],
#  ['религия', 'основоположник', 'проповедь', 'жизнь', 'автор'],
#  ['интернет', 'политика', 'кампания', 'интернетом', 'тв'],
#  ['германия', 'газета', 'социал', 'социал демократ', 'пресса'],
#  ['марс', 'компания', 'маска', 'маск', 'заказ'],
#  ['наблюдение', 'зона', 'застройка', 'суд', 'анастасий'],
#  ['эстония', 'церковь', 'сотрудничество', 'традиция', 'совет'],
#  ['экономика', 'топливо', 'ископаемое', 'ратификация', 'соглашение'],
#  ['терроризм', 'совет безопасность', 'оон', 'совет', 'резолюция'],
#  ['экипаж', 'лайнер', 'самолёт', 'заход', 'высота'],
#  ['газопровод', 'газпром', 'миллиард куб', 'куб метр', 'куб'],
#  ['пацан', 'депутат', 'дума', 'время', 'ночь'],
#  ['оао', 'чаша', 'кузнецов', 'факел', 'игра'],
#  ['ципраса', 'брюссель', 'евро', 'миллиард евро', 'миллиард'],
#  ['алюминий', 'русало', 'металл', 'отход', 'производство'],
#  ['патрик', 'ирландия', 'день', 'символ', 'пиво'],
#  ['ес', 'вопрос', 'германия', 'реформа', 'саммит'],
#  ['спортсмен', 'символика', 'эмират', 'тренер', 'крокодил'],
#  ['сирия', 'су', 'самолёт', 'военный', 'турция'],
#  ['доллар', 'наряд', 'тысяча доллар', 'торг', 'коллекция'],
#  ['концерт', 'горбунов', 'билет', 'артист', 'музыкант'],
#  ['долг', 'рубль', 'жкх', 'услуга', 'задолженность'],
#  ['олимпиада', 'игра', 'церемония закрытие', 'закрытие', 'сочи'],
#  ['клетка', 'кожа', 'частица', 'ген', 'слой'],
#  ['редактор', 'писатель', 'наука', 'литература', 'слово'],
#  ['показатель', 'страна', 'земеля', 'хозяйство', 'природа'],
#  ['пакистан', 'вопрос борьба', 'мухаммад', 'рф страна', 'год участие'],
#  ['оон', 'грузия', 'абхазия', 'тбилиси', 'конфликт'],
#  ['академик', 'наука', 'комиссия', 'господин', 'дисциплина'],
#  ['дед', 'жидкость', 'ося', 'баба', 'аппарат'],
#  ['молодёжь', 'год', 'лифт', 'активность', 'молодая'],
#  ['партия', 'яблоко', 'женщина', 'год', 'явлинский'],
#  ['крокодил', 'отдых', 'боль', 'бассейн', 'место отдых'],
#  ['отель', 'турист', 'колледж', 'заведение', 'россиянин'],
#  ['гонка', 'пилот', 'феттель', 'росберг', 'мексика'],
#  ['поезд', 'дорога', 'витта', 'система', 'царь'],
#  ['мост', 'уголь', 'хакасия', 'строительство', 'месторождение'],
#  ['аэс', 'потребитель', 'мощность', 'энергоблок', 'цена'],
#  ['экипаж', 'полёт', 'самолёт', 'высота', 'сирия'],
#  ['минздрав', 'пункт', 'помощь', 'численность', 'росстат'],
#  ['красота', 'конкурс', 'войско', 'бал', 'обеспечение военный'],
#  ['солсбери', 'отравление', 'россия', 'мотив', 'дочь'],
#  ['папа', 'церковь', 'кардинал', 'сериал', 'бог'],
#  ['горький', 'фабрика', 'роман', 'дело', 'крестьянин'],
#  ['зарплата', 'тысяча рубль', 'тысяча', 'рубль', 'вознаграждение'],
#  ['композиция', 'авиакатастрофа', 'самолёт', 'дубай', 'борт человек'],
#  ['остров', 'япония', 'деятельность', 'токио', 'деятельность остров'],
#  ['гудков', 'кандидат', 'мэр', 'явлинский', 'праймериза'],
#  ['гражданин россия', 'паспорт', 'лишение', 'крым', 'проверка'],
#  ['выставка', 'ветроэнергетика', 'компания', 'мощность', 'рынок'],
#  ['луиджи', 'ричард', 'друг', 'пощёчина', 'друг друг'],
#  ['девочка', 'мама', 'бабушка', 'нога', 'школа'],
#  ['книжка', 'похороны', 'том', 'жуть', 'пора год'],
#  ['тайвань', 'китай', 'си', 'авианосец', 'пекин'],
#  ['подразделение', 'войско', 'сша', 'противник', 'боев'],
#  ['механик', 'командир', 'корабль', 'дивизия', 'химик'],
#  ['гражданство', 'паспорт', 'крым', 'беженец', 'рф'],
#  ['металл', 'реактор', 'изделие', 'завод', 'продукция'],
#  ['сухогруз', 'экипаж', 'член экипаж', 'шторм', 'мчс'],
#  ['кпрф', 'новосибирск', 'депутат', 'ер', 'партия'],
#  ['патриарх', 'болгария', 'кирилл', 'патриарх кирилл', 'март'],
#  ['япония', 'остров', 'путин', 'токио', 'переговоры'],
#  ['возраст', 'утрата', 'цифровизация', 'численность', 'соловьев'],
#  ['киргизия', 'ислам', 'джихад', 'посол', 'клан'],
#  ['проект', 'тонна', 'выброс', 'сбербанк', 'сокращение выброс'],
#  ['община', 'молодёжь', 'еврей', 'раввин', 'документ'],
#  ['км', 'скорость', 'дорога', 'автомобилист', 'стоянка'],
#  ['россия', 'партия', 'депутат', 'накопление', 'госдума'],
#  ['врач', 'грант', 'поликлиника', 'рубль', 'пациент'],
#  ['ходорковский', 'путин', 'экс глава', 'юкос', 'экс'],
#  ['поэт', 'клуб', 'писатель', 'выставка', 'член клуб'],
#  ['малыш', 'кафе', 'луч', 'бар', 'мясо'],
#  ['сирия', 'гута', 'дамаск', 'оон', 'резолюция'],
#  ['послание', 'год', 'зарплата', 'экономист', 'ввп'],
#  ['тэк', 'прогноз', 'экономика', 'рынок', 'ввп'],
#  ['греция', 'еврозона', 'предложение', 'выход греция', 'референдум'],
#  ['потепление',
#   'побережье',
#   'страна тысяча',
#   'потепление климат',
#   'страна страна'],
#  ['поэт', 'клуб', 'писатель', 'выставка', 'член клуб'],
#  ['гута', 'оружие', 'начальник генштаб', 'генерал армия', 'женщина ребёнок'],
#  ['водохранилище', 'переброска', 'вода', 'бассейн', 'река'],
#  ['преступление', 'раскрытие', 'скрипаль', 'отравление', 'юрист'],
#  ['рота', 'оборона', 'работа военный', 'гагарин', 'конец лето'],
#  ['скора', 'скора помощь', 'бригада', 'станция', 'помощь'],
#  ['при', 'гран при', 'гран', 'команда', 'пилот'],
#  ['поезд', 'дорога', 'витта', 'система', 'царь'],
#  ['повесть', 'рыбка', 'дрова', 'тоска', 'одиночество'],
#  ['экология', 'русало', 'экомарафон', 'волна', 'дерево'],
#  ['сирия', 'сша', 'курд', 'армия', 'турция'],
#  ['ар', 'вячеслав', 'слово', 'стих', 'ангел'],
#  ['сериал', 'команда', 'актёр', 'презентация', 'космонавт'],
#  ['наблюдатель', 'организация', 'индия пакистан', 'конфликт', 'саммит'],
#  ['каток', 'лёд', 'вднх', 'сокольник', 'парка'],
#  ['самолёт', 'энергия', 'здание', 'энергетика', 'батарея'],
#  ['заседание правительство',
#   'программа сотрудничество',
#   'сотрудничество',
#   'средство развитие',
#   'год премьер'],
#  ['монголия', 'гэс', 'байкал', 'проект', 'строительство гэс'],
#  ['прокуратура', 'жалоба', 'обращение', 'количество', 'прокурор'],
#  ['рейтинг', 'работодатель', 'росатом', 'компания', 'госкорпорация'],
#  ['молекула', 'изображение', 'метод', 'премия', 'год'],
#  ['робот', 'интеллект', 'система', 'человек', 'машина'],
#  ['приднестровье', 'ес', 'страна союз', 'продукция', 'молдавия'],
#  ['университет', 'рейтинг', 'вуз', 'добыча ископаемое', 'предмет'],
#  ['команда', 'гонка', 'фунт', 'менеджмент', 'чемпионат'],
#  ['команда', 'сезон', 'себастьен', 'беннаня', 'медь беннаня'],
#  ['эволюция', 'доклад', 'музей', 'летие день', 'муха'],
#  ['казань', 'аэропорт', 'самолёт', 'татарстан', 'посадка'],
#  ['явлинский', 'украина', 'партия яблоко', 'псков', 'представитель рф'],
#  ['би', 'отравление солсбери', 'путин вопрос', 'джереми', 'политика дело'],
#  ['резолюция', 'расследование', 'сирия', 'оон', 'право человек'],
#  ['манёвр', 'бюджет', 'пошлина', 'налог', 'администрирование'],
#  ['табаков', 'священник', 'воля', 'рпц', 'спектакль'],
#  ['протест', 'акция', 'инаугурация', 'оппозиция', 'май'],
#  ['гута', 'асад', 'удар', 'сша', 'дейр эз'],
#  ['поставка', 'экспорт', 'нефть', 'танкер', 'газа'],
#  ['гонка', 'машина', 'нико', 'болид', 'финиш'],
#  ['коронель', 'квалификация', 'сегмент', 'пилот', 'себастьен'],
#  ['цена', 'молдавия', 'газпром', 'газ', 'тысяча куб'],
#  ['брат мусульманин', 'брат', 'мусульманин', 'группировка', 'египет'],
#  ['поэзия', 'поэт', 'стих', 'рифма', 'эхо'],
#  ['газпром', 'транзит', 'газа', 'коммерсант', 'кубометр'],
#  ['ас сися', 'сися', 'ас', 'египет', 'египтянин'],
#  ['список', 'санкция', 'грузия', 'тбилиси', 'документ'],
#  ['дебаты', 'собчак', 'грудинин', 'жириновский', 'электорат'],
#  ['лёд', 'фильм', 'песня', 'петров', 'спорт'],
#  ['байкал', 'мусор', 'фильм', 'экология', 'красноярск'],
#  ['пилот', 'болид', 'квалификация', 'трасса', 'баттон'],
#  ['человек', 'молодая человек', 'молодая', 'церковь', 'ребёнок'],
#  ['мемуарист', 'мемуары', 'литератор', 'повествование', 'поэт'],
#  ['санкция', 'лавров', 'оружие', 'дезинформация', 'россия'],
#  ['законопроект', 'украина', 'киев', 'принятие закон', 'принятие'],
#  ['фильм', 'зайцев', 'пионер', 'герой', 'режиссёр'],
#  ['новичок', 'солсбери', 'рф', 'мид', 'яд'],
#  ['ввст', 'оружие', 'экспорт', 'китай', 'рынок'],
#  ['стих', 'проза', 'бутусов', 'интервью', 'текст'],
#  ['квалификация', 'пилот', 'штраф', 'ситроен', 'заезд'],
#  ['троцкий', 'ленин', 'революция', 'лариса', 'теория'],
#  ['аэрофлот', 'смерть', 'адвокат', 'хищение', 'год суд'],
#  ['лужники', 'посетитель', 'система', 'болельщик', 'стадион'],
#  ['олег', 'корабль', 'византия', 'колесо', 'история'],
#  ['аэропорт', 'посёлок', 'полоса', 'падение', 'авиакатастрофа'],
#  ['грузия', 'вредитель', 'фермер', 'крестьянин', 'лесна'],
#  ['нико', 'себастьян', 'болид', 'сегмент', 'двигатель'],
#  ['доллар', 'наряд', 'тысяча доллар', 'торг', 'коллекция'],
#  ['название', 'оружие', 'ракета', 'вид', 'наименование'],
#  ['выброс', 'выброс газ', 'газ', 'уровень выброс', 'развитие'],
#  ['абхазия', 'грузия', 'осетия', 'абхазия осетия', 'мид'],
#  ['буш', 'аль', 'ирак', 'угроза', 'бен'],
#  ['чечня', 'кадыров', 'обращение', 'ахмед', 'правозащитник'],
#  ['гранат', 'селение', 'мина', 'выстрел', 'рустам'],
#  ['культура', 'книга', 'вольф', 'призрак', 'прочтение'],
#  ['книга', 'любовь', 'шкаф', 'ряд причина', 'герой книга'],
#  ['операция', 'сила операция', 'израиль', 'крым', 'спецназ'],
#  ['поликлиника', 'врач', 'пациент', 'емиас', 'приём'],
#  ['дельфин', 'остров', 'тамара', 'племя', 'ребёнок'],
#  ['серов',
#   'мощность',
#   'премьер правительство',
#   'отключение',
#   'электростанция'],
#  ['гэс', 'монголия', 'байкал', 'река', 'экосистема'],
#  ['гражданство', 'доклад', 'мигрант', 'правозащитник', 'право'],
#  ['пошлина', 'товар', 'импорт', 'сша', 'введение'],
#  ['порошенко', 'украина', 'ар', 'татарин', 'мусульманин'],
#  ['ливия', 'кампания', 'миллион евро', 'евро', 'париж'],
#  ['сердце', 'спортсмен', 'остановка', 'обследование', 'пол'],
#  ['переселенец', 'соотечественник', 'программа', 'переселение', 'миграция'],
#  ['поезд', 'дорога', 'витта', 'система', 'царь'],
#  ['аль', 'фракция', 'ан нуср', 'нуср', 'ан'],
#  ['роба', 'лада', 'чилтон', 'хафф', 'гонка'],
#  ['экономика', 'технология', 'закон', 'транзакция', 'толкование'],
#  ['спектакль', 'театр', 'алексей', 'галина', 'пётр'],
#  ['компания', 'стенд', 'выставка', 'макет', 'стенд компания'],
#  ['фабрика', 'индустрия', 'производство', 'технология', 'экономика'],
#  ['дежурство', 'ракета', 'комплекс', 'минобороны', 'истребитель'],
#  ['леди', 'фильм', 'режиссёр', 'номинация', 'актриса'],
#  ['клуб', 'член клуб', 'бизнес', 'член', 'бизнесмен'],
#  ['дивизия', 'войско', 'американец', 'корея', 'оон'],
#  ['театр', 'табаков', 'режиссёр', 'спектакль', 'преемник'],
#  ['конкурс', 'лифт', 'тысяча', 'победитель', 'участник'],
#  ['помпео', 'мусульманин', 'назначение', 'джина', 'майк'],
#  ['собчак', 'путин', 'кандидат', 'неделя', 'кампания'],
#  ['геном', 'ген', 'мозг', 'африка', 'человек'],
#  ['прошение', 'ходатайство', 'служба безопасность', 'экс глава', 'юкос'],
#  ['надпись', 'лёд', 'фонтанка', 'агитация', 'избирком'],
#  ['бизнес', 'ребёнок', 'предприниматель', 'проект', 'предпринимательство'],
#  ['разведчик', 'книга', 'молодая гвардия', 'спецслужба', 'герой'],
#  ['сон', 'фаза', 'цикл', 'минута', 'человек'],
#  ['революция', 'социализм', 'маркс', 'теория', 'мышление'],
#  ['питание', 'сочи', 'продукт', 'спортсмен', 'тысяча'],
#  ['катание', 'канада', 'сочи', 'победа', 'чемпион'],
#  ['миллиард человек', 'вымирание', 'миллион', 'площадь', 'миллиард'],
#  ['аппарат', 'полёт', 'беспилотник', 'система', 'килограмм'],
#  ['фильм', 'герой', 'спектакль', 'роль', 'репортёр'],
#  ['глеб', 'дом', 'окно', 'наталья', 'день'],
#  ['госдума',
#   'лидер лдпр',
#   'выборы госдума',
#   'лдпр владимир',
#   'возможность создание'],
#  ['нато', 'королевство', 'британия', 'отравление', 'вещество'],
#  ['аль', 'список', 'хезболл', 'организация', 'каида'],
#  ['чемпионат', 'автомобиль', 'команда', 'производитель', 'регламент'],
#  ['турция', 'вашингтон', 'анкара', 'отношение', 'вооружение'],
#  ['аппарат', 'система', 'беспилотник', 'камера', 'сша'],
#  ['греция', 'церковь', 'ес', 'грек', 'албания'],
#  ['афганистан', 'кабул', 'группировка', 'провинция', 'атака'],
#  ['отец', 'василий', 'княжество', 'престол', 'листок'],
#  ['километр', 'трасса', 'река', 'дорога', 'дорога инфраструктура'],
#  ['африна', 'агентство', 'террорист', 'город', 'турция'],
#  ['строительство', 'сочи', 'график', 'объект', 'проектирование'],
#  ['язык', 'место', 'парламент', 'квота', 'пресс конференция'],
#  ['повестка', 'путин', 'меньшинство', 'отставание', 'выбор'],
#  ['соревнование', 'спорт', 'спортсмен', 'тренер', 'дистанция'],
#  ['юкос', 'хищение', 'расследование дело', 'актив', 'расследование'],
#  ['вднх', 'павильон', 'выставка', 'парк', 'модернизация'],
#  ['регулирование', 'выброс', 'квота', 'налог', 'рынок'],
#  ['банка', 'год сумма', 'дмитрий козак', 'год счёт', 'сторона соглашение'],
#  ['надпись', 'лёд', 'фонтанка', 'агитация', 'избирком'],
#  ['аэропорт',
#   'самолёт',
#   'ссылка представитель',
#   'самолёт авиакомпания',
#   'авиакомпания'],
#  ['снег', 'столица', 'площадь территория', 'осадок', 'коллапс'],
#  ['сирия', 'группировка', 'анкара', 'иерусалим', 'дамаск'],
#  ['коррупция',
#   'противодействие коррупция',
#   'образование',
#   'противодействие',
#   'вуз'],
#  ['нии', 'препарат', 'коммерсант', 'завод', 'яхта'],
#  ['ребёнок', 'лужники', 'площадка', 'взрослый', 'сад'],
#  ['ренэ', 'ренэ герр', 'герр', 'эссе', 'метр'],
#  ['оркестр', 'фестиваль', 'хор', 'март апрель', 'вена'],
#  ['человек', 'эволюция', 'ген', 'мозг', 'сантиметр'],
#  ['высоцкий', 'рассказ', 'поп', 'канал', 'еврей'],
#  ['цру', 'пытка', 'джина', 'тюрьма', 'директор цру'],
#  ['яблоко', 'отделение', 'владивосток', 'партия', 'конференция'],
#  ['мобилизация', 'явка', 'коллектив', 'рекомендация', 'избиратель'],
#  ['сталин', 'народ', 'немец', 'депортация', 'чеченец'],
#  ['путин', 'президент', 'интервью', 'высказывание', 'колядина'],
#  ['рейтинг', 'работодатель', 'росатом', 'индекс', 'госкорпорация'],
#  ['росатом', 'аэс', 'энергоблок', 'реактор', 'госкорпорация'],
#  ['конкурс', 'грант', 'администрация президент', 'миллион рубль', 'опыт'],
#  ['фонд', 'инвестор', 'рынок', 'цена', 'стратегия'],
#  ['прокурор', 'закон', 'раскрытие', 'личность', 'корреспондент'],
#  ['мечеть', 'поджог', 'германия', 'турция', 'африна'],
#  ['маяковский', 'стих', 'стихотворение', 'книга', 'поэт'],
#  ['донбасс', 'украина', 'волкер', 'закон', 'агрессор'],
#  ['узбекистан', 'киргизия', 'ташкент', 'таджикистан', 'гэс'],
#  ['доход', 'зарплата', 'доход население', 'регион', 'рост'],
#  ['наталья', 'книга', 'поляков', 'стихотворение', 'типография'],
#  ['озеро байкал', 'байкал', 'озеро', 'зона', 'район'],
#  ['греция', 'пожар', 'район', 'огонь', 'вертолёт'],
#  ['крушение', 'самолёт', 'обломок', 'борт человек', 'домодедово'],
#  ['якутия', 'восстание', 'книга', 'сибирь', 'леонид'],
#  ['год список', 'гонка сезон', 'сезон год', 'автоспорт', 'расписание'],
#  ['маска', 'спектакль', 'показ', 'кинотеатр', 'номинант'],
#  ['наводнение', 'рейн', 'ливень', 'вода', 'дождь'],
#  ['бомбардировщик', 'удар', 'военный', 'авиация', 'латакия'],
#  ['победа', 'путин', 'россия', 'владимир путин', 'партия'],
#  ['кандидат', 'церковь', 'выборы', 'священнослужитель', 'агитация'],
#  ['гостиница', 'отель', 'компания', 'врио', 'андрей'],
#  ['ячейка', 'электричество', 'энергия', 'источник энергия', 'технология'],
#  ['финал', 'здравоохранение', 'олег', 'конкурс', 'министр здравоохранение'],
#  ['байкал', 'вклад', 'туризм', 'китаец', 'турист'],
#  ['сирия', 'асад', 'сша', 'режим асад', 'территория'],
#  ['партия', 'налогоплательщик', 'организация', 'минюст', 'год'],
#  ['миллион', 'том', 'миллион том', 'миллиард человек', 'вымирание'],
#  ['театр', 'псков', 'спектакль', 'фестиваль', 'режиссёр'],
#  ['пилот', 'трасса', 'болид', 'сессия', 'заезд'],
#  ['квалификация', 'пилот', 'авария', 'сочи автодром', 'данил'],
#  ['пилот', 'туринг', 'заезд', 'иван мюллер', 'роба'],
#  ['меркель', 'канцлер', 'берлин', 'ес', 'ведомство'],
#  ['алюминий', 'потребление', 'тысяча том', 'том', 'ассоциация'],
#  ['номинация', 'церемония', 'актриса', 'премия', 'битва'],
#  ['река', 'гора', 'везение', 'свод', 'лесна'],
#  ['здравоохранение', 'доклад', 'услуга', 'помощь', 'расход'],
#  ['горожанин', 'парка', 'город', 'парк', 'мегаполис'],
#  ['знание', 'образование', 'компетенция', 'технология', 'навык'],
#  ['гонка', 'команда', 'трасса', 'кара', 'заезд'],
#  ['ночлежка', 'квартира', 'клиент', 'рыбка', 'ребёнок'],
#  ['алюминий', 'производство', 'выброс', 'производство алюминий', 'экология'],
#  ['мо', 'управление', 'закупка', 'пентагон', 'приобретение'],
#  ['гонка', 'трасса', 'беннаня', 'джеймс', 'пилот'],
#  ['жуков', 'вто', 'экономика', 'вступление', 'вице премьер'],
#  ['огонь', 'чудо', 'пасха', 'гроб', 'обряд'],
#  ['вто', 'пошлина', 'швеция', 'древесина', 'финляндия'],
#  ['сердце', 'спортсмен', 'остановка', 'обследование', 'пол'],
#  ['ввс', 'ввс сша', 'космос', 'миллиард доллар', 'сша'],
#  ['газа', 'куб метр', 'куб', 'миллиард куб', 'газопровод'],
#  ['конструктор', 'испытание', 'коллектив', 'вооружение', 'ввст'],
#  ['газпром', 'тимошенко', 'украина', 'газа', 'лицензия'],
#  ['монархия', 'идея', 'процент', 'правитель', 'никита'],
#  ['женщина', 'сестра', 'мор', 'мужчина', 'право женщина'],
#  ['пыль', 'уголь', 'терминал', 'воздух', 'находка'],
#  ['прокуратура', 'заявление', 'конверт', 'отдел', 'фирма'],
#  ['буш', 'каида', 'аль каида', 'аль', 'сентябрь'],
#  ['теракт', 'комитет', 'поправка', 'комиссаров', 'сми'],
#  ['журнал', 'сатира', 'антология', 'александр', 'василий'],
#  ['интернет', 'телевизор', 'шоу', 'тв', 'ток шоу'],
#  ['россия', 'партия', 'депутат', 'накопление', 'госдума'],
#  ['акт', 'одиночка', 'нападение', 'организация', 'цель'],
#  ['украина', 'донбасс', 'лнр', 'днр лнр', 'днр'],
#  ['сюжет', 'серия', 'смысл', 'повествование', 'шкала'],
#  ['фильм', 'курт', 'история', 'режиссёр', 'экран'],
#  ['приднестровье', 'молдавия', 'кишинев', 'газа', 'поставка'],
#  ['памятник', 'вокзал', 'горький', 'площадь', 'писатель'],
#  ['италия', 'партия', 'ес', 'звезда', 'движение'],
#  ['гонка', 'пилот', 'флаг', 'трасса', 'подиум'],
#  ['музей', 'выставка', 'охота', 'пушкин', 'ружьё'],
#  ['военный', 'россия китай', 'наблюдатель', 'взаимодействие', 'воробьев'],
#  ['музей', 'коллекция', 'искусство', 'собрание', 'выставка'],
#  ['вьетнам', 'молоко', 'воробей', 'концерн', 'маня'],
#  ['оплата', 'карта', 'проезд', 'пассажир', 'автобус'],
#  ['приз', 'фильм', 'кино', 'берлинал', 'картина'],
#  ['аль', 'фракция', 'ан нуср', 'нуср', 'ан'],
#  ['экономика', 'реализация', 'привлечение', 'сектор', 'рост'],
#  ['журнал', 'коллекция', 'обложка', 'выставка', 'панорама'],
#  ['жюля', 'авария', 'француз', 'при', 'гран при'],
#  ['фестиваль', 'варшава', 'анне', 'кристиан', 'музыка'],
#  ['шторм', 'побережье', 'китай', 'синоптик', 'движение направление'],
#  ['мгимо', 'фонд', 'университет', 'выпускник', 'благотворитель'],
#  ['рост', 'манёвр', 'правительство', 'ндс', 'профицит'],
#  ['тайвань', 'китай', 'си', 'авианосец', 'пекин'],
#  ['пропуск', 'охранник', 'машина', 'этаж', 'дед'],
#  ['явка', 'избиратель', 'кандидат', 'выбор', 'кампания'],
#  ['любовь', 'белые', 'стихотворение', 'осень', 'нить'],
#  ['модернизация', 'потребитель', 'оборудование', 'мощность', 'износ'],
#  ['реактор', 'аэс', 'энергетика', 'год', 'страна'],
#  ['фильм', 'тоня', 'драма', 'оскар', 'целое'],
#  ['конкурс', 'компания', 'земеля', 'компенсация', 'дмитрий'],
#  ['папа', 'франциск', 'кардинал', 'епископ', 'ватикан'],
#  ['поэт', 'стихотворение', 'поэзия', 'виктор', 'сборник'],
#  ['сша', 'шпионаж', 'шпион', 'спецслужба', 'контрразведка'],
#  ['вид', 'миллион', 'биосфера', 'биоразнообразие', 'животное'],
#  ['наука', 'рана', 'сергеев', 'академия', 'академия наука'],
#  ['зарплата', 'тысяча рубль', 'тысяча', 'рубль', 'вознаграждение'],
#  ['опека', 'комитет', 'нефтедобыча', 'оман', 'приверженность'],
#  ['автомобиль', 'актор', 'человек', 'водитель', 'телефон'],
#  ['крокодил', 'подполковник', 'товарищ', 'телезритель', 'шапка'],
#  ['фильм', 'кино', 'студия', 'продюсер', 'куликов'],
#  ['байкал', 'гэс', 'озеро', 'вода', 'уровень вода'],
#  ['тысяча рубль', 'рубль', 'издание', 'санкт петербург', 'санкт'],
#  ['сочи', 'премьер', 'путин', 'частное', 'премьер министр'],
#  ['поэзия', 'поэт', 'стих', 'рифма', 'эхо'],
#  ['еврозона', 'греция', 'афина', 'кредитор', 'евро'],
#  ['кислород', 'пространство', 'леса', 'страна', 'территория'],
#  ['пилот', 'гонка', 'команда', 'подиум', 'себастьян'],
#  ['аудитория', 'бренд', 'команда', 'девушка', 'балет'],
#  ['поэт', 'стих', 'поэзия', 'эмигрант', 'тираж'],
#  ['декрет', 'лукашенко', 'экономика', 'белоруссия', 'министерство'],
#  ['ливан', 'наука', 'образование наука', 'наука рф', 'должность'],
#  ['пациент', 'емиас', 'карта', 'здравоохранение', 'внедрение'],
#  ['шура', 'талибан', 'группа', 'афганистан', 'командир'],
#  ['отставка',
#   'отставка президент',
#   'рабочий день',
#   'год лидер',
#   'данные агентство'],
#  ['инфаркт', 'пациент', 'центр', 'помощь', 'сосуд'],
#  ['стандарт', 'васильев', 'ольга', 'источник', 'предмет'],
#  ['отход', 'биомасса', 'год', 'мусор', 'компьютер'],
#  ['луиджи', 'ричард', 'друг', 'пощёчина', 'друг друг'],
#  ['партия', 'человек', 'россия', 'депутат', 'путин'],
#  ['посол', 'сеул', 'размещение', 'кндр', 'россия'],
#  ['партизан', 'немец', 'повстанец', 'италия', 'дождь'],
#  ['прокуратура', 'жалоба', 'обращение', 'количество', 'прокурор'],
#  ['монета', 'кошка', 'клиент', 'перерыв', 'дерево'],
#  ['умберто', 'умберто эко', 'эко', 'литр', 'треугольник'],
#  ['учение', 'каспий', 'снг', 'регион', 'сша'],
#  ['книга', 'женщина', 'фрейд', 'мужчина', 'мужчина женщина'],
#  ['зала', 'честь', 'управление оборона', 'военачальник', 'центр управление'],
#  ['мгимо', 'фонд', 'университет', 'выпускник', 'благотворитель'],
#  ['донбасс', 'миротворец', 'украина', 'волкер', 'киев'],
#  ['грудинин', 'подмосковье', 'кпрф', 'губернатор', 'павел грудинин'],
#  ['арктика', 'доклад', 'изменение климат', 'климат', 'ес'],
#  ['номинация', 'премия', 'философ', 'бердяев', 'награда'],
#  ['премия', 'год', 'летие', 'поэт', 'собака'],
#  ['стих', 'метр', 'польша', 'лауреат', 'поэзия'],
#  ['судан', 'военный', 'область', 'мероприятие', 'область россия'],
#  ['летие', 'игорь', 'северянин', 'поэт', 'елена'],
#  ['грузия', 'осетия', 'переговоры', 'тбилиси', 'женева'],
#  ['жизнь', 'чиновник', 'описание', 'книга', 'александр'],
#  ['озеро байкал', 'байкал', 'озеро', 'зона', 'район'],
#  ['нии', 'аккредитация', 'подготовка', 'экзамен', 'специальность'],
#  ['эйзенштейн', 'архив', 'книга', 'мастер', 'музей'],
#  ['иностранец', 'икра', 'ракета', 'пример', 'жена'],
#  ['юрий', 'писатель', 'милиционер', 'клуб', 'книга'],
#  ['узбекистан', 'парламент', 'соглашение', 'душанбе', 'палата парламент'],
#  ['подписчик', 'рейтинг', 'пост', 'сергей миронов', 'сеть'],
#  ['потепление',
#   'побережье',
#   'страна тысяча',
#   'потепление климат',
#   'страна страна'],
#  ['расход', 'объект', 'сочи', 'козак', 'олимпиада'],
#  ['метр', 'поэт', 'библиотека', 'март', 'др'],
#  ['красота', 'отчаяние', 'порыв', 'кошка', 'глаз'],
#  ['экология', 'русало', 'экомарафон', 'волна', 'дерево'],
#  ['аллюзия', 'детство', 'капитал', 'человек сторона', 'чашка'],
#  ['наталья', 'книга', 'поляков', 'стихотворение', 'типография'],
#  ['маяковский', 'стих', 'стихотворение', 'книга', 'поэт'],
#  ['литвиненко', 'отравление', 'шпион', 'британия', 'покушение'],
#  ['фильм', 'берлинал', 'конкурс', 'фестиваль', 'приз'],
#  ['ирак', 'американец', 'война', 'дивизия', 'сша'],
#  ['грузия', 'мид', 'мид рф', 'рф', 'диалог'],
#  ['повесть', 'писатель', 'роман', 'мальчик', 'автор книга'],
#  ['гостиница', 'отель', 'компания', 'врио', 'андрей'],
#  ['полиция', 'орган', 'корпус', 'партия', 'мвд'],
#  ['стих', 'тишина', 'рассказ', 'ян', 'буним'],
#  ['буш', 'канада', 'саммит', 'мексика', 'встреча'],
#  ['тиллерсон', 'иран', 'трамп', 'сделка', 'отставка'],
#  ['грудинин', 'цик', 'неделя', 'кандидат', 'центризбирком'],
#  ['корабль', 'джон', 'вмс', 'машина', 'ключ'],
#  ['постмодернизм', 'герой', 'мир', 'текст', 'эпоха'],
#  ['еврей', 'священник', 'лагерь', 'смерть', 'миллер'],
#  ['балет', 'танец', 'театр', 'спектакль', 'музыка'],
#  ['польша', 'украина', 'киев', 'решение', 'закон'],
#  ['бумага', 'выпуск', 'миллиард доллар', 'миллиард', 'минфин'],
#  ['договор',
#   'военный назначение',
#   'госдума рф',
#   'развитие сотрудничество',
#   'ратификация'],
#  ['поэт', 'одиночество', 'вагон', 'горький', 'остров'],
#  ['км', 'скорость', 'дорога', 'автомобилист', 'стоянка'],
#  ['раздел', 'сборник', 'палец', 'вспышка', 'стих'],
#  ['команда', 'гонка', 'мерседес', 'феттель', 'сезон'],
#  ['революция', 'социализм', 'маркс', 'теория', 'мышление'],
#  ['яблоко', 'кампания', 'человек', 'партия', 'ложь'],
#  ['петра', 'кремль', 'памятник', 'спортсмен', 'столица'],
#  ['япония', 'партия', 'бизнес', 'страна', 'год'],
#  ['путь сообщение', 'воспоминание', 'дума', 'костюм', 'сообщение'],
#  ['отец', 'василий', 'княжество', 'престол', 'листок'],
#  ['оплата', 'карта', 'проезд', 'пассажир', 'автобус'],
#  ['редактор', 'автор', 'текст', 'редактирование', 'полемика'],
#  ['взрыв', 'милиционер', 'следование', 'автобус', 'мвд'],
#  ['кремль', 'британия', 'движение', 'великобритания', 'бизнесмен'],
#  ['кндр', 'ким', 'корея', 'сша', 'китай'],
#  ['гонка', 'команда', 'алонсо', 'пилот', 'сезон'],
#  ['триллион рубль', 'триллион', 'рубль', 'доля', 'рождаемость'],
#  ['достоевский', 'михайло', 'писатель', 'пётр', 'народ'],
#  ['словарь', 'термин', 'язык', 'понятие', 'наука'],
#  ['помпео', 'трамп', 'тиллерсон', 'госсекретарь', 'цру'],
#  ['финляндия', 'реактор', 'сжигание', 'электричество', 'аэс'],
#  ['афганистан', 'боевик', 'иго', 'провинция', 'таджикистан'],
#  ['поэт', 'дом', 'стих', 'угол', 'переулок'],
#  ['ходорковский',
#   'обыск',
#   'правоохранитель',
#   'квартира',
#   'нарушение законодательство'],
#  ['питание', 'продукт', 'россиянин', 'вциома', 'образ жизнь'],
#  ['ранение', 'территория район', 'инспектор', 'стрельба', 'район'],
#  ['объект', 'козак', 'олимпиада', 'совещание', 'путин'],
#  ['человек', 'молодая человек', 'молодая', 'церковь', 'ребёнок'],
#  ['сирия', 'удар', 'ракета', 'гута', 'носитель'],
#  ['блогер', 'спорт', 'владимир', 'владимир владимир', 'реализм'],
#  ['композиция', 'джаз', 'мэтр', 'филипп', 'шарль'],
#  ['нефть', 'компания', 'запас', 'год', 'страна'],
#  ['депутат', 'бюллетень', 'нож', 'среда', 'заседание'],
#  ['грузия', 'ответственность', 'кооперация', 'оппозиция власть', 'москва'],
#  ['заседание правительство',
#   'программа сотрудничество',
#   'сотрудничество',
#   'средство развитие',
#   'год премьер'],
#  ['руслан', 'нии', 'дед', 'шеф', 'гдр'],
#  ['театр', 'худрук', 'бутусов', 'режиссёр', 'директор'],
#  ['саудовец', 'иран', 'эр', 'оружие', 'бомба'],
#  ['команда', 'пилот', 'хэмилтон', 'гонка', 'подиум'],
#  ['игрушка', 'коробка', 'домик', 'шар', 'одежда'],
#  ['обвинение', 'прокурор', 'особа', 'польша', 'апрель год'],
#  ['власть общество', 'общество', 'власть', 'опыт', 'страна'],
#  ['туркмения', 'телевидение', 'маяк', 'радиостанция', 'отключение'],
#  ['греция', 'ципраса', 'кредитор', 'еврозона', 'налог'],
#  ['сирия', 'боевик', 'прекращение огонь', 'президент', 'асад'],
#  ['еаэс', 'соглашение', 'цепочка', 'услуга', 'страна'],
#  ['сера', 'сухогруз', 'тонна', 'пролив', 'экипаж'],
#  ['океан', 'остров', 'пластик', 'чарльз', 'том'],
#  ['доказательство', 'фсб', 'дочь', 'россия отравление', 'россия министр'],
#  ['возраст', 'нагрузка', 'столыпин', 'экономика', 'доклад'],
#  ['харьков', 'рифма', 'поэт', 'подарок', 'современник'],
#  ['донбасс', 'украина', 'киев', 'закон', 'сепаратист'],
#  ['бенедикт', 'папа', 'франциск', 'ратцингер', 'кардинал'],
#  ['самолёт', 'бомбардировщик', 'система', 'боев', 'сирия'],
#  ['масса килограмм', 'аппарат', 'боеприпас', 'система', 'килограмм'],
#  ['эстония', 'церковь', 'сотрудничество', 'традиция', 'совет'],
#  ['интеллект', 'человек', 'функция', 'человечество', 'технология'],
#  ['избирком', 'молодёжь', 'молодая', 'избиратель', 'выбор'],
#  ['корабль', 'вмф', 'проект', 'единица', 'фрегат'],
#  ['авианосец', 'строительство комплекс', 'базирование', 'шторм', 'комплекс'],
#  ['стих', 'поэт', 'зима', 'дом', 'павел'],
#  ['режиссёр', 'сцена театр', 'театр', 'сцена', 'создание'],
#  ['вс', 'политика', 'флот', 'сирия', 'армия'],
#  ['анкара', 'турция', 'сша', 'эрдогана', 'вашингтон'],
#  ['происшествие', 'школа', 'ученик школа', 'пистолет', 'пострадавший'],
#  ['поставка', 'экспорт', 'нефть', 'танкер', 'газа'],
#  ['матч', 'канада', 'команда', 'гол', 'американец'],
#  ['владимир', 'площадь', 'христос', 'монумент', 'князь'],
#  ['перевод', 'поэзия', 'проза', 'подвиг', 'полка'],
#  ['клетка', 'белок', 'самец', 'ген', 'самка'],
#  ['подмосковье', 'кандидат', 'яблоко', 'выборы', 'оппозиция'],
#  ['газа', 'газопровод', 'украина', 'миллиард куб', 'куб метр'],
#  ['гран при', 'при', 'гран', 'пилот', 'команда'],
#  ['поэзия', 'поэт', 'стих', 'рифма', 'эхо'],
#  ['масло', 'интернет', 'механик', 'компьютер', 'фильтр'],
#  ['тиллерсон', 'нетаньяха', 'глава мид', 'госдеп', 'обвинение'],
#  ['американец', 'джонатан', 'бой', 'генерал', 'военный'],
#  ['поток', 'газпром', 'нитка', 'газопровод', 'маршрут'],
#  ['гонка', 'команда', 'при', 'гран при', 'пилот'],
#  ['квалификация', 'хонда', 'поул', 'часть квалификация', 'норберт'],
#  ['туркменистан', 'газа', 'куб метр', 'куб', 'месторождение'],
#  ['собака', 'остров', 'андерсон', 'мальчик', 'герой'],
#  ['оппозиция', 'выбор', 'саакашвили', 'грузия', 'выборы'],
#  ['украинец', 'украина', 'год', 'показатель', 'кмис'],
#  ['вода', 'ресурс', 'вод', 'труба', 'водоём'],
#  ['обложка', 'женщина', 'выставка', 'журнал', 'очерк'],
#  ['мюллер', 'кардинал', 'конгрегация', 'папа', 'префект'],
#  ['ольга', 'карл', 'самоубийство', 'посольство', 'нью йорк'],
#  ['финляндия', 'ворот', 'сборная', 'период', 'счёт'],
#  ['высоцкий', 'январь', 'первое канал', 'канал', 'владимир высоцкий'],
#  ['терроризм', 'меморандум', 'борьба терроризм', 'буш', 'ирак'],
#  ['препарат', 'лекарство', 'болезнь', 'цена', 'регистрация'],
#  ['самолёт', 'фрагмент', 'рейс', 'австралия', 'лайнер'],
#  ['губернаторов', 'фильтр', 'подпись', 'подпись депутат', 'послание'],
#  ['губернатор', 'весна', 'чиновник', 'рейтинг', 'поднятие'],
#  ['координатор', 'отделение', 'собчак', 'соловьев', 'совет'],
#  ['робот', 'интеллект', 'система', 'человек', 'машина'],
#  ['площадка', 'москва', 'тверская', 'парк', 'парка'],
#  ['интеллектуал', 'курс', 'власть', 'реформа', 'борьба власть'],
#  ['мигрант', 'тысяча рубль', 'тысяча', 'рубль', 'россия'],
#  ['мвф', 'украина', 'реформа', 'выплата', 'программа'],
#  ['юкос', 'ходорковский', 'прошение', 'убийство', 'следствие'],
#  ['смертность', 'рак', 'профилактика', 'снижение', 'алкоголь'],
#  ['опека', 'газа', 'заседание', 'устав', 'тегеран'],
#  ['кпрф', 'валерий', 'коммунист', 'руководство', 'митинг'],
#  ['продолжительность жизнь',
#   'москва',
#   'продолжительность',
#   'старший поколение',
#   'проект'],
#  ['новосибирск', 'яблоко', 'акция', 'партия', 'сторонник'],
#  ['валюта', 'минфин', 'никифоров', 'бизнесмен', 'биржа'],
#  ['ес', 'брюссель', 'венгрия', 'правый', 'европа'],
#  ['выброс', 'выброс газ', 'газ', 'уровень выброс', 'развитие'],
#  ['юрий', 'писатель', 'милиционер', 'клуб', 'книга'],
#  ['фильм', 'приз', 'режиссёр', 'фестиваль', 'кино'],
#  ['война', 'знание', 'экономика', 'безопасность', 'средство']]

# %%
evaluate(data['keywords'], keywords)
# Out:
# Precision -  0.18
# Recall -  0.18
# F1 -  0.17
# Jaccard -  0.1

# %% [markdown]
# Сильного улучшения нет. Немного подросла точность. Теперь вместо стоп-слов в ключевые попадают имена и все такое. Иногда это хорощо, а иногда нет (собянин - может быть ключевым словом, а дарья - вряд ли)

# %% [markdown]
# ## Попробуем графы!

# %%
from itertools import combinations

# %%
def get_kws(text, top=5, window_size=5):

    vocab = set(text)
    word2id = {w:i for i, w in enumerate(vocab)}
    id2word = {i:w for i, w in enumerate(vocab)}
    # преобразуем слова в индексы для удобства
    ids = [word2id[word] for word in text]

    # создадим матрицу совстречаемости
    m = np.zeros((len(vocab), len(vocab)))

    # пройдемся окном по всему тексту
    for i in range(0, len(ids), window_size):
        window = ids[i:i+window_size]
        # добавим единичку всем парам слов в этом окне
        for j, k in combinations(window, 2):
            # чтобы граф был направленный 
            m[j][k] += 1
            m[k][j] += 1
    
    # нормализуем строки, чтобы получилась вероятность перехода
    for i in range(m.shape[0]):
        m[i] /= np.sum(m[i])
    
    # случайно выберем первое слова, а затем будет выбирать на основе полученых распределений
    # сделаем так 5 раз и добавим каждое слово в счетчик
    # чтобы не забиться в одном круге, иногда будет перескакивать на случайное слово
    
    c = Counter()
    n = np.random.choice(len(vocab))
    for i in range(1000):
        
        j = np.random.randint(1,10)
        if j > 8:
            n = np.random.choice(len(vocab))
        n = take_step(n, m)
        c.update([n])
    
    # вернем топ-N наиболее часто встретившихся сл
    return [id2word[i] for i, count in c.most_common(top)]

def take_step(n, matrix):
    rang = len(matrix[n])
    next_n = np.random.choice(range(rang), p=matrix[n])
    return next_n

# %%
# %%time
keywords_rw = data['content_norm'].apply(lambda x: get_kws(x, 10, 10))
# Out:
# CPU times: user 50 s, sys: 0 ns, total: 50 s
# Wall time: 50 s

# %%
evaluate(data['keywords'], keywords_rw)
# Out:
# Precision -  0.11
# Recall -  0.22
# F1 -  0.14
# Jaccard -  0.08

# %%
keywords_rw
# Out:
# 0                             [яблоко, год, активист, акция, сторона, политика, украина, убийство, молодая, жизнь]
# 1                                   [миллиард, газпром, газа, куб, год, метр, добыча, цена, производитель, страна]
# 2                                     [год, книга, роман, мениппея, россия, поэзия, москва, работа, перевод, жанр]
# 3                          [ким, зинаида, видео, журналист, год, подсудимая, свидетель, заседание, губарев, рубль]
# 4                                   [площадь, москва, га, территория, парк, тинао, регион, год, развитие, столица]
# 5                              [гонка, команда, позиция, бокс, круг, место, дженсон, ситуация, строчка, чемпионат]
# 6                              [место, рф, влияние, глава, позиция, президент, россия, сергей, сообщение, алексей]
# 7      [культура, закон, сфера, изменение, законодательство, человек, концепция, сообщество, проект, председатель]
# 8                                       [сирия, год, газопровод, россия, турция, европа, катар, иран, газа, поток]
# 9                         [участник, рф, организация, эмиссар, подготовка, март, фсб, территория, ячейка, область]
# 10                               [тихон, стихомант, журибеда, старик, время, казак, колба, голос, маленькая, лицо]
# 11                                    [жильё, метр, год, миллион, прогноз, объём, спрос, население, центр, страна]
# 12                            [фильм, сеанс, кино, год, владимир, качество, результат, ситуация, сравнение, театр]
# 13                  [фестиваль, революция, награда, фильм, владимир, ленин, картина, искусство, сахалин, режиссёр]
# 14                  [фёдоров, женщина, вечер, книга, произведение, балашов, чистяков, герой, читатель, литература]
# 15                       [оон, переговоры, лавров, франция, резолюция, россия, дриана, сторона, президент, макрон]
# 16                                  [суд, минюст, рф, постановление, право, запрос, еспч, юкос, человек, акционер]
# 17                       [электромобиль, год, тысяча, центр, кобальт, цена, компания, россия, батарея, автомобиль]
# 18                           [фильм, оскар, год, женщина, статуэтка, билборд, вечер, мужчина, дискриминация, тема]
# 19                      [нюрбургринг, трасса, гонка, шмитц, сабина, автомобиль, участие, пилотесса, правило, круг]
# 20                                 [год, книга, день, франция, язык, перевод, том, участие, нарбикова, литература]
# 21                      [сирия, дамаск, вашингтон, формирование, войско, война, москва, ополчение, ливан, союзник]
# 22                                       [шельф, год, страна, точка, полюс, миллиард, хребет, граница, мир, запас]
# 23                                           [метр, поэт, александр, центр, сергей, исмиева, книга, дом, март, др]
# 24                          [пассажир, авиакомпания, багаж, победа, тариф, питание, борт, ведомство, полёт, пакет]
# 25                       [фильм, серебряков, андрей, культура, идея, актёр, внимание, режиссёр, картина, развитие]
# 26                     [теплов, энергия, температура, земля, глубина, тепло, скважина, система, источник, горячее]
# 27                                [власть, собчак, интерес, часть, фигура, электорат, система, дело, схема, время]
# 28                               [саммит, встреча, путин, день, саванна, райса, город, вашингтон, москва, событие]
# 29                            [сальери, моцарт, зависть, результат, музыка, человек, пушкин, жизнь, польза, гений]
#                                                           ...
# 969                   [год, отношение, украина, война, ситуация, показатель, государство, нато, значение, человек]
# 970                          [вода, год, ресурс, проблема, россия, труба, экономика, вод, нанотехнология, углерод]
# 971                                      [женщина, журнал, выставка, век, обложка, власть, начало, мода, год, ряд]
# 972                             [мюллер, конгрегация, папа, кардинал, франциск, префект, год, герхард, пост, тема]
# 973                                 [парти, ольга, фидель, карл, мир, самоубийство, гевар, человек, жизнь, газета]
# 974                                 [финляндия, период, шайба, счёт, ворот, минута, россия, сборная, борьба, илья]
# 975                         [высоцкий, владимир, программа, канал, премьера, январь, год, жизнь, зритель, человек]
# 976                          [терроризм, война, сша, рамсфелд, буш, мышление, тип, вопрос, минобороны, меморандум]
# 977                       [препарат, год, лекарство, мир, специалист, цена, деньга, механизм, регистрация, бюджет]
# 978                                 [самолёт, год, австралия, рейс, тысяча, зона, лайнер, часть, авиалиния, поиск]
# 979                [россия, губернаторов, президент, послание, фильтр, выбор, страна, разъяснение, подпись, тезис]
# 980                             [гто, гиря, губернатор, условие, чиновник, весна, друг, рейтинг, авитаминоз, пора]
# 981                      [координатор, баронов, движение, соловьев, отделение, ротация, совет, собчак, год, выбор]
# 982                             [человек, система, страна, робот, интеллект, жизнь, мир, проблема, процесс, часть]
# 983                        [город, москва, площадка, выступление, сентябрь, день, театр, праздник, парк, переулок]
# 984                          [страна, россия, управление, вопрос, сила, власть, случай, ответ, политика, медведев]
# 985                   [россия, мигрант, тысяча, рубль, гастарбайтер, год, россиянин, страна, исследование, работа]
# 986                              [год, мвф, украина, программа, фонд, эксперт, реформа, суд, сотрудничество, долг]
# 987                  [пичугин, дело, решение, год, президент, помилование, убийство, следствие, адвокат, прошение]
# 988                 [год, рак, смертность, профилактика, снижение, результат, курение, мужчина, население, лёгкое]
# 989                               [газа, организация, заседание, опека, россия, иран, год, москва, фсэг, создание]
# 990                    [кпрф, валерий, рашкина, руководство, горком, организатор, госдума, революция, алексей, цк]
# 991                        [человек, жизнь, год, москва, программа, долголетие, поколение, проект, участие, город]
# 992              [яблоко, партия, акция, новосибирск, регион, яблочник, год, представитель, отделение, монстрация]
# 993         [криптовалюта, крипторубль, валюта, бизнесмен, новость, никифоров, минфин, доллар, биткоина, операция]
# 994                            [ес, брюссель, европа, страна, политика, ценность, венгрия, орбан, правый, эксперт]
# 995                                    [выброс, цель, год, газ, развитие, уровень, пункт, сторона, россия, страна]
# 996                                      [коваль, юрий, писатель, жизнь, глаз, книга, берег, человек, река, иосиф]
# 997                              [фильм, режиссёр, история, фальк, приз, зритель, тайга, иванов, герой, интонация]
# 998              [война, экономика, ценность, информация, безопасность, средство, угроза, вопрос, знание, военный]
# Name: content_norm, Length: 999, dtype: object

# %%
import networkx as nx

# %%
def build_matrix(text, window_size=5):
    vocab = set(text)
    word2id = {w:i for i, w in enumerate(vocab)}
    id2word = {i:w for i, w in enumerate(vocab)}
    # преобразуем слова в индексы для удобства
    ids = [word2id[word] for word in text]

    # создадим матрицу совстречаемости
    m = np.zeros((len(vocab), len(vocab)))

    # пройдемся окном по всему тексту
    for i in range(0, len(ids), window_size):
        window = ids[i:i+window_size]
        # добавим единичку всем парам слов в этом окне
        for j, k in combinations(window, 2):
            # чтобы граф был направленный 
            m[j][k] += 1
            m[k][j] += 1
    
    return m, id2word

def some_centrality_measure(text, window_size=5, topn=5):
    
    matrix, id2word = build_matrix(text, window_size)
    G = nx.from_numpy_array(matrix)
    # тут можно поставить любую метрику
    node2measure = dict(nx.degree(G))
    
    return [id2word[index] for index,measure in sorted(node2measure.items(), key=lambda x: -x[1])[:topn]]

# %%
matrix, id2word = build_matrix(data['content_norm'][0])

# %%
# %%time
keyword_nx = data['content_norm'].apply(lambda x: some_centrality_measure(x, 10, 10))
# Out:
# CPU times: user 6.6 s, sys: 0 ns, total: 6.6 s
# Wall time: 6.6 s

# %%
evaluate(data['keywords'], keyword_nx)
# Out:
# Precision -  0.12
# Recall -  0.24
# F1 -  0.16
# Jaccard -  0.09
