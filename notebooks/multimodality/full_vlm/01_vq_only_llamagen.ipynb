# %% [markdown]
# # Fully multimodal LLM
#
# В последнем семинаре мы разбирали как можно обучить модель токенизировать (и детокенизировать) картинки. Но это только промежуточный шаг. В итоге мы хотим обучить языковую модель, которая можно генерировать не только текст, но и картинки. Давайте попробуем это сделать в этом семинаре.
#
# В целом архитектура обучения такой модели не сильно отличается от дообучения обычной LLM на текстах. Главное отличие в том, что для мультимодальной модели нам нужно смешать модальности в один поток токенов на входе, а на выходе раскодировать текстовые токены в текст, а картиночные токены в пиксели картинок.
#
# Схематично архитектура выглядит как-то так:
# ![](https://i.ibb.co/TM64tMjY/Screenshot-2026-06-03-at-15-20-09.png)
#
# Тут я показываю авторегрессионную генерацию, и этот цикл от generation в image tokenizer означает, что мы генерируем токен и передаем его как часть промпта на следующем вызове. Для простоты в семинаре будем работать только со случаем, когда на вход мы подаем картинку+текст, а на выходе ожидаем только картинку.
# На первом шаге предсказания структура промпта выглядит как-то так:
# `[токены входной картинки] + [текстовые токены (инструкции/описания)] + [картиночный BOS token]`
# В середине генерации структура промпта будет какая-то такая:
# `[токены входной картинки] + [текстовые токены (инструкции/описания)] + [BOS, уже сгенерированные токены выходной картинки]`
# А в конце соответственно:
# `[токены входной картинки] + [текстовые токены (инструкции/описания)] + [BOS, токены выходной картинки, EOS]`
#
# Я проговариваю это отдельно потому что нам не обязательно использовать один и тот же картиночный токенизатор для токенов входной картинки и токенов выходной картинки, но пока давайте попробуем сделать все через одну модель.

# %% [markdown]
# Возьмем предобученный картиночный VQ токенизатор **LlamaGen VQ** (downsample 16, codebook 16384). Изначально я хотел использовать `vqgan_imagenet_f16_1024`, но он уже немного устарел и качество у него похуже. LLamaGen взят отсюда - https://github.com/foundationvision/llamagen

# %% [raw]
# Давайте загрузим какую-то картинку и прогоним ее через эту модель, чтобы оценить качество этого автоэнкодера

# %%
# %pip install requests matplotlib datasets transformers

# %%
import io, os, json, math, time, pickle, requests
from dataclasses import dataclass, field
from typing import List, Optional

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

from PIL import Image
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

from datasets import load_dataset
from transformers import AutoTokenizer
from huggingface_hub import hf_hub_download

os.environ["TOKENIZERS_PARALLELISM"] = "false"
torch.set_grad_enabled(False)   # включим только на обучении
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
torch.manual_seed(0)
print("device:", DEVICE)
# Out:
# device: cuda

# %% [markdown]
# Тут я немного вытащил код из репозитория, чтобы загрузить чекпойнт

# %%
from dataclasses import dataclass, field
from typing import List

import torch
import torch.nn as nn
import torch.nn.functional as F


@dataclass
class ModelArgs:
    codebook_size: int = 16384
    codebook_embed_dim: int = 8
    codebook_l2_norm: bool = True
    codebook_show_usage: bool = True
    commit_loss_beta: float = 0.25
    entropy_loss_ratio: float = 0.0
    
    encoder_ch_mult: List[int] = field(default_factory=lambda: [1, 1, 2, 2, 4])
    decoder_ch_mult: List[int] = field(default_factory=lambda: [1, 1, 2, 2, 4])
    z_channels: int = 256
    dropout_p: float = 0.0



class VQModel(nn.Module):
    def __init__(self, config: ModelArgs):
        super().__init__()
        self.config = config
        self.encoder = Encoder(ch_mult=config.encoder_ch_mult, z_channels=config.z_channels, dropout=config.dropout_p)
        self.decoder = Decoder(ch_mult=config.decoder_ch_mult, z_channels=config.z_channels, dropout=config.dropout_p)

        self.quantize = VectorQuantizer(config.codebook_size, config.codebook_embed_dim, 
                                        config.commit_loss_beta, config.entropy_loss_ratio,
                                        config.codebook_l2_norm, config.codebook_show_usage)
        self.quant_conv = nn.Conv2d(config.z_channels, config.codebook_embed_dim, 1)
        self.post_quant_conv = nn.Conv2d(config.codebook_embed_dim, config.z_channels, 1)

    def encode(self, x):
        h = self.encoder(x)
        h = self.quant_conv(h)
        quant, emb_loss, info = self.quantize(h)
        return quant, emb_loss, info

    def decode(self, quant):
        quant = self.post_quant_conv(quant)
        dec = self.decoder(quant)
        return dec

    def decode_code(self, code_b, shape=None, channel_first=True):
        quant_b = self.quantize.get_codebook_entry(code_b, shape, channel_first)
        dec = self.decode(quant_b)
        return dec

    def forward(self, input):
        quant, diff, _ = self.encode(input)
        dec = self.decode(quant)
        return dec, diff



class Encoder(nn.Module):
    def __init__(self, in_channels=3, ch=128, ch_mult=(1,1,2,2,4), num_res_blocks=2, 
                 norm_type='group', dropout=0.0, resamp_with_conv=True, z_channels=256):
        super().__init__()
        self.num_resolutions = len(ch_mult)
        self.num_res_blocks = num_res_blocks
        self.conv_in = nn.Conv2d(in_channels, ch, kernel_size=3, stride=1, padding=1)

        # downsampling
        in_ch_mult = (1,) + tuple(ch_mult)
        self.conv_blocks = nn.ModuleList()
        for i_level in range(self.num_resolutions):
            conv_block = nn.Module()
            # res & attn
            res_block = nn.ModuleList()
            attn_block = nn.ModuleList()
            block_in = ch*in_ch_mult[i_level]
            block_out = ch*ch_mult[i_level]
            for _ in range(self.num_res_blocks):
                res_block.append(ResnetBlock(block_in, block_out, dropout=dropout, norm_type=norm_type))
                block_in = block_out
                if i_level == self.num_resolutions - 1:
                    attn_block.append(AttnBlock(block_in, norm_type))
            conv_block.res = res_block
            conv_block.attn = attn_block
            # downsample
            if i_level != self.num_resolutions-1:
                conv_block.downsample = Downsample(block_in, resamp_with_conv)
            self.conv_blocks.append(conv_block)

        # middle
        self.mid = nn.ModuleList()
        self.mid.append(ResnetBlock(block_in, block_in, dropout=dropout, norm_type=norm_type))
        self.mid.append(AttnBlock(block_in, norm_type=norm_type))
        self.mid.append(ResnetBlock(block_in, block_in, dropout=dropout, norm_type=norm_type))

        # end
        self.norm_out = Normalize(block_in, norm_type)
        self.conv_out = nn.Conv2d(block_in, z_channels, kernel_size=3, stride=1, padding=1)


    def forward(self, x):
        h = self.conv_in(x)
        # downsampling
        for i_level, block in enumerate(self.conv_blocks):
            for i_block in range(self.num_res_blocks):
                h = block.res[i_block](h)
                if len(block.attn) > 0:
                    h = block.attn[i_block](h)
            if i_level != self.num_resolutions - 1:
                h = block.downsample(h)
        
        # middle
        for mid_block in self.mid:
            h = mid_block(h)
        
        # end
        h = self.norm_out(h)
        h = nonlinearity(h)
        h = self.conv_out(h)
        return h



class Decoder(nn.Module):
    def __init__(self, z_channels=256, ch=128, ch_mult=(1,1,2,2,4), num_res_blocks=2, norm_type="group",
                 dropout=0.0, resamp_with_conv=True, out_channels=3):
        super().__init__()
        self.num_resolutions = len(ch_mult)
        self.num_res_blocks = num_res_blocks

        block_in = ch*ch_mult[self.num_resolutions-1]
        # z to block_in
        self.conv_in = nn.Conv2d(z_channels, block_in, kernel_size=3, stride=1, padding=1)

       # middle
        self.mid = nn.ModuleList()
        self.mid.append(ResnetBlock(block_in, block_in, dropout=dropout, norm_type=norm_type))
        self.mid.append(AttnBlock(block_in, norm_type=norm_type))
        self.mid.append(ResnetBlock(block_in, block_in, dropout=dropout, norm_type=norm_type))

        # upsampling
        self.conv_blocks = nn.ModuleList()
        for i_level in reversed(range(self.num_resolutions)):
            conv_block = nn.Module()
            # res & attn
            res_block = nn.ModuleList()
            attn_block = nn.ModuleList()
            block_out = ch*ch_mult[i_level]
            for _ in range(self.num_res_blocks + 1):
                res_block.append(ResnetBlock(block_in, block_out, dropout=dropout, norm_type=norm_type))
                block_in = block_out
                if i_level == self.num_resolutions - 1:
                    attn_block.append(AttnBlock(block_in, norm_type))
            conv_block.res = res_block
            conv_block.attn = attn_block
            # downsample
            if i_level != 0:
                conv_block.upsample = Upsample(block_in, resamp_with_conv)
            self.conv_blocks.append(conv_block)

        # end
        self.norm_out = Normalize(block_in, norm_type)
        self.conv_out = nn.Conv2d(block_in, out_channels, kernel_size=3, stride=1, padding=1)

    @property
    def last_layer(self):
        return self.conv_out.weight
    
    def forward(self, z):
        # z to block_in
        h = self.conv_in(z)

        # middle
        for mid_block in self.mid:
            h = mid_block(h)
        
        # upsampling
        for i_level, block in enumerate(self.conv_blocks):
            for i_block in range(self.num_res_blocks + 1):
                h = block.res[i_block](h)
                if len(block.attn) > 0:
                    h = block.attn[i_block](h)
            if i_level != self.num_resolutions - 1:
                h = block.upsample(h)

        # end
        h = self.norm_out(h)
        h = nonlinearity(h)
        h = self.conv_out(h)
        return h


class VectorQuantizer(nn.Module):
    def __init__(self, n_e, e_dim, beta, entropy_loss_ratio, l2_norm, show_usage):
        super().__init__()
        self.n_e = n_e
        self.e_dim = e_dim
        self.beta = beta
        self.entropy_loss_ratio = entropy_loss_ratio
        self.l2_norm = l2_norm
        self.show_usage = show_usage

        self.embedding = nn.Embedding(self.n_e, self.e_dim)
        self.embedding.weight.data.uniform_(-1.0 / self.n_e, 1.0 / self.n_e)
        if self.l2_norm:
            self.embedding.weight.data = F.normalize(self.embedding.weight.data, p=2, dim=-1)
        if self.show_usage:
            self.register_buffer("codebook_used", nn.Parameter(torch.zeros(65536)))

    
    def forward(self, z):
        # reshape z -> (batch, height, width, channel) and flatten
        z = torch.einsum('b c h w -> b h w c', z).contiguous()
        z_flattened = z.view(-1, self.e_dim)
        # distances from z to embeddings e_j (z - e)^2 = z^2 + e^2 - 2 e * z

        if self.l2_norm:
            z = F.normalize(z, p=2, dim=-1)
            z_flattened = F.normalize(z_flattened, p=2, dim=-1)
            embedding = F.normalize(self.embedding.weight, p=2, dim=-1)
        else:
            embedding = self.embedding.weight

        d = torch.sum(z_flattened ** 2, dim=1, keepdim=True) + \
            torch.sum(embedding**2, dim=1) - 2 * \
            torch.einsum('bd,dn->bn', z_flattened, torch.einsum('n d -> d n', embedding))

        min_encoding_indices = torch.argmin(d, dim=1)
        z_q = embedding[min_encoding_indices].view(z.shape)
        perplexity = None
        min_encodings = None
        vq_loss = None
        commit_loss = None
        entropy_loss = None
        codebook_usage = 0

        if self.show_usage and self.training:
            cur_len = min_encoding_indices.shape[0]
            self.codebook_used[:-cur_len] = self.codebook_used[cur_len:].clone()
            self.codebook_used[-cur_len:] = min_encoding_indices
            codebook_usage = len(torch.unique(self.codebook_used)) / self.n_e

        # compute loss for embedding
        if self.training:
            vq_loss = torch.mean((z_q - z.detach()) ** 2) 
            commit_loss = self.beta * torch.mean((z_q.detach() - z) ** 2) 
            entropy_loss = self.entropy_loss_ratio * compute_entropy_loss(-d)

        # preserve gradients
        z_q = z + (z_q - z).detach()

        # reshape back to match original input shape
        z_q = torch.einsum('b h w c -> b c h w', z_q)

        return z_q, (vq_loss, commit_loss, entropy_loss, codebook_usage), (perplexity, min_encodings, min_encoding_indices)

    def get_codebook_entry(self, indices, shape=None, channel_first=True):
        # shape = (batch, channel, height, width) if channel_first else (batch, height, width, channel)
        if self.l2_norm:
            embedding = F.normalize(self.embedding.weight, p=2, dim=-1)
        else:
            embedding = self.embedding.weight
        z_q = embedding[indices]  # (b*h*w, c)

        if shape is not None:
            if channel_first:
                z_q = z_q.reshape(shape[0], shape[2], shape[3], shape[1])
                # reshape back to match original input shape
                z_q = z_q.permute(0, 3, 1, 2).contiguous()
            else:
                z_q = z_q.view(shape)
        return z_q


class ResnetBlock(nn.Module):
    def __init__(self, in_channels, out_channels=None, conv_shortcut=False, dropout=0.0, norm_type='group'):
        super().__init__()
        self.in_channels = in_channels
        out_channels = in_channels if out_channels is None else out_channels
        self.out_channels = out_channels
        self.use_conv_shortcut = conv_shortcut

        self.norm1 = Normalize(in_channels, norm_type)
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=1, padding=1)
        self.norm2 = Normalize(out_channels, norm_type)
        self.dropout = nn.Dropout(dropout)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1)

        if self.in_channels != self.out_channels:
            if self.use_conv_shortcut:
                self.conv_shortcut = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=1, padding=1)
            else:
                self.nin_shortcut = nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1, padding=0)

    def forward(self, x):
        h = x
        h = self.norm1(h)
        h = nonlinearity(h)
        h = self.conv1(h)
        h = self.norm2(h)
        h = nonlinearity(h)
        h = self.dropout(h)
        h = self.conv2(h)

        if self.in_channels != self.out_channels:
            if self.use_conv_shortcut:
                x = self.conv_shortcut(x)
            else:
                x = self.nin_shortcut(x)
        return x+h


class AttnBlock(nn.Module):
    def __init__(self, in_channels, norm_type='group'):
        super().__init__()
        self.norm = Normalize(in_channels, norm_type)
        self.q = nn.Conv2d(in_channels, in_channels, kernel_size=1, stride=1, padding=0)
        self.k = nn.Conv2d(in_channels, in_channels, kernel_size=1, stride=1, padding=0)
        self.v = nn.Conv2d(in_channels, in_channels, kernel_size=1, stride=1, padding=0)
        self.proj_out = nn.Conv2d(in_channels, in_channels, kernel_size=1, stride=1, padding=0)


    def forward(self, x):
        h_ = x
        h_ = self.norm(h_)
        q = self.q(h_)
        k = self.k(h_)
        v = self.v(h_)

        # compute attention
        b,c,h,w = q.shape
        q = q.reshape(b,c,h*w)
        q = q.permute(0,2,1)   # b,hw,c
        k = k.reshape(b,c,h*w) # b,c,hw
        w_ = torch.bmm(q,k)     # b,hw,hw    w[b,i,j]=sum_c q[b,i,c]k[b,c,j]
        w_ = w_ * (int(c)**(-0.5))
        w_ = F.softmax(w_, dim=2)

        # attend to values
        v = v.reshape(b,c,h*w)
        w_ = w_.permute(0,2,1)   # b,hw,hw (first hw of k, second of q)
        h_ = torch.bmm(v,w_)     # b, c,hw (hw of q) h_[b,c,j] = sum_i v[b,c,i] w_[b,i,j]
        h_ = h_.reshape(b,c,h,w)

        h_ = self.proj_out(h_)

        return x+h_


def nonlinearity(x):
    # swish
    return x*torch.sigmoid(x)


def Normalize(in_channels, norm_type='group'):
    assert norm_type in ['group', 'batch']
    if norm_type == 'group':
        return nn.GroupNorm(num_groups=32, num_channels=in_channels, eps=1e-6, affine=True)
    elif norm_type == 'batch':
        return nn.SyncBatchNorm(in_channels)


class Upsample(nn.Module):
    def __init__(self, in_channels, with_conv):
        super().__init__()
        self.with_conv = with_conv
        if self.with_conv:
            self.conv = nn.Conv2d(in_channels, in_channels, kernel_size=3, stride=1, padding=1)

    def forward(self, x):
        x = F.interpolate(x, scale_factor=2.0, mode="nearest")
        if self.with_conv:
            x = self.conv(x)
        return x


class Downsample(nn.Module):
    def __init__(self, in_channels, with_conv):
        super().__init__()
        self.with_conv = with_conv
        if self.with_conv:
            # no asymmetric padding in torch conv, must do it ourselves
            self.conv = nn.Conv2d(in_channels, in_channels, kernel_size=3, stride=2, padding=0)

    def forward(self, x):
        if self.with_conv:
            pad = (0,1,0,1)
            x = F.pad(x, pad, mode="constant", value=0)
            x = self.conv(x)
        else:
            x = F.avg_pool2d(x, kernel_size=2, stride=2)
        return x


def compute_entropy_loss(affinity, loss_type="softmax", temperature=0.01):
    flat_affinity = affinity.reshape(-1, affinity.shape[-1])
    flat_affinity /= temperature
    probs = F.softmax(flat_affinity, dim=-1)
    log_probs = F.log_softmax(flat_affinity + 1e-5, dim=-1)
    if loss_type == "softmax":
        target_probs = probs
    else:
        raise ValueError("Entropy loss {} not supported".format(loss_type))
    avg_probs = torch.mean(target_probs, dim=0)
    avg_entropy = - torch.sum(avg_probs * torch.log(avg_probs + 1e-5))
    sample_entropy = - torch.mean(torch.sum(target_probs * log_probs, dim=-1))
    loss = sample_entropy - avg_entropy
    return loss


#################################################################################
#                              VQ Model Configs                                 #
#################################################################################
def VQ_8(**kwargs):
    return VQModel(ModelArgs(encoder_ch_mult=[1, 2, 2, 4], decoder_ch_mult=[1, 2, 2, 4], **kwargs))

def VQ_16(**kwargs):
    return VQModel(ModelArgs(encoder_ch_mult=[1, 1, 2, 2, 4], decoder_ch_mult=[1, 1, 2, 2, 4], **kwargs))

VQ_models = {'VQ-16': VQ_16, 'VQ-8': VQ_8}

# %% [markdown]
# Загрузка весов + хелперы препроцессинга/реконструкции.

# %%
def load_llamagen_vq(device=DEVICE, codebook_size=16384, codebook_embed_dim=8):
    model = VQ_models["VQ-16"](codebook_size=codebook_size, codebook_embed_dim=codebook_embed_dim)
    ckpt_path = hf_hub_download(repo_id="FoundationVision/LlamaGen", filename="vq_ds16_c2i.pt")
    ckpt = torch.load(ckpt_path, map_location="cpu", weights_only=False)
    sd = ckpt.get("ema") or ckpt.get("model") or ckpt.get("state_dict") or ckpt
    model.load_state_dict(sd)
    return model.eval().to(device)


vq = load_llamagen_vq()
VQ_CODEBOOK = vq.config.codebook_size       # 16384
VQ_EDIM = vq.config.codebook_embed_dim      # 8
N_IMG_TOKENS = 16 * 16                       # 256x256 -> 16x16
print(f"LlamaGen VQ: codebook={VQ_CODEBOOK}, embed_dim={VQ_EDIM}, tokens/image={N_IMG_TOKENS}")


def center_crop_arr(pil_image, image_size):
    while min(*pil_image.size) >= 2 * image_size:
        pil_image = pil_image.resize(tuple(x // 2 for x in pil_image.size), resample=Image.BOX)
    scale = image_size / min(*pil_image.size)
    pil_image = pil_image.resize(tuple(round(x * scale) for x in pil_image.size), resample=Image.BICUBIC)
    arr = np.array(pil_image)
    cy = (arr.shape[0] - image_size) // 2
    cx = (arr.shape[1] - image_size) // 2
    return Image.fromarray(arr[cy:cy + image_size, cx:cx + image_size])


def custom_to_pil(x):
    x = torch.clamp(x.detach().cpu(), -1.0, 1.0)
    x = (x + 1.0) / 2.0
    x = (255 * x.permute(1, 2, 0).numpy()).astype(np.uint8)
    return Image.fromarray(x).convert("RGB")


@torch.no_grad()
def lg_encode_indices(pil, image_size=256):
    crop = center_crop_arr(pil.convert("RGB"), image_size)
    arr = np.array(crop) / 255.0
    x = torch.tensor(2.0 * arr - 1.0).unsqueeze(0)          # [-1, 1] -- так обучался VQ
    x = torch.einsum("nhwc->nchw", x).float().to(DEVICE)
    _, _, [_, _, idx] = vq.encode(x)
    return idx.cpu().numpy()                                # (256,) индексы codebook


@torch.no_grad()
def lg_decode_to_pil(indices, grid=16):
    idx = torch.as_tensor(indices, dtype=torch.long, device=DEVICE).reshape(-1)
    dec = vq.decode_code(idx, shape=(1, VQ_EDIM, grid, grid))
    return custom_to_pil(dec[0])
# Out:
# LlamaGen VQ: codebook=16384, embed_dim=8, tokens/image=256

# %% [markdown]
# Быстрая проверка токенизатора: реконструкция (encode → decode) и число токенов.

# %%
_demo = Image.open(requests.get(
    "https://pettownsendvet.com/wp-content/uploads/2023/01/iStock-1052880600-2048x1365.jpg",
    stream=True).raw)
_idx = lg_encode_indices(_demo)
_rec = lg_decode_to_pil(_idx)
print("tokens:", len(_idx), "| codebook:", VQ_CODEBOOK)
fig, ax = plt.subplots(1, 2, figsize=(8, 4))
ax[0].imshow(center_crop_arr(_demo.convert("RGB"), 256)); ax[0].set_title("original"); ax[0].axis("off")
ax[1].imshow(_rec); ax[1].set_title("VQ reconstruction"); ax[1].axis("off")
plt.show()
# Out:
# tokens: 256 | codebook: 16384

# %% [markdown]
# Видно, что картинка даже без каких-либо промежуточный шагов уже что-то теряет. То есть не стоит рассчитывать, что качество нашей модели будет очень хорошим. Однако мы все еще можем разобрать ретривера на картинке и значит можем ожидать хотя бы приблизительно разборчивые картинки

# %% [markdown]
# ## InstructPix2Pix
#
# Обучать модель мы будем на датасете pix2pix [timbrooks/instructpix2pix-clip-filtered](https://huggingface.co/datasets/timbrooks/instructpix2pix-clip-filtered). Это датасет с парами «картинка + инструкция → отредактированная картинка»

# %%
# !ls data_vqllm/prompts
# Out:
# 0_prompt.json	   14500_prompt.json  19000_prompt.json  5500_prompt.json
# 10000_prompt.json  14501_prompt.json  19001_prompt.json  5501_prompt.json
# 10001_prompt.json  14502_prompt.json  19002_prompt.json  5502_prompt.json
# 10002_prompt.json  14503_prompt.json  19003_prompt.json  5503_prompt.json
# 10003_prompt.json  14504_prompt.json  19004_prompt.json  5504_prompt.json
# 10004_prompt.json  14505_prompt.json  19005_prompt.json  5505_prompt.json
# 10005_prompt.json  14506_prompt.json  19006_prompt.json  5506_prompt.json
# 10006_prompt.json  14507_prompt.json  19007_prompt.json  5507_prompt.json
# 10007_prompt.json  14508_prompt.json  19008_prompt.json  5508_prompt.json
# 10008_prompt.json  14509_prompt.json  19009_prompt.json  5509_prompt.json
# 10009_prompt.json  1450_prompt.json   1900_prompt.json	 550_prompt.json
# 1000_prompt.json   14510_prompt.json  19010_prompt.json  5510_prompt.json
# 10010_prompt.json  14511_prompt.json  19011_prompt.json  5511_prompt.json
# 10011_prompt.json  14512_prompt.json  19012_prompt.json  5512_prompt.json
# 10012_prompt.json  14513_prompt.json  19013_prompt.json  5513_prompt.json
# 10013_prompt.json  14514_prompt.json  19014_prompt.json  5514_prompt.json
# 10014_prompt.json  14515_prompt.json  19015_prompt.json  5515_prompt.json
# 10015_prompt.json  14516_prompt.json  19016_prompt.json  5516_prompt.json
# 10016_prompt.json  14517_prompt.json  19017_prompt.json  5517_prompt.json
# 10017_prompt.json  14518_prompt.json  19018_prompt.json  5518_prompt.json
# 10018_prompt.json  14519_prompt.json  19019_prompt.json  5519_prompt.json
# 10019_prompt.json  1451_prompt.json   1901_prompt.json	 551_prompt.json
# 1001_prompt.json   14520_prompt.json  19020_prompt.json  5520_prompt.json
# 10020_prompt.json  14521_prompt.json  19021_prompt.json  5521_prompt.json
# 10021_prompt.json  14522_prompt.json  19022_prompt.json  5522_prompt.json
# 10022_prompt.json  14523_prompt.json  19023_prompt.json  5523_prompt.json
# 10023_prompt.json  14524_prompt.json  19024_prompt.json  5524_prompt.json
# 10024_prompt.json  14525_prompt.json  19025_prompt.json  5525_prompt.json
# 10025_prompt.json  14526_prompt.json  19026_prompt.json  5526_prompt.json
# 10026_prompt.json  14527_prompt.json  19027_prompt.json  5527_prompt.json
# 10027_prompt.json  14528_prompt.json  19028_prompt.json  5528_prompt.json
# 10028_prompt.json  14529_prompt.json  19029_prompt.json  5529_prompt.json
# 10029_prompt.json  1452_prompt.json   1902_prompt.json	 552_prompt.json
# 1002_prompt.json   14530_prompt.json  19030_prompt.json  5530_prompt.json
# 10030_prompt.json  14531_prompt.json  19031_prompt.json  5531_prompt.json
# 10031_prompt.json  14532_prompt.json  19032_prompt.json  5532_prompt.json
# 10032_prompt.json  14533_prompt.json  19033_prompt.json  5533_prompt.json
# 10033_prompt.json  14534_prompt.json  19034_prompt.json  5534_prompt.json
# 10034_prompt.json  14535_prompt.json  19035_prompt.json  5535_prompt.json
# 10035_prompt.json  14536_prompt.json  19036_prompt.json  5536_prompt.json
# 10036_prompt.json  14537_prompt.json  19037_prompt.json  5537_prompt.json
# 10037_prompt.json  14538_prompt.json  19038_prompt.json  5538_prompt.json
# 10038_prompt.json  14539_prompt.json  19039_prompt.json  5539_prompt.json
# 10327_prompt.json  14828_prompt.json  19328_prompt.json  5828_prompt.json
# 10328_prompt.json  14829_prompt.json  19329_prompt.json  5829_prompt.json
# 10329_prompt.json  1482_prompt.json   1932_prompt.json	 582_prompt.json
# 1032_prompt.json   14830_prompt.json  19330_prompt.json  5830_prompt.json
# 10330_prompt.json  14831_prompt.json  19331_prompt.json  5831_prompt.json
# 10331_prompt.json  14832_prompt.json  19332_prompt.json  5832_prompt.json
# 10332_prompt.json  14833_prompt.json  19333_prompt.json  5833_prompt.json
# 10333_prompt.json  14834_prompt.json  19334_prompt.json  5834_prompt.json
# 10334_prompt.json  14835_prompt.json  19335_prompt.json  5835_prompt.json
# 10335_prompt.json  14836_prompt.json  19336_prompt.json  5836_prompt.json
# 10336_prompt.json  14837_prompt.json  19337_prompt.json  5837_prompt.json
# 10337_prompt.json  14838_prompt.json  19338_prompt.json  5838_prompt.json
# 10338_prompt.json  14839_prompt.json  19339_prompt.json  5839_prompt.json
# 10339_prompt.json  1483_prompt.json   1933_prompt.json	 583_prompt.json
# 1033_prompt.json   14840_prompt.json  19340_prompt.json  5840_prompt.json
# 10340_prompt.json  14841_prompt.json  19341_prompt.json  5841_prompt.json
# 10341_prompt.json  14842_prompt.json  19342_prompt.json  5842_prompt.json
# 10342_prompt.json  14843_prompt.json  19343_prompt.json  5843_prompt.json
# 10343_prompt.json  14844_prompt.json  19344_prompt.json  5844_prompt.json
# 10344_prompt.json  14845_prompt.json  19345_prompt.json  5845_prompt.json
# 10345_prompt.json  14846_prompt.json  19346_prompt.json  5846_prompt.json
# 10346_prompt.json  14847_prompt.json  19347_prompt.json  5847_prompt.json
# 10347_prompt.json  14848_prompt.json  19348_prompt.json  5848_prompt.json
# 10348_prompt.json  14849_prompt.json  19349_prompt.json  5849_prompt.json
# 10349_prompt.json  1484_prompt.json   1934_prompt.json	 584_prompt.json
# 1034_prompt.json   14850_prompt.json  19350_prompt.json  5850_prompt.json
# 10350_prompt.json  14851_prompt.json  19351_prompt.json  5851_prompt.json
# 10351_prompt.json  14852_prompt.json  19352_prompt.json  5852_prompt.json
# 10352_prompt.json  14853_prompt.json  19353_prompt.json  5853_prompt.json
# 10353_prompt.json  14854_prompt.json  19354_prompt.json  5854_prompt.json
# 10354_prompt.json  14855_prompt.json  19355_prompt.json  5855_prompt.json
# 10355_prompt.json  14856_prompt.json  19356_prompt.json  5856_prompt.json
# 10356_prompt.json  14857_prompt.json  19357_prompt.json  5857_prompt.json
# 10357_prompt.json  14858_prompt.json  19358_prompt.json  5858_prompt.json
# 10358_prompt.json  14859_prompt.json  19359_prompt.json  5859_prompt.json
# 10359_prompt.json  1485_prompt.json   1935_prompt.json	 585_prompt.json
# 1035_prompt.json   14860_prompt.json  19360_prompt.json  5860_prompt.json
# 10360_prompt.json  14861_prompt.json  19361_prompt.json  5861_prompt.json
# 10361_prompt.json  14862_prompt.json  19362_prompt.json  5862_prompt.json
# 10362_prompt.json  14863_prompt.json  19363_prompt.json  5863_prompt.json
# 10580_prompt.json  15080_prompt.json  19581_prompt.json  6080_prompt.json
# 10581_prompt.json  15081_prompt.json  19582_prompt.json  6081_prompt.json
# 10582_prompt.json  15082_prompt.json  19583_prompt.json  6082_prompt.json
# 10583_prompt.json  15083_prompt.json  19584_prompt.json  6083_prompt.json
# 10584_prompt.json  15084_prompt.json  19585_prompt.json  6084_prompt.json
# 10585_prompt.json  15085_prompt.json  19586_prompt.json  6085_prompt.json
# ...
# 14303_prompt.json  18804_prompt.json  5303_prompt.json	 9804_prompt.json
# 14304_prompt.json  18805_prompt.json  5304_prompt.json	 9805_prompt.json
# 14305_prompt.json  18806_prompt.json  5305_prompt.json	 9806_prompt.json
# 14306_prompt.json  18807_prompt.json  5306_prompt.json	 9807_prompt.json
# 14307_prompt.json  18808_prompt.json  5307_prompt.json	 9808_prompt.json
# 14308_prompt.json  18809_prompt.json  5308_prompt.json	 9809_prompt.json
# 14309_prompt.json  1880_prompt.json   5309_prompt.json	 980_prompt.json
# 1430_prompt.json   18810_prompt.json  530_prompt.json	 9810_prompt.json
# 14310_prompt.json  18811_prompt.json  5310_prompt.json	 9811_prompt.json
# 14311_prompt.json  18812_prompt.json  5311_prompt.json	 9812_prompt.json
# 14312_prompt.json  18813_prompt.json  5312_prompt.json	 9813_prompt.json
# 14313_prompt.json  18814_prompt.json  5313_prompt.json	 9814_prompt.json
# 14314_prompt.json  18815_prompt.json  5314_prompt.json	 9815_prompt.json
# 14315_prompt.json  18816_prompt.json  5315_prompt.json	 9816_prompt.json
# 14316_prompt.json  18817_prompt.json  5316_prompt.json	 9817_prompt.json
# 14317_prompt.json  18818_prompt.json  5317_prompt.json	 9818_prompt.json
# 14318_prompt.json  18819_prompt.json  5318_prompt.json	 9819_prompt.json
# 14319_prompt.json  1881_prompt.json   5319_prompt.json	 981_prompt.json
# 1431_prompt.json   18820_prompt.json  531_prompt.json	 9820_prompt.json
# 14320_prompt.json  18821_prompt.json  5320_prompt.json	 9821_prompt.json
# 14321_prompt.json  18822_prompt.json  5321_prompt.json	 9822_prompt.json
# 14322_prompt.json  18823_prompt.json  5322_prompt.json	 9823_prompt.json
# 14323_prompt.json  18824_prompt.json  5323_prompt.json	 9824_prompt.json
# 14324_prompt.json  18825_prompt.json  5324_prompt.json	 9825_prompt.json
# 14325_prompt.json  18826_prompt.json  5325_prompt.json	 9826_prompt.json
# 14326_prompt.json  18827_prompt.json  5326_prompt.json	 9827_prompt.json
# 14327_prompt.json  18828_prompt.json  5327_prompt.json	 9828_prompt.json
# 14328_prompt.json  18829_prompt.json  5328_prompt.json	 9829_prompt.json
# 14329_prompt.json  1882_prompt.json   5329_prompt.json	 982_prompt.json
# 1432_prompt.json   18830_prompt.json  532_prompt.json	 9830_prompt.json
# 14330_prompt.json  18831_prompt.json  5330_prompt.json	 9831_prompt.json
# 14331_prompt.json  18832_prompt.json  5331_prompt.json	 9832_prompt.json
# 14332_prompt.json  18833_prompt.json  5332_prompt.json	 9833_prompt.json
# 14333_prompt.json  18834_prompt.json  5333_prompt.json	 9834_prompt.json
# 14334_prompt.json  18835_prompt.json  5334_prompt.json	 9835_prompt.json
# 14335_prompt.json  18836_prompt.json  5335_prompt.json	 9836_prompt.json
# 14336_prompt.json  18837_prompt.json  5336_prompt.json	 9837_prompt.json
# 14337_prompt.json  18838_prompt.json  5337_prompt.json	 9838_prompt.json
# 14338_prompt.json  18839_prompt.json  5338_prompt.json	 9839_prompt.json
# 14339_prompt.json  1883_prompt.json   5339_prompt.json	 983_prompt.json
# 1433_prompt.json   18840_prompt.json  533_prompt.json	 9840_prompt.json
# 14340_prompt.json  18841_prompt.json  5340_prompt.json	 9841_prompt.json
# 14341_prompt.json  18842_prompt.json  5341_prompt.json	 9842_prompt.json
# 14342_prompt.json  18843_prompt.json  5342_prompt.json	 9843_prompt.json
# 14343_prompt.json  18844_prompt.json  5343_prompt.json	 9844_prompt.json
# 14344_prompt.json  18845_prompt.json  5344_prompt.json	 9845_prompt.json
# 14345_prompt.json  18846_prompt.json  5345_prompt.json	 9846_prompt.json
# 14346_prompt.json  18847_prompt.json  5346_prompt.json	 9847_prompt.json
# 14347_prompt.json  18848_prompt.json  5347_prompt.json	 9848_prompt.json
# 14348_prompt.json  18849_prompt.json  5348_prompt.json	 9849_prompt.json
# 14349_prompt.json  1884_prompt.json   5349_prompt.json	 984_prompt.json
# 1434_prompt.json   18850_prompt.json  534_prompt.json	 9850_prompt.json
# 14350_prompt.json  18851_prompt.json  5350_prompt.json	 9851_prompt.json
# 14351_prompt.json  18852_prompt.json  5351_prompt.json	 9852_prompt.json
# 14352_prompt.json  18853_prompt.json  5352_prompt.json	 9853_prompt.json
# 14353_prompt.json  18854_prompt.json  5353_prompt.json	 9854_prompt.json
# 14354_prompt.json  18855_prompt.json  5354_prompt.json	 9855_prompt.json
# 14355_prompt.json  18856_prompt.json  5355_prompt.json	 9856_prompt.json
# 14356_prompt.json  18857_prompt.json  5356_prompt.json	 9857_prompt.json
# 14357_prompt.json  18858_prompt.json  5357_prompt.json	 9858_prompt.json
# 14358_prompt.json  18859_prompt.json  5358_prompt.json	 9859_prompt.json
# 14359_prompt.json  1885_prompt.json   5359_prompt.json	 985_prompt.json
# 1435_prompt.json   18860_prompt.json  535_prompt.json	 9860_prompt.json
# 14360_prompt.json  18861_prompt.json  5360_prompt.json	 9861_prompt.json
# 14361_prompt.json  18862_prompt.json  5361_prompt.json	 9862_prompt.json
# 14362_prompt.json  18863_prompt.json  5362_prompt.json	 9863_prompt.json
# 14363_prompt.json  18864_prompt.json  5363_prompt.json	 9864_prompt.json
# 14364_prompt.json  18865_prompt.json  5364_prompt.json	 9865_prompt.json
# 14365_prompt.json  18866_prompt.json  5365_prompt.json	 9866_prompt.json
# 14366_prompt.json  18867_prompt.json  5366_prompt.json	 9867_prompt.json
# 14367_prompt.json  18868_prompt.json  5367_prompt.json	 9868_prompt.json
# 14368_prompt.json  18869_prompt.json  5368_prompt.json	 9869_prompt.json
# 14369_prompt.json  1886_prompt.json   5369_prompt.json	 986_prompt.json
# 1436_prompt.json   18870_prompt.json  536_prompt.json	 9870_prompt.json
# 14370_prompt.json  18871_prompt.json  5370_prompt.json	 9871_prompt.json
# 14371_prompt.json  18872_prompt.json  5371_prompt.json	 9872_prompt.json
# 14372_prompt.json  18873_prompt.json  5372_prompt.json	 9873_prompt.json
# 14373_prompt.json  18874_prompt.json  5373_prompt.json	 9874_prompt.json
# 14374_prompt.json  18875_prompt.json  5374_prompt.json	 9875_prompt.json
# 14375_prompt.json  18876_prompt.json  5375_prompt.json	 9876_prompt.json
# 14376_prompt.json  18877_prompt.json  5376_prompt.json	 9877_prompt.json
# 14377_prompt.json  18878_prompt.json  5377_prompt.json	 9878_prompt.json
# 14378_prompt.json  18879_prompt.json  5378_prompt.json	 9879_prompt.json
# 14379_prompt.json  1887_prompt.json   5379_prompt.json	 987_prompt.json
# 1437_prompt.json   18880_prompt.json  537_prompt.json	 9880_prompt.json
# 14380_prompt.json  18881_prompt.json  5380_prompt.json	 9881_prompt.json
# 14381_prompt.json  18882_prompt.json  5381_prompt.json	 9882_prompt.json
# 14382_prompt.json  18883_prompt.json  5382_prompt.json	 9883_prompt.json
# 14383_prompt.json  18884_prompt.json  5383_prompt.json	 9884_prompt.json
# 14384_prompt.json  18885_prompt.json  5384_prompt.json	 9885_prompt.json
# 14385_prompt.json  18886_prompt.json  5385_prompt.json	 9886_prompt.json
# 14386_prompt.json  18887_prompt.json  5386_prompt.json	 9887_prompt.json
# 14387_prompt.json  18888_prompt.json  5387_prompt.json	 9888_prompt.json
# 14388_prompt.json  18889_prompt.json  5388_prompt.json	 9889_prompt.json
# 14389_prompt.json  1888_prompt.json   5389_prompt.json	 988_prompt.json
# 1438_prompt.json   18890_prompt.json  538_prompt.json	 9890_prompt.json
# 14390_prompt.json  18891_prompt.json  5390_prompt.json	 9891_prompt.json
# 14391_prompt.json  18892_prompt.json  5391_prompt.json	 9892_prompt.json
# 14392_prompt.json  18893_prompt.json  5392_prompt.json	 9893_prompt.json
# 14393_prompt.json  18894_prompt.json  5393_prompt.json	 9894_prompt.json
# 14394_prompt.json  18895_prompt.json  5394_prompt.json	 9895_prompt.json
# 14395_prompt.json  18896_prompt.json  5395_prompt.json	 9896_prompt.json
# 14396_prompt.json  18897_prompt.json  5396_prompt.json	 9897_prompt.json
# 14397_prompt.json  18898_prompt.json  5397_prompt.json	 9898_prompt.json
# 14398_prompt.json  18899_prompt.json  5398_prompt.json	 9899_prompt.json
# 14399_prompt.json  1889_prompt.json   5399_prompt.json	 989_prompt.json
# 1439_prompt.json   188_prompt.json    539_prompt.json	 98_prompt.json
# 143_prompt.json    18900_prompt.json  53_prompt.json	 9900_prompt.json
# 14400_prompt.json  18901_prompt.json  5400_prompt.json	 9901_prompt.json
# 14401_prompt.json  18902_prompt.json  5401_prompt.json	 9902_prompt.json
# 14402_prompt.json  18903_prompt.json  5402_prompt.json	 9903_prompt.json
# 14403_prompt.json  18904_prompt.json  5403_prompt.json	 9904_prompt.json
# 14404_prompt.json  18905_prompt.json  5404_prompt.json	 9905_prompt.json
# 14405_prompt.json  18906_prompt.json  5405_prompt.json	 9906_prompt.json
# 14406_prompt.json  18907_prompt.json  5406_prompt.json	 9907_prompt.json
# 14407_prompt.json  18908_prompt.json  5407_prompt.json	 9908_prompt.json
# 14408_prompt.json  18909_prompt.json  5408_prompt.json	 9909_prompt.json
# 14409_prompt.json  1890_prompt.json   5409_prompt.json	 990_prompt.json
# 1440_prompt.json   18910_prompt.json  540_prompt.json	 9910_prompt.json
# 14410_prompt.json  18911_prompt.json  5410_prompt.json	 9911_prompt.json
# 14411_prompt.json  18912_prompt.json  5411_prompt.json	 9912_prompt.json
# 14412_prompt.json  18913_prompt.json  5412_prompt.json	 9913_prompt.json
# 14413_prompt.json  18914_prompt.json  5413_prompt.json	 9914_prompt.json
# 14414_prompt.json  18915_prompt.json  5414_prompt.json	 9915_prompt.json
# 14415_prompt.json  18916_prompt.json  5415_prompt.json	 9916_prompt.json
# 14416_prompt.json  18917_prompt.json  5416_prompt.json	 9917_prompt.json
# 14417_prompt.json  18918_prompt.json  5417_prompt.json	 9918_prompt.json
# 14418_prompt.json  18919_prompt.json  5418_prompt.json	 9919_prompt.json
# 14419_prompt.json  1891_prompt.json   5419_prompt.json	 991_prompt.json
# 1441_prompt.json   18920_prompt.json  541_prompt.json	 9920_prompt.json
# 14420_prompt.json  18921_prompt.json  5420_prompt.json	 9921_prompt.json
# 14421_prompt.json  18922_prompt.json  5421_prompt.json	 9922_prompt.json
# 14422_prompt.json  18923_prompt.json  5422_prompt.json	 9923_prompt.json
# 14423_prompt.json  18924_prompt.json  5423_prompt.json	 9924_prompt.json
# 14424_prompt.json  18925_prompt.json  5424_prompt.json	 9925_prompt.json
# 14425_prompt.json  18926_prompt.json  5425_prompt.json	 9926_prompt.json
# 14426_prompt.json  18927_prompt.json  5426_prompt.json	 9927_prompt.json
# 14427_prompt.json  18928_prompt.json  5427_prompt.json	 9928_prompt.json
# 14428_prompt.json  18929_prompt.json  5428_prompt.json	 9929_prompt.json
# 14429_prompt.json  1892_prompt.json   5429_prompt.json	 992_prompt.json
# 1442_prompt.json   18930_prompt.json  542_prompt.json	 9930_prompt.json
# 14430_prompt.json  18931_prompt.json  5430_prompt.json	 9931_prompt.json
# 14431_prompt.json  18932_prompt.json  5431_prompt.json	 9932_prompt.json
# 14432_prompt.json  18933_prompt.json  5432_prompt.json	 9933_prompt.json
# 14433_prompt.json  18934_prompt.json  5433_prompt.json	 9934_prompt.json
# 14434_prompt.json  18935_prompt.json  5434_prompt.json	 9935_prompt.json
# 14435_prompt.json  18936_prompt.json  5435_prompt.json	 9936_prompt.json
# 14436_prompt.json  18937_prompt.json  5436_prompt.json	 9937_prompt.json
# 14437_prompt.json  18938_prompt.json  5437_prompt.json	 9938_prompt.json
# 14438_prompt.json  18939_prompt.json  5438_prompt.json	 9939_prompt.json
# 14439_prompt.json  1893_prompt.json   5439_prompt.json	 993_prompt.json
# 1443_prompt.json   18940_prompt.json  543_prompt.json	 9940_prompt.json
# 14440_prompt.json  18941_prompt.json  5440_prompt.json	 9941_prompt.json
# 14441_prompt.json  18942_prompt.json  5441_prompt.json	 9942_prompt.json
# 14442_prompt.json  18943_prompt.json  5442_prompt.json	 9943_prompt.json
# 14443_prompt.json  18944_prompt.json  5443_prompt.json	 9944_prompt.json
# 14444_prompt.json  18945_prompt.json  5444_prompt.json	 9945_prompt.json
# 14445_prompt.json  18946_prompt.json  5445_prompt.json	 9946_prompt.json
# 14446_prompt.json  18947_prompt.json  5446_prompt.json	 9947_prompt.json
# 14447_prompt.json  18948_prompt.json  5447_prompt.json	 9948_prompt.json
# 14448_prompt.json  18949_prompt.json  5448_prompt.json	 9949_prompt.json
# 14449_prompt.json  1894_prompt.json   5449_prompt.json	 994_prompt.json
# 1444_prompt.json   18950_prompt.json  544_prompt.json	 9950_prompt.json
# 14450_prompt.json  18951_prompt.json  5450_prompt.json	 9951_prompt.json
# 14451_prompt.json  18952_prompt.json  5451_prompt.json	 9952_prompt.json
# 14452_prompt.json  18953_prompt.json  5452_prompt.json	 9953_prompt.json
# 14453_prompt.json  18954_prompt.json  5453_prompt.json	 9954_prompt.json
# 14454_prompt.json  18955_prompt.json  5454_prompt.json	 9955_prompt.json
# 14455_prompt.json  18956_prompt.json  5455_prompt.json	 9956_prompt.json
# 14456_prompt.json  18957_prompt.json  5456_prompt.json	 9957_prompt.json
# 14457_prompt.json  18958_prompt.json  5457_prompt.json	 9958_prompt.json
# 14458_prompt.json  18959_prompt.json  5458_prompt.json	 9959_prompt.json
# 14459_prompt.json  1895_prompt.json   5459_prompt.json	 995_prompt.json
# 1445_prompt.json   18960_prompt.json  545_prompt.json	 9960_prompt.json
# 14460_prompt.json  18961_prompt.json  5460_prompt.json	 9961_prompt.json
# 14461_prompt.json  18962_prompt.json  5461_prompt.json	 9962_prompt.json
# 14462_prompt.json  18963_prompt.json  5462_prompt.json	 9963_prompt.json
# 14463_prompt.json  18964_prompt.json  5463_prompt.json	 9964_prompt.json
# 14464_prompt.json  18965_prompt.json  5464_prompt.json	 9965_prompt.json
# 14465_prompt.json  18966_prompt.json  5465_prompt.json	 9966_prompt.json
# 14466_prompt.json  18967_prompt.json  5466_prompt.json	 9967_prompt.json
# 14467_prompt.json  18968_prompt.json  5467_prompt.json	 9968_prompt.json
# 14468_prompt.json  18969_prompt.json  5468_prompt.json	 9969_prompt.json
# 14469_prompt.json  1896_prompt.json   5469_prompt.json	 996_prompt.json
# 1446_prompt.json   18970_prompt.json  546_prompt.json	 9970_prompt.json
# 14470_prompt.json  18971_prompt.json  5470_prompt.json	 9971_prompt.json
# 14471_prompt.json  18972_prompt.json  5471_prompt.json	 9972_prompt.json
# 14472_prompt.json  18973_prompt.json  5472_prompt.json	 9973_prompt.json
# 14473_prompt.json  18974_prompt.json  5473_prompt.json	 9974_prompt.json
# 14474_prompt.json  18975_prompt.json  5474_prompt.json	 9975_prompt.json
# 14475_prompt.json  18976_prompt.json  5475_prompt.json	 9976_prompt.json
# 14476_prompt.json  18977_prompt.json  5476_prompt.json	 9977_prompt.json
# 14477_prompt.json  18978_prompt.json  5477_prompt.json	 9978_prompt.json
# 14478_prompt.json  18979_prompt.json  5478_prompt.json	 9979_prompt.json
# 14479_prompt.json  1897_prompt.json   5479_prompt.json	 997_prompt.json
# 1447_prompt.json   18980_prompt.json  547_prompt.json	 9980_prompt.json
# 14480_prompt.json  18981_prompt.json  5480_prompt.json	 9981_prompt.json
# 14481_prompt.json  18982_prompt.json  5481_prompt.json	 9982_prompt.json
# 14482_prompt.json  18983_prompt.json  5482_prompt.json	 9983_prompt.json
# 14483_prompt.json  18984_prompt.json  5483_prompt.json	 9984_prompt.json
# 14484_prompt.json  18985_prompt.json  5484_prompt.json	 9985_prompt.json
# 14485_prompt.json  18986_prompt.json  5485_prompt.json	 9986_prompt.json
# 14486_prompt.json  18987_prompt.json  5486_prompt.json	 9987_prompt.json
# 14487_prompt.json  18988_prompt.json  5487_prompt.json	 9988_prompt.json
# 14488_prompt.json  18989_prompt.json  5488_prompt.json	 9989_prompt.json
# 14489_prompt.json  1898_prompt.json   5489_prompt.json	 998_prompt.json
# 1448_prompt.json   18990_prompt.json  548_prompt.json	 9990_prompt.json
# 14490_prompt.json  18991_prompt.json  5490_prompt.json	 9991_prompt.json
# 14491_prompt.json  18992_prompt.json  5491_prompt.json	 9992_prompt.json
# 14492_prompt.json  18993_prompt.json  5492_prompt.json	 9993_prompt.json
# 14493_prompt.json  18994_prompt.json  5493_prompt.json	 9994_prompt.json
# 14494_prompt.json  18995_prompt.json  5494_prompt.json	 9995_prompt.json
# 14495_prompt.json  18996_prompt.json  5495_prompt.json	 9996_prompt.json
# 14496_prompt.json  18997_prompt.json  5496_prompt.json	 9997_prompt.json
# 14497_prompt.json  18998_prompt.json  5497_prompt.json	 9998_prompt.json
# 14498_prompt.json  18999_prompt.json  5498_prompt.json	 9999_prompt.json
# 14499_prompt.json  1899_prompt.json   5499_prompt.json	 999_prompt.json
# 1449_prompt.json   189_prompt.json    549_prompt.json	 99_prompt.json
# 144_prompt.json    18_prompt.json     54_prompt.json	 9_prompt.json

# %%
DATA_DIR = "./data_vqllm"
N_SAMPLES = 20000

def download_data(data_dir=DATA_DIR, n=N_SAMPLES):
    img_dir, pr_dir = f"{data_dir}/images", f"{data_dir}/prompts"
    if os.path.isdir(img_dir) and len(os.listdir(img_dir)) >= 2 * n:
        print("data already downloaded"); return
    os.makedirs(img_dir, exist_ok=True); os.makedirs(pr_dir, exist_ok=True)
    ds = load_dataset("timbrooks/instructpix2pix-clip-filtered", split="train", streaming=True)
    for i, e in enumerate(tqdm(ds, total=n)):
        if i >= n: break
        e["original_image"].save(f"{img_dir}/{i}_original.png")
        e["edited_image"].save(f"{img_dir}/{i}_edited.png")
        json.dump({"original_prompt": e["original_prompt"], "edit_prompt": e["edit_prompt"]},
                  open(f"{pr_dir}/{i}_prompt.json", "w"))
    print("downloaded", n)


download_data()
# Out:
# Resolving data files:   0%|          | 0/262 [00:00<?, ?it/s]
#   0%|          | 0/20000 [00:00<?, ?it/s]
# downloaded 20000

# %% [markdown]
# Пример из датасета

# %% [markdown]
# ![](./data_vqllm/images/0_original.png)
# ![](./data_vqllm/images/0_edited.png)

# %%
open("./data_vqllm/prompts/0_prompt.json").read()
# Out:
# '{"original_prompt": "Baronne James de Rothschild-nee Betty von Rothschild | Jean-Auguste-Dominique Ingres | oil painting", "edit_prompt": "Turn it into a photo"}'

# %% [markdown]
# ## Токенизация в кэш
#
# Мы можем заранее прогнать все картинки через токенизитор vq и сохранить их на диске, чтобы чуть чуть сэкономить время обучения

# %%
def build_token_cache(data_dir=DATA_DIR, image_size=256):
    pkl_dir = f"{data_dir}/pickles"; os.makedirs(pkl_dir, exist_ok=True)
    ids = sorted(int(f.split("_")[0]) for f in os.listdir(f"{data_dir}/prompts") if f.endswith("json"))
    for item in tqdm(ids):
        dst = f"{pkl_dir}/{item}.pkl"
        if os.path.exists(dst): continue
        pr = json.load(open(f"{data_dir}/prompts/{item}_prompt.json"))
        text = f"Original image description: {pr['original_prompt']}; Prompt: {pr['edit_prompt']}; Answer:"
        orig = lg_encode_indices(Image.open(f"{data_dir}/images/{item}_original.png"), image_size)
        edit = lg_encode_indices(Image.open(f"{data_dir}/images/{item}_edited.png"), image_size)
        pickle.dump({"original_image": orig, "edited_image": edit, "text_data": text}, open(dst, "wb"))
    print("cached", len(ids))


build_token_cache()
# Out:
#   0%|          | 0/20000 [00:00<?, ?it/s]
# cached 20000

# %% [markdown]
# ## Датасет и коллатор
#
# У нас два токенизитора и их нужно соединить в один поток токенов. У этих токенизитор разные пересекающиеся индексы. Чтобы их совместить мы можем просто взять наш текстовый токенизатор, посчитать его размер и ко всем индексам из картиночных токенов просто добавить это числа.
#
# Если у нас изначально что-то такое:
# `[1, 2, 3] + [1,2]` (сначала текстовые потом картиночные токены)
# То после такой операции будет:
# `[1, 2, 3] + [4, 5]` (3 это размер словаря текстов и если мы его добавим то картиночные сдвинуться)
#
# Таким образом текстовые и картиночные токены будет в одном пространстве, но при этом не будут пересекаться! На раскодировке мы просто вычтем размер словаря и вернемся к обычным картиночным токенам.

# %%
class EditTokenDataset(Dataset):
    def __init__(self, data_dir, start=None, end=None):
        ids = sorted(int(f.split(".")[0]) for f in os.listdir(f"{data_dir}/pickles") if f.endswith("pkl"))
        self.ids = ids[start:end]; self.data_dir = data_dir

    def __len__(self): return len(self.ids)

    def __getitem__(self, i):
        return pickle.load(open(f"{self.data_dir}/pickles/{self.ids[i]}.pkl", "rb"))


class VQCollator:
    def __init__(self, tokenizer, max_text_len=64):
        self.tok = tokenizer
        self.offset = tokenizer.vocab_size      # визуальные токены живут выше текстовых
        self.max_text = max_text_len

    def __call__(self, batch):
        texts = self.tok([b["text_data"] for b in batch], truncation=True, max_length=self.max_text)["input_ids"]
        input_ids, labels = [], []
        for b, t_ids in zip(batch, texts):
            orig = (np.asarray(b["original_image"]).reshape(-1) + self.offset).tolist()
            edit = (np.asarray(b["edited_image"]).reshape(-1) + self.offset).tolist()
            seq = orig + t_ids + edit
            lab = [-100] * len(seq)
            start_ed = len(orig) + len(t_ids)
            # next-token: logits[j-1] предсказывает seq[j]; учим только на целевой картинке
            for j in range(start_ed, len(seq)):
                lab[j - 1] = seq[j]
            input_ids.append(seq); labels.append(lab)

        maxlen = max(len(x) for x in input_ids); pad = self.tok.pad_token_id
        attn = [[1] * len(x) + [0] * (maxlen - len(x)) for x in input_ids]
        input_ids = [x + [pad] * (maxlen - len(x)) for x in input_ids]
        labels = [x + [-100] * (maxlen - len(x)) for x in labels]
        return {
            "input_ids": torch.tensor(input_ids, dtype=torch.long),
            "attention_mask": torch.tensor(attn, dtype=torch.long),
            "labels": torch.tensor(labels, dtype=torch.long),
        }

# %% [markdown]
# ## Языковая модель
# Обучать будет какую-нибудь очень маленькую модель, например `SmolLM2-135M`
# Это Llama-подобный декодер из [nanoVLM](https://huggingface.co/blog/nanovlm). Словарь расширяем на размер codebook (`49152 + 16384`), `from_pretrained` сам аккуратно достраивает матрицу эмбеддингов для новых визуальных токенов.
# LLM уже знакома с текстовыми токенами, но для всех токенов, которые мы будем передавать для картинок у нее не будет эмбедингов и они будет выучены с нуля.

# %% [markdown]
# Дальше просто код трансформера аналогичный тому, чтобы делали в прошлых семинарах. Но тут код вытащен из llama в transformers

# %%
def top_k_top_p_filtering(logits, top_k=0, top_p=1.0, filter_value=-float('Inf')):
    """
    Apply top-k and/or nucleus (top-p) filtering to logits.
    """
    top_k = min(top_k, logits.size(-1))  # Safety

    if top_k > 0:
        # Remove all tokens with a probability less than the top-k tokens
        indices_to_remove = logits < torch.topk(logits, top_k)[0][..., -1, None]
        logits = logits.masked_fill(indices_to_remove, filter_value)

    if top_p < 1.0:
        sorted_logits, sorted_indices = torch.sort(logits, descending=True)
        cumulative_probs = torch.softmax(sorted_logits, dim=-1).cumsum(dim=-1)

        # Remove tokens with cumulative probability above top_p
        sorted_indices_to_remove = cumulative_probs > top_p

        # Always keep the first token
        sorted_indices_to_remove[..., 0] = False
        
        indices_to_remove = sorted_indices_to_remove.scatter(1, sorted_indices, sorted_indices_to_remove)
        logits = logits.masked_fill(indices_to_remove, filter_value)

    return logits

# %%
# https://github.com/huggingface/transformers/blob/main/src/transformers/models/llama/modeling_llama.py#L69
class RMSNorm(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.weight = nn.Parameter(torch.ones(cfg.lm_hidden_dim))
        self.eps = cfg.lm_rms_eps

    def forward(self, x):
        irms = torch.rsqrt(torch.mean(x ** 2, dim=-1, keepdim=True) + self.eps) # inverse of RMS
        x = x * irms * self.weight

        return x


class RotaryEmbedding(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        assert cfg.lm_hidden_dim % cfg.lm_n_heads == 0, "Hidden dimension must be divisible by number of heads"
        
        self.dim = cfg.lm_hidden_dim // cfg.lm_n_heads # dim of each head
        self.base = cfg.lm_re_base
        self.max_seq_len = cfg.lm_max_position_embeddings
        # Standard RoPE implementation - create frequencies for each dimension
        # freq_i = 1 / (base^(2i/dim)) where i is the dimension index
        inv_freq = 1.0 / (self.base ** (torch.arange(0, self.dim, 2).float() / self.dim))
        self.register_buffer("inv_freq", inv_freq)
        self.original_max_seq_len = cfg.lm_max_position_embeddings
        self.attention_scaling = cfg.lm_attn_scaling

    # @torch.no_grad()
    def forward(self, position_ids):
        batch_size, seq_len = position_ids.shape
        # Dynamic scaling for longer sequences
        max_seq = position_ids.max() + 1
        if max_seq > self.original_max_seq_len:
            scale = max_seq / self.original_max_seq_len
            inv_freq = self.inv_freq / scale
        else:
            inv_freq = self.inv_freq
            
        # Compute theta = position * frequency
        # Flatten position_ids for batch processing
        flat_position_ids = position_ids.reshape(-1).float()
        
        # Element-wise outer product: [seq_len] x [dim/2] => [seq_len, dim/2]
        freqs = flat_position_ids.unsqueeze(-1) * inv_freq.unsqueeze(0)
        
        # Reshape to include batch dimension
        freqs = freqs.reshape(batch_size, seq_len, -1)
        
        # Now create interleaved pattern
        emb = torch.cat([freqs, freqs], dim=-1)
        
        # Compute cos and sin
        cos = torch.cos(emb) * self.attention_scaling
        sin = torch.sin(emb) * self.attention_scaling
        
        return cos, sin

# Rotates half the hidden dims of the input by swapping and negating dimensions.
def rotate_half(x):
    x1, x2 = x.chunk(2, dim=-1)
    return torch.cat((-x2, x1), dim=-1)

# Apply rotary position embeddings to queries and keys.
def apply_rotary_pos_embd(q, k, cos, sin, unsqueeze_dim=1):
    # We need to make sure cos and sin can be properly broadcast
    # to the shape of q and k by adding the heads dimension
    cos = cos.unsqueeze(unsqueeze_dim)  # [batch_size, 1, seq_len, head_dim]
    sin = sin.unsqueeze(unsqueeze_dim)  # [batch_size, 1, seq_len, head_dim]
    
    # Apply complex multiplication:
    # (q * cos) + (rotate_half(q) * sin)
    q_embed = (q * cos) + (rotate_half(q) * sin)
    k_embed = (k * cos) + (rotate_half(k) * sin)
    
    return q_embed, k_embed

# https://github.com/huggingface/transformers/blob/main/src/transformers/models/llama/modeling_llama.py#L214
# https://github.com/huggingface/smollm/blob/main/vision/m4/models/vllama3/modeling_vllama3.py#L382
class LanguageModelGroupedQueryAttention(nn.Module):
    def __init__(self, cfg):
        super().__init__()

        self.n_heads = cfg.lm_n_heads
        self.n_kv_heads = cfg.lm_n_kv_heads
        self.embd_dim = cfg.lm_hidden_dim
        self.dropout = cfg.lm_dropout

        assert self.n_heads % self.n_kv_heads == 0, "n_heads must be divisible by n_kv_heads"
        assert self.embd_dim % self.n_heads == 0, "embd_dim must be divisible by num_heads"

        self.n_kv_groups = self.n_heads // self.n_kv_heads
        self.head_dim = self.embd_dim // self.n_heads

        self.q_proj = nn.Linear(self.embd_dim, self.embd_dim, bias=False)
        self.k_proj = nn.Linear(self.embd_dim, self.head_dim * self.n_kv_heads, bias=False)
        self.v_proj = nn.Linear(self.embd_dim, self.head_dim * self.n_kv_heads, bias=False)
        self.out_proj = nn.Linear(self.embd_dim, self.embd_dim, bias=False)

        self.attn_dropout = nn.Dropout(self.dropout)
        self.resid_dropout = nn.Dropout(self.dropout)

        # Use scaled dot product attention if available
        # self.sdpa = hasattr(torch.nn.functional, 'scaled_dot_product_attention')
        self.sdpa = False
        # if not self.sdpa:
        #     print("Warning: scaled dot product attention not available, using standard attention in LM.")

    def forward(self, x, cos, sin, attention_mask=None):
        B, T, C = x.size()

        q = self.q_proj(x).view(B, T, self.n_heads, self.head_dim).transpose(1, 2)  # (B, n_heads, T, head_dim)
        k = self.k_proj(x).view(B, T, self.n_kv_heads, self.head_dim).transpose(1, 2)  # (B, n_kv_heads, T, head_dim)
        v = self.v_proj(x).view(B, T, self.n_kv_heads, self.head_dim).transpose(1, 2)  # (B, n_kv_heads, T, head_dim)
        
        # Use precomputed positional embeddings
        q, k = apply_rotary_pos_embd(q, k, cos, sin)

        k = k.repeat_interleave(self.n_kv_groups, dim=1)
        v = v.repeat_interleave(self.n_kv_groups, dim=1)

        # Process attention mask if provided
        if attention_mask is not None:
            # Create a 4D attention mask [batch_size, 1, 1, seq_length], In this format, 1 = attend, 0 = mask
            attention_mask = attention_mask.unsqueeze(1).unsqueeze(2)  # [B, 1, 1, T]
            padding_mask = (attention_mask == 0).transpose(-1, -2) # Use this for the manual path
            # Convert to attention mask where 0 keeps values and -inf masks
            attention_mask = (1.0 - attention_mask) * torch.finfo(q.dtype).min

        if self.sdpa:
            y = torch.nn.functional.scaled_dot_product_attention(
                q, k, v,
                attn_mask=attention_mask,
                dropout_p=self.dropout if self.training else 0.0,
                is_causal=True # LM attention is causal (masked)
            )
        else:
            attn = torch.matmul(q, k.transpose(2, 3)) / math.sqrt(self.head_dim)
            causal_mask = torch.tril(torch.ones(T, T, device=x.device)).view(1, 1, T, T)
            attn = attn.masked_fill(causal_mask == 0, float('-inf'))
            if attention_mask is not None:
                attn = attn + attention_mask 

            attn = F.softmax(attn, dim=-1)
            attn = self.attn_dropout(attn)
            y = attn @ v
            
            if attention_mask is not None:
                y = y.masked_fill(padding_mask, 0.0) # Zero out the padded positions in the output

        y = y.transpose(1, 2).contiguous().view(B, T, C)  
        y = self.out_proj(y)
        y = self.resid_dropout(y)

        return y

# https://github.com/huggingface/transformers/blob/main/src/transformers/models/llama/modeling_llama.py#L160
class LanguageModelMLP(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.embd_dim = cfg.lm_hidden_dim
        self.inter_dim = cfg.lm_inter_dim

        self.activation_fn = F.silu
        self.gate_proj = nn.Linear(self.embd_dim, self.inter_dim, bias=False)
        self.up_proj = nn.Linear(self.embd_dim, self.inter_dim, bias=False)
        self.down_proj = nn.Linear(self.inter_dim, self.embd_dim, bias=False)

    def forward(self, x):
        gate = self.activation_fn(self.gate_proj(x))
        x = self.up_proj(x)
        x = self.down_proj(gate * x)

        return x

# https://github.com/meta-llama/llama3/blob/main/llama/model.py#L222
class LanguageModelBlock(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.mlp = LanguageModelMLP(cfg)
        self.attn = LanguageModelGroupedQueryAttention(cfg)
        self.norm1 = RMSNorm(cfg) # Input Norm
        self.norm2 = RMSNorm(cfg) # Post Attention Norm
    
    def forward(self, x, cos, sin, attention_mask=None):
        res = x
        x = self.norm1(x)
        x = self.attn(x, cos, sin, attention_mask)
        x = res + x

        res = x
        x = self.norm2(x)
        x = self.mlp(x)
        x = res + x

        return x

# https://github.com/meta-llama/llama3/blob/main/llama/model.py#L251
class LanguageModel(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.cfg = cfg
        self.lm_use_tokens = cfg.lm_use_tokens
        self.lm_tie_weights = cfg.lm_tie_weights

        self.token_embedding = nn.Embedding(cfg.lm_vocab_size, cfg.lm_hidden_dim)
        self.rotary_embd = RotaryEmbedding(cfg)
        self.blocks = nn.ModuleList([
            LanguageModelBlock(cfg) for _ in range(cfg.lm_n_blocks)
        ])
        self.norm = RMSNorm(cfg) # Final Norm
        self.head = nn.Linear(cfg.lm_hidden_dim, cfg.lm_vocab_size, bias=False)
        if self.lm_tie_weights:
            self.head.weight = self.token_embedding.weight

        self.apply(self._init_weights)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
        elif isinstance(module, RMSNorm):
            module.weight.data.fill_(1.0)

    def forward(self, x, attention_mask=None):

        if self.lm_use_tokens:
            x = self.token_embedding(x) # Only embed the inputs when using tokens

        B , T, _ = x.size()
        
        # Note: You could also cache these input embeddings if you want to avoid recomputing them
        position_ids = torch.arange(T, device=x.device).unsqueeze(0).expand(B, -1) # Create position ids [0, 1, 2, ..., seq_len-1]
        cos, sin = self.rotary_embd(position_ids) # Get rotary position embeddings

        for block in self.blocks:
            x = block(x, cos, sin, attention_mask)
        x = self.norm(x)

        if self.lm_use_tokens:
            x = self.head(x) # Compute logits if we are using tokens, otherwise stay in the embedding space


        return x

    @torch.no_grad()
    def generate(self, inputs, max_new_tokens=20):
        # Add batch dimension if needed
        if inputs.dim() == 1:
            inputs = inputs.unsqueeze(0)
            
        generated = inputs.clone()
        
        for _ in range(max_new_tokens):
            # Forward pass through the model
            outputs = self.forward(generated)
            last_output = outputs[:, -1, :]

            if self.lm_use_tokens:
                # Now the model outputs logits
                next_token = torch.argmax(last_output, dim=-1, keepdim=True)
                generated = torch.cat((generated, next_token), dim=-1)
            else:
                # Now the model outputs embeddings
                next_token_embedding = last_output.unsqueeze(1)  # Shape: [batch_size, 1, hidden_dim]
                generated = torch.cat((generated, next_token_embedding), dim=1)
            
            #Note: You could enable the generation to break earlier than max_new_tokens when it detects a eos token, but this does not work in batched generation (output tensors need to have the same size)
    
        return generated

    # Load the model from a pretrained HuggingFace model (we don't want to have to train the Language Backbone from scratch)
    @classmethod
    def from_pretrained(cls, cfg):
        from transformers import AutoConfig
        from huggingface_hub import hf_hub_download
        import safetensors
        import torch.nn.init as init
                
        # Load the HuggingFace config
        hf_config = AutoConfig.from_pretrained(cfg.lm_model_type)
        
        # Store original HF vocab size before we modify it
        original_vocab_size = hf_config.vocab_size
        # print(f"Original vocabulary size from pretrained model: {original_vocab_size}")
        
        # Configure model parameters from HF config
        # В свежих версиях transformers rope_theta переехал внутрь rope_parameters,
        # а часть полей может отсутствовать -- поэтому читаем через getattr с запасными
        # значениями (по умолчанию берём то, что уже лежит в нашем cfg).
        def hf_get(name, default):
            return getattr(hf_config, name, default)

        rope_theta = getattr(hf_config, "rope_theta", None)
        if rope_theta is None:
            rope_params = getattr(hf_config, "rope_parameters", None) or {}
            rope_theta = rope_params.get("rope_theta", cfg.lm_re_base)

        cfg.lm_hidden_dim = hf_get("hidden_size", cfg.lm_hidden_dim)
        cfg.lm_inter_dim = hf_get("intermediate_size", cfg.lm_inter_dim)
        cfg.lm_rms_eps = hf_get("rms_norm_eps", cfg.lm_rms_eps)
        cfg.lm_re_base = rope_theta
        cfg.lm_max_position_embeddings = hf_get("max_position_embeddings", cfg.lm_max_position_embeddings)
        # We're keeping our own vocab size in cfg, but checking it's larger than original
        if hasattr(cfg, 'lm_vocab_size'):
            if cfg.lm_vocab_size < original_vocab_size:
                raise ValueError(f"Config vocab size ({cfg.lm_vocab_size}) is smaller than pretrained model vocab size ({original_vocab_size})")
            # print(f"Using vocabulary size: {cfg.lm_vocab_size}")
        else:
            # If not specified, use the original
            cfg.lm_vocab_size = original_vocab_size
            # print(f"Using original vocabulary size: {cfg.lm_vocab_size}")
        
        cfg.lm_n_heads = hf_get("num_attention_heads", cfg.lm_n_heads)
        cfg.lm_n_kv_heads = hf_get("num_key_value_heads", cfg.lm_n_kv_heads)
        cfg.lm_dropout = hf_get("attention_dropout", cfg.lm_dropout)
        cfg.lm_n_blocks = hf_get("num_hidden_layers", cfg.lm_n_blocks)
        
        # Create our model with potentially larger vocabulary
        model = cls(cfg)
        safetensors_file = hf_hub_download(repo_id=cfg.lm_model_type, filename="model.safetensors")
        
        sd = model.state_dict()
        
        mapping = {
            'model.embed_tokens.weight': 'token_embedding.weight',
            'model.norm.weight': 'norm.weight'
        }
        
        for i in range(cfg.lm_n_blocks):
            layer_prefix = f'model.layers.{i}.'
            block_prefix = f'blocks.{i}.'
            
            mapping.update({
                f"{layer_prefix}self_attn.q_proj.weight": f"{block_prefix}attn.q_proj.weight",
                f"{layer_prefix}self_attn.k_proj.weight": f"{block_prefix}attn.k_proj.weight",
                f"{layer_prefix}self_attn.v_proj.weight": f"{block_prefix}attn.v_proj.weight",
                f"{layer_prefix}self_attn.o_proj.weight": f"{block_prefix}attn.out_proj.weight",
                f"{layer_prefix}mlp.gate_proj.weight": f"{block_prefix}mlp.gate_proj.weight",
                f"{layer_prefix}mlp.up_proj.weight": f"{block_prefix}mlp.up_proj.weight",
                f"{layer_prefix}mlp.down_proj.weight": f"{block_prefix}mlp.down_proj.weight",
                f"{layer_prefix}input_layernorm.weight": f"{block_prefix}norm1.weight",
                f"{layer_prefix}post_attention_layernorm.weight": f"{block_prefix}norm2.weight"
            })
        
        # Special handling for token embeddings with extended vocabulary
        has_extended_embeddings = False
        with safetensors.safe_open(filename=safetensors_file, framework="pt", device="cpu") as f:
            for hf_key, our_key in mapping.items():
                if hf_key in f.keys() and our_key in sd:
                    tensor = f.get_tensor(hf_key)
                    
                    # Special handling for token embeddings if vocab sizes differ
                    if hf_key == 'model.embed_tokens.weight' and tensor.shape[0] != sd[our_key].shape[0]:
                        has_extended_embeddings = True
                        print(f"Extending token embeddings from {tensor.shape} to {sd[our_key].shape}")
                        
                        # Copy existing embeddings to the beginning of our larger embedding matrix
                        sd[our_key][:tensor.shape[0]].copy_(tensor)
                        
                        # Initialize the new embeddings using the same approach as the original model
                        std = 0.02  # Common value, but you might want to adjust based on model
                        init.normal_(sd[our_key][tensor.shape[0]:], mean=0.0, std=std)
                        
                        print(f"Initialized {sd[our_key].shape[0] - tensor.shape[0]} new token embeddings")
                        sd['head.weight'].copy_(sd[our_key])  # Update the head weights as well
                    elif tensor.shape == sd[our_key].shape:
                        sd[our_key].copy_(tensor)
                    else:
                        print(f"Shape mismatch for {hf_key} -> {our_key}: {tensor.shape} vs {sd[our_key].shape}")
                else:
                    if hf_key not in f.keys():
                        print(f"Warning: Key {hf_key} not found in safetensors file")
                    if our_key not in sd:
                        print(f"Warning: Key {our_key} not found in model state dict")
        
        # Load the state dict
        model.load_state_dict(sd)
        
        # Handle output projection / language modeling head
        if has_extended_embeddings and hasattr(model, 'head') and 'head.weight' in sd:
            # If we have a separate output projection layer and extended the vocab
            # we should handle it similarly to the input embeddings
            with safetensors.safe_open(filename=safetensors_file, framework="pt", device="cpu") as f:
                if 'lm_head.weight' in f.keys():
                    lm_head = f.get_tensor('lm_head.weight')
                    if lm_head.shape[0] != sd['head.weight'].shape[0]:
                        print(f"Extending LM head from {lm_head.shape} to {sd['head.weight'].shape}")
                        # Copy existing weights
                        sd['head.weight'][:lm_head.shape[0]].copy_(lm_head)
                        # Initialize new weights
                        std = 0.02
                        init.normal_(sd['head.weight'][lm_head.shape[0]:], mean=0.0, std=std)
                        # Load updated weights
                        model.load_state_dict(sd)
        
        # Handle weight tying (if needed)
        if cfg.lm_tie_weights and hasattr(model, 'head') and hasattr(model, 'token_embedding'):
            model.head.weight = model.token_embedding.weight
            # print("Tied token embedding and LM head weights")
        
        print(f"Successfully loaded {cfg.lm_model_type} weights from safetensors. Model has {sum(p.numel() for p in model.parameters()):,} parameters.")
        return model

# %% [markdown]
# Тонкая обёртка: forward с CE-лоссом + авторегрессионная генерация.

# %%
class VisionLanguageModel(nn.Module):
    def __init__(self, cfg, load_backbone=True):
        super().__init__()
        self.cfg = cfg
        self.decoder = LanguageModel.from_pretrained(cfg) if load_backbone else LanguageModel(cfg)

    def forward(self, input_ids, attention_mask=None, targets=None):
        logits = self.decoder(input_ids, attention_mask)   # lm_use_tokens=True -> сразу логиты
        loss = None
        if targets is not None:
            loss = F.cross_entropy(logits.reshape(-1, logits.size(-1)), targets.reshape(-1), ignore_index=-100)
        return logits, loss

    @torch.no_grad()
    def generate(self, input_ids, attention_mask=None, max_new_tokens=256,
                 top_k=100, top_p=0.9, temperature=1.0, greedy=False):
        was_training = self.training
        self.eval()
        out = input_ids
        gen = []
        for _ in range(max_new_tokens):
            logits = self.decoder(out, attention_mask)[:, -1, :]
            if greedy:
                nxt = logits.argmax(-1, keepdim=True)
            else:
                filt = top_k_top_p_filtering(logits, top_k=top_k, top_p=top_p)
                probs = torch.softmax(filt / temperature, dim=-1)
                nxt = torch.multinomial(probs, num_samples=1)
            gen.append(nxt)
            out = torch.cat([out, nxt], dim=1)
            if attention_mask is not None:
                ones = torch.ones(out.size(0), 1, dtype=attention_mask.dtype, device=attention_mask.device)
                attention_mask = torch.cat([attention_mask, ones], dim=1)
        self.train(was_training)
        return torch.cat(gen, dim=1)

# %% [markdown]
# ## Конфиг

# %%
@dataclass
class VLMConfig:
    lm_hidden_dim: int = 576
    lm_inter_dim: int = 1536
    lm_rms_eps: float = 1e-5
    lm_re_base: int = 100000
    lm_max_position_embeddings: int = 8192
    lm_vocab_size: int = 49152 + 16384      # текст + codebook LlamaGen
    lm_n_heads: int = 9
    lm_n_kv_heads: int = 3
    lm_dropout: float = 0.0
    lm_n_blocks: int = 30
    lm_attn_scaling: float = 1.0
    lm_use_tokens: bool = True              # всё -- токены (общий словарь)
    lm_tie_weights: bool = True
    lm_model_type: str = "HuggingFaceTB/SmolLM2-135M"
    lm_tokenizer: str = "HuggingFaceTB/cosmo2-tokenizer"
    lm_eos_token_id: int = 0


@dataclass
class TrainConfig:
    lr: float = 5e-4
    epochs: int = 20
    batch_size: int = 8
    train_samples: int = 20000
    val_samples: int = 100
    resume_checkpoint: Optional[str] = None   # путь к .pt, чтобы продолжить обучение (иначе с нуля)

# %% [markdown]
# ## Обучение
#
# После каждой эпохи прогоняем фиксированный пример (исходная картинка + инструкция → картинка) и сохраняем результат в `results_vqonly/`, чтобы видеть прогресс.

# %%
def get_lr(it, max_lr, max_steps):
    min_lr = max_lr * 0.1
    warmup_steps = max_steps * 0.03
    # 1) linear warmup for warmup_iters steps
    if it < warmup_steps:
        return max_lr * (it+1) / warmup_steps
    # 2) if it > lr_decay_iters, return min learning rate
    if it > max_steps:
        return min_lr
    # 3) in between, use cosine decay down to min learning rate
    decay_ratio = (it - warmup_steps) / (max_steps - warmup_steps)
    assert 0 <= decay_ratio <= 1
    coeff = 0.5 * (1.0 + math.cos(math.pi * decay_ratio)) # coeff starts at 1 and goes to 0
    return min_lr + coeff * (max_lr - min_lr)

# %%
def get_eval_example(data_dir=DATA_DIR, idx=None):
    # берём пример из ВАЛИДАЦИИ (на нём не обучались) -> превью осмысленное и самодостаточное
    if idx is None:
        idx = TrainConfig().train_samples           # первый val-пример
    pr_path = f"{data_dir}/prompts/{idx}_prompt.json"
    img_path = f"{data_dir}/images/{idx}_original.png"
    pr = json.load(open(pr_path))
    return dict(image_path=img_path, description=pr["original_prompt"] + " ", prompt=pr["edit_prompt"])




@torch.no_grad()
def sample_edit_image(vlm, tokenizer, image_path, description, prompt, device, max_new_tokens=256):
    if not os.path.exists(image_path):
        return None
    was_training = vlm.training
    vlm.eval()
    orig_idx = lg_encode_indices(Image.open(image_path), 256)
    or_tokens = (np.asarray(orig_idx).reshape(-1) + tokenizer.vocab_size).tolist()
    text = f"Original image description: {description}; Prompt: {prompt}; Answer:"
    input_ids = torch.LongTensor([or_tokens + tokenizer.encode(text)]).to(device)

    preds = vlm.generate(input_ids, max_new_tokens=max_new_tokens).cpu().tolist()[0]
    vis = [x - tokenizer.vocab_size for x in preds if x >= tokenizer.vocab_size]
    vis = (vis[:N_IMG_TOKENS] + [0] * N_IMG_TOKENS)[:N_IMG_TOKENS]
    out = lg_decode_to_pil(vis, grid=16)
    vlm.train(was_training)
    return out


def get_dataloaders(collator, train_cfg):
    tr = EditTokenDataset(DATA_DIR, 0, train_cfg.train_samples)
    va = EditTokenDataset(DATA_DIR, train_cfg.train_samples, train_cfg.train_samples + train_cfg.val_samples)
    return (DataLoader(tr, batch_size=train_cfg.batch_size, shuffle=True, collate_fn=collator, num_workers=0, drop_last=True),
            DataLoader(va, batch_size=train_cfg.batch_size, shuffle=False, collate_fn=collator, num_workers=0, drop_last=True))


def train(train_cfg, vlm_cfg):
    tokenizer = AutoTokenizer.from_pretrained(vlm_cfg.lm_tokenizer, use_fast=True)
    tokenizer.pad_token = tokenizer.eos_token
    collator = VQCollator(tokenizer)
    train_loader, val_loader = get_dataloaders(collator, train_cfg)

    # при resume не качаем заново бэкбон -- грузим всё из чекпоинта
    model = VisionLanguageModel(vlm_cfg, load_backbone=train_cfg.resume_checkpoint is None).to(DEVICE)
    start_epoch = 0
    if train_cfg.resume_checkpoint:
        model.load_state_dict(torch.load(train_cfg.resume_checkpoint, map_location=DEVICE))
        import re
        m = re.search(r"epoch_(\d+)", train_cfg.resume_checkpoint)
        start_epoch = int(m.group(1)) + 1 if m else 0
        print(f"resumed from {train_cfg.resume_checkpoint} (start at epoch {start_epoch})")
    print(f"params: {sum(p.numel() for p in model.parameters()):,} | vocab {vlm_cfg.lm_vocab_size}")

    optimizer = optim.AdamW(model.parameters(), lr=train_cfg.lr)
    total_steps = len(train_loader) * train_cfg.epochs
    os.makedirs("results_vqonly", exist_ok=True); os.makedirs("checkpoints", exist_ok=True)
    losses = []; step = start_epoch * len(train_loader)   # держим lr-расписание согласованным
    for epoch in range(start_epoch, train_cfg.epochs):
        model.train(); running = 0.0; t0 = time.time()
        for batch in tqdm(train_loader):
            lr = get_lr(step, train_cfg.lr, total_steps)
            for pg in optimizer.param_groups: pg["lr"] = lr
            optimizer.zero_grad()
            _, loss = model(batch["input_ids"].to(DEVICE), batch["attention_mask"].to(DEVICE),
                            targets=batch["labels"].to(DEVICE))
            loss.backward(); optimizer.step()
            running += loss.item(); losses.append(loss.item()); step += 1
        print(f"epoch {epoch+1}/{train_cfg.epochs} | train {running/len(train_loader):.4f} | {time.time()-t0:.1f}s")

        edited = sample_edit_image(model, tokenizer, device=DEVICE, **EVAL_EXAMPLE)
        if edited is not None:
            edited.save(f"results_vqonly/edit_epoch_{epoch:03d}.png")
            plt.figure(figsize=(3, 3)); plt.imshow(edited); plt.axis("off"); plt.title(f"epoch {epoch+1}"); plt.show()
        torch.save(model.state_dict(), f"checkpoints/vqonly_epoch_{epoch}.pt")

    plt.plot(losses); plt.xlabel("step"); plt.ylabel("train loss"); plt.grid(True); plt.show()
    return model

# %%
EVAL_EXAMPLE = get_eval_example("./data_vqllm/", 14)
print("eval example:", EVAL_EXAMPLE.get("prompt"))
# Out:
# eval example: The siblings are all robots

# %%
vlm_cfg = VLMConfig()
train_cfg = TrainConfig()
with torch.enable_grad():
    model = train(train_cfg, vlm_cfg)
# Out:
# Extending token embeddings from torch.Size([49152, 576]) to torch.Size([65536, 576])
# Initialized 16384 new token embeddings
# Successfully loaded HuggingFaceTB/SmolLM2-135M weights from safetensors. Model has 143,952,192 parameters.
# params: 143,952,192 | vocab 65536
#   0%|          | 0/2500 [00:00<?, ?it/s]
# epoch 1/20 | train 9.8721 | 645.0s
#   0%|          | 0/2500 [00:00<?, ?it/s]
# epoch 2/20 | train 9.5708 | 645.3s
#   0%|          | 0/2500 [00:00<?, ?it/s]

# %%
1

# %% [markdown]
# ## Итог
#
# Это базовый VQ-only вариант: **один токенизатор (LlamaGen) для входа и выхода, единый расширенный словарь, чистый next-token prediction**.
#
# Слабое место — VQ-токены заточены под пиксельную реконструкцию, а не под семантику, поэтому модели тяжело «понимать» входную картинку. В следующем ноутбуке заменим вход на CLIP (подход Janus), оставив LlamaGen на выходе.

# %%
# пример из валидации (можно заменить своим dict(image_path=..., description=..., prompt=...))
# ex = get_eval_example()
ex = dict(image_path="berner.jpg", description="A photo of a bernese mountain dog puppy. ", prompt="Make the puppy a tiger!")

edited = sample_edit_image(infer_model, infer_tokenizer, device=DEVICE, **ex)
orig = center_crop_arr(Image.open(ex["image_path"]).convert("RGB"), 256)

fig, ax = plt.subplots(1, 2, figsize=(8, 4))
ax[0].imshow(orig);   ax[0].set_title("input"); ax[0].axis("off")
ax[1].imshow(edited); ax[1].set_title(f"edit: {ex['prompt']}"); ax[1].axis("off")
plt.show()
